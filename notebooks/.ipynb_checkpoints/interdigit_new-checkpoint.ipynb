# %%
import MDAnalysis as mda
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import sys

# %%
base_dir = os.path.abspath(os.path.join('..', 'membrane'))
sys.path.append(base_dir)

# %%
from analysis import InterdigitationAnalysis,  Membrane_overlap_distance, MicAnalysis, OverlapAnalysis

# %%
def loader(topology_path, trajectory_path):
    u = mda.Universe(topology_path, trajectory_path)
    return u

# %%
u1 = loader('../../trajs/gro.gro', '../../trajs/c36_skip100.xtc')
u2 = loader('../../trajs/gro.gro', '../../trajs/c36c_skip100.xtc')
u3 = loader('../../trajs/ld.psf', '../../trajs/drude_skip100.dcd')
u4 = loader('../../trajs/ld.psf', '../../trajs/3mn_eq.dcd')
u5 = loader('../../trajs/ld.psf', '../../trajs/5mn.dcd')
u6 = loader('../../trajs/ld.psf', '../../trajs/eq.dcd')

# %% [markdown]
# First we calculate the average distance that the TG tails intercalate with the PL monolayer

# %%
def manager(u, start_frame=0, end_frame=None, method='all',
            atom_name='C316', lipid_1='POPC', lipid_2='DOPE', 
            lipid_3='SAPI', neutral_lipid='TRIO'):
    
    instance = Membrane_overlap_distance(u, start_frame, end_frame)
    instance.setup_groups(atom_name, lipid_1, lipid_2, lipid_3, neutral_lipid)
    results = instance.analyze_trajectory(method)
    df = instance.analysis_to_df(results)
    
    analysis = OverlapAnalysis(df, method='all')
    analysis.print_analysis()
    overlap_overtime = analysis.calculate_average_overlap_depth()
    overlap_average = analysis.calculate_average_depth_overall()
    overlap_number = analysis.calculate_number_of_overlaps_per_frame()

    return df, overlap_overtime, overlap_number

# %%
# Define a function that calls manager with appropriate arguments
def load_dataset(universe, start_frame=0, end_frame=None):
    return manager(
        universe, start_frame=start_frame, end_frame=end_frame, method='all',
        atom_name='C316', lipid_1='POPC', lipid_2='DOPE',
        lipid_3='SAPI', neutral_lipid='TRIO'
    )

# Now, load all datasets using the function
df_c36, time_c36, number_c36 = load_dataset(u1)
df_c36c, time_c36c, number_c36c = load_dataset(u2)
df_drude, time_drude, number_drude = load_dataset(u3)
df_3mn, time_3mn, number_3mn = load_dataset(u4)
df_5mn, time_5mn, number_5mn = load_dataset(u5)
df_eq, tim_eq, number_eq = load_dataset(u6)
df_early, time_early, number_early = load_dataset(u3, end_frame=100)
# Out:
# Overall Average Overlap Depth: 4.2433114
# Overall Average Overlap Depth: 4.3869414
# Overall Average Overlap Depth: 3.86824
# Overall Average Overlap Depth: 3.4213157
# Overall Average Overlap Depth: 4.303415
# Overall Average Overlap Depth: 3.8073835
# Overall Average Overlap Depth: 3.7314126

# %%
def plot_overlap(df, title="Average Overlap Depth over Time", x_label="Time (ns)", y_label="Average Overlap Depth (Å)", ylim=(2, 6), figsize=(6, 3)):
    """
    Plots Average Overlap Depth over Time.

    Parameters:
    - df: Pandas DataFrame containing the data
    - time_col: Name of the column for the x-axis (time)
    - overlap_col: Name of the column for the y-axis (average overlap depth)
    - title: Title of the plot
    - x_label: Label for the x-axis
    - y_label: Label for the y-axis
    - ylim: Tuple specifying the y-axis limits
    - figsize: Tuple specifying the figure size
    """
    plt.figure(figsize=figsize)
    plt.plot(df["Time"], df["Average_Overlap_Depth"], marker='o', linestyle='-', color='teal', label='Average Overlap Depth')

    # Adding titles and labels with smaller font sizes
    plt.title(title, fontsize=12)
    plt.xlabel(x_label, fontsize=10)
    plt.ylabel(y_label, fontsize=10)
    plt.ylim(ylim)

    # Adding gridlines, legend, and customizing the plot
    plt.grid(visible=True, linestyle='--', alpha=0.7)
    plt.legend(fontsize=10)
    plt.tight_layout()
    plt.show()

def plot_overlap_number(df, title="Number over Time", x_label="Time (ns)", y_label="Average Overlap Depth (Å)", ylim=(0, 100), figsize=(6, 3)):
    """
    Plots Average Overlap Depth over Time.

    Parameters:
    - df: Pandas DataFrame containing the data
    - time_col: Name of the column for the x-axis (time)
    - overlap_col: Name of the column for the y-axis (average overlap depth)
    - title: Title of the plot
    - x_label: Label for the x-axis
    - y_label: Label for the y-axis
    - ylim: Tuple specifying the y-axis limits
    - figsize: Tuple specifying the figure size
    """
    plt.figure(figsize=figsize)
    plt.plot(df["Time"], df["Number_of_Overlaps"], marker='o', linestyle='-', color='teal', label='Average Overlap Depth')

    # Adding titles and labels with smaller font sizes
    plt.title(title, fontsize=12)
    plt.xlabel(x_label, fontsize=10)
    plt.ylabel(y_label, fontsize=10)
    plt.ylim(ylim)

    # Adding gridlines, legend, and customizing the plot
    plt.grid(visible=True, linestyle='--', alpha=0.7)
    plt.legend(fontsize=10)
    plt.tight_layout()
    plt.show()

# %%
plot_overlap(time_c36, title='c36')
plot_overlap(time_c36c, title='c36c')
plot_overlap(time_drude, title='drude eq')
plot_overlap(time_3mn,title='drude 2.5mn')
plot_overlap(time_5mn,title='drude 5mn')
plot_overlap(time_early,title='drude early')

# %%
plot_overlap_number(number_c36, title='c36')
plot_overlap_number(number_c36c, title='c36c')
plot_overlap_number(number_drude, title='drude eq')
plot_overlap_number(number_3mn,title='drude 2.5mn')
plot_overlap_number(number_5mn,title='drude 5mn')
plot_overlap_number(number_early,title='drude early')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def histo_overlap(df, title):
    plt.figure(figsize=(4, 3))
    sns.histplot(df["Max_Overlap_Distance"], kde=True, bins=30, color='teal', stat='density')

    # Adding labels and title
    plt.title(title, fontsize=10)
    plt.xlabel("Max Overlap Distance (Å)", fontsize=14)
    plt.ylabel("Probability Density", fontsize=14)
    plt.grid(visible=True, linestyle='--', alpha=0.7)
    plt.ylim(0,0.3)
    plt.xlim(0,20)
    plt.tight_layout()
    plt.show()

# %%
histo_overlap(df_c36,'c36')
histo_overlap(df_c36c, 'c36c')
histo_overlap(df_drude,'drude')
histo_overlap(df_3mn,'2.5mn')
histo_overlap(df_5mn,'5mn')
histo_overlap(df_early,'drude early')

# %% [markdown]
# # Interdigitation, overlap, densities

# %%
# Define a function to perform the analysis
def run_interdigitation_analysis(structure, trajectory, lipids, neutral_lipid, solvent, nbins=100, b=0, e=None):
    analysis = InterdigitationAnalysis(structure, trajectory, lipids, neutral_lipid, solvent)
    return analysis.interdigit(nbins=nbins, b=b, e=e)

# Use the function to perform the analyses
results_c36 = run_interdigitation_analysis(
    '../../trajs/gro.gro', '../../trajs/c36_skip100.xtc', ['POPC', 'DOPE', 'SAPI'], 'TRIO', 'TIP3'
)

results_c36c = run_interdigitation_analysis(
    '../../trajs/gro.gro', '../../trajs/c36c_skip100.xtc', ['POPC', 'DOPE', 'SAPI'], 'TRIO', 'TIP3'
)

results_drude = run_interdigitation_analysis(
    '../../trajs/ld.psf', '../../trajs/drude_skip100.dcd', ['POPC', 'DOPE'], 'TRIO', 'SWM4'
)

results_3mn = run_interdigitation_analysis(
    '../../trajs/ld.psf', '../../trajs/3mn_eq.dcd', ['POPC', 'DOPE'], 'TRIO', 'SWM4'
)

results_5mn = run_interdigitation_analysis(
    '../../trajs/ld.psf', '../../trajs/5mn.dcd', ['POPC', 'DOPE'], 'TRIO', 'SWM4'
)

results_early = run_interdigitation_analysis(
    '../../trajs/ld.psf', '../../trajs/drude_skip100.dcd', ['POPC', 'DOPE'], 'TRIO', 'SWM4',e=100
)
# Out:
# analyzing 0 us....
# analyzing 1 us....
# units: Z (nm), interdigitation (nm), time (ns), density (g/m3)
# analyzing 0 us....
# analyzing 1 us....
# units: Z (nm), interdigitation (nm), time (ns), density (g/m3)
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# units: Z (nm), interdigitation (nm), time (ns), density (g/m3)
# units: Z (nm), interdigitation (nm), time (ns), density (g/m3)
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# units: Z (nm), interdigitation (nm), time (ns), density (g/m3)
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# units: Z (nm), interdigitation (nm), time (ns), density (g/m3)

# %%
def plot_interdigitation_over_time(results):
    # Extract data for plotting
    total_interdigitation = results['inter']['total']
    strong_interdigitation = results['inter']['strong']
    weak_interdigitation = results['inter']['weak']

    # Extract time and interdigitation values
    time_total, inter_total = total_interdigitation[:, 0], total_interdigitation[:, 1]
    time_strong, inter_strong = strong_interdigitation[:, 0], strong_interdigitation[:, 1]
    time_weak, inter_weak = weak_interdigitation[:, 0], weak_interdigitation[:, 1]

    # Create the plot
    plt.figure(figsize=(5, 2))
    plt.plot(time_total, inter_total, label='Total Intedigitation', color='blue')
    plt.plot(time_strong, inter_strong, label='Strong Intedigitation', color='green')
    plt.plot(time_weak, inter_weak, label='Weak Intedigitation', color='red')

    plt.title('Interdigitation Over Time')
    plt.xlabel('Time (ns)')
    plt.ylabel('Interdigitation (nm)')
    plt.ylim(0, 2.9)
#     plt.legend()
    plt.grid(True)
    plt.show()
def plot_overlap(results):
    # Extract data for plotting
    total_overlap = results['ov']['total']
    strong_overlap = results['ov']['strong']
    weak_overlap = results['ov']['weak']

    # Extract z-coordinates and overlap values
    z_coords, ov_total = total_overlap[:, 0], total_overlap[:, 1]
    _, ov_strong = strong_overlap[:, 0], strong_overlap[:, 1]
    _, ov_weak = weak_overlap[:, 0], weak_overlap[:, 1]

    # Create the plot
    plt.figure(figsize=(5, 2))
    plt.plot(z_coords, ov_total, label='Total Overlap', color='blue', linewidth=2)
    plt.plot(z_coords, ov_strong, label='Strong Overlap', color='green', linewidth=2)
    plt.plot(z_coords, ov_weak, label='Weak Overlap', color='red', linewidth=2)

    plt.title('Overlap as a Function of Z-coordinate')
    plt.xlabel('Z-coordinate (nm)')
    plt.ylabel('Overlap (dimensionless)')
    plt.ylim(0, 1)
    plt.legend()
    plt.grid(True)
    plt.show()

# Assuming 'results' is your data dictionary loaded as per your simulation outputs


def plot_densities(results):
    # Extract density data
    pl_density = results['density']['PL']
    trio_density = results['density']['TRIO']
    surf_trio_density = results['density']['SURF-TRIO']
    core_trio_density = results['density']['CORE-TRIO']
    water_density = results['density']['water']

    # Extract z-coordinates and density values
    z_coords, den_pl = pl_density[:, 0], pl_density[:, 1]
    _, den_trio = trio_density[:, 0], trio_density[:, 1]
    _, den_surf_trio = surf_trio_density[:, 0], surf_trio_density[:, 1]
    _, den_core_trio = core_trio_density[:, 0], core_trio_density[:, 1]
    _, den_water = water_density[:, 0], water_density[:, 1]

    # Create the plot
    plt.figure(figsize=(5, 2))
    plt.plot(z_coords, den_pl, label='PL Density', color='blue', linewidth=2)
    plt.plot(z_coords, den_trio, label='TRIO Density', color='green', linewidth=2)
    plt.plot(z_coords, den_surf_trio, label='SURF-TRIO Density', color='red', linewidth=2)
    plt.plot(z_coords, den_core_trio, label='CORE-TRIO Density', color='purple', linewidth=2)
    plt.plot(z_coords, den_water, label='Water Density', color='cyan', linewidth=2)
#     plt.ylim(0,0.02)

    plt.title('Density Profiles Along Z-Coordinate')
    plt.xlabel('Z-coordinate (nm)')
    plt.ylabel('Density (g/m³)')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_ratios(results):
    # Extract data for plotting
    num_ratio = results['ratio']['num']          # Number of strong interdigitating molecules over time
    trio_to_pl_ratio = results['ratio']['trio-to-pl']  # Ratio of strong interdigitating molecules to phospholipids
    trio_to_pl_trio_ratio = results['ratio']['trio-to-pl+trio']  # Ratio of strong interdigitating molecules to the sum of phospholipids and strong interdigitating molecules

    # Extract time and ratio values
    time_num, ratio_num = num_ratio[:, 0], num_ratio[:, 1]
    time_trio_to_pl, ratio_trio_to_pl = trio_to_pl_ratio[:, 0], trio_to_pl_ratio[:, 1]
    time_trio_to_pl_trio, ratio_trio_to_pl_trio = trio_to_pl_trio_ratio[:, 0], trio_to_pl_trio_ratio[:, 1]

    # Create the plot
    plt.figure(figsize=(8, 6))
    plt.subplot(311)  # 3 rows, 1 column, 1st subplot
    plt.plot(time_num, ratio_num, label='Number of Strong Interdigitators', color='blue', linewidth=2)
    plt.title('Number of Strong Interdigitating Molecules Over Time')
    plt.xlabel('Time (ns)')
    plt.ylabel('Number')
    plt.ylim(0,20)
#     plt.legend()
    plt.grid(True)

    plt.subplot(312)  # 3 rows, 1 column, 2nd subplot
    plt.plot(time_trio_to_pl, ratio_trio_to_pl, label='Ratio of Strong Interdigitators to PL', color='green', linewidth=2)
    plt.title('Ratio of Strong Interdigitating Molecules to Phospholipids')
    plt.xlabel('Time (ns)')
    plt.ylabel('Ratio')
#     plt.legend()
    plt.grid(True)

    plt.subplot(313)  # 3 rows, 1 column, 3rd subplot
    plt.plot(time_trio_to_pl_trio, ratio_trio_to_pl_trio, label='Ratio of Strong Interdigitators to PL+Strong Interdigitators', color='red', linewidth=2)
    plt.title('Ratio of Strong Interdigitating Molecules to Total (PL + Strong Interdigitators)')
    plt.xlabel('Time (ns)')
    plt.ylabel('Ratio')
#     plt.legend()
    plt.grid(True)

    plt.tight_layout()  # Adjust subplots to fit into figure area.
    plt.show()

# %%
# Assuming 'results' is your data dictionary loaded as per your simulation outputs
plot_interdigitation_over_time(results_c36)
plot_interdigitation_over_time(results_c36c)
plot_interdigitation_over_time(results_drude)
plot_interdigitation_over_time(results_3mn)
plot_interdigitation_over_time(results_5mn)
plot_interdigitation_over_time(results_early)

# %%
plot_overlap(results_c36)
plot_overlap(results_c36c)
plot_overlap(results_drude)
plot_overlap(results_3mn)
plot_overlap(results_5mn)
plot_overlap(results_early)

# %%
# Assuming 'results' is your data dictionary loaded as per your simulation outputs
plot_densities(results_c36)
plot_densities(results_c36c)
plot_densities(results_drude)
plot_densities(results_3mn)
plot_densities(results_5mn)
plot_densities(results_early)

# %%
plot_ratios(results_c36)
plot_ratios(results_c36c)
plot_ratios(results_drude)
plot_ratios(results_drude_eq)
plot_ratios(results_drude_3mn)

# %% [markdown]
# # Develop method for new interdigitation

# %%
def percent_overlap(results, type1_name, type2_name):
    # Retrieve density arrays from the results using the provided names
    type_density_1 = results['density'][type1_name]
    type_density_2 = results['density'][type2_name]
    z = type_density_1[:, 0]
    if type_density_1.shape != type_density_2.shape:
        raise ValueError("The two density arrays must have the same shape.")
    overlap_density = np.minimum(type_density_1[:, 1], type_density_2[:, 1])
    total_area = np.trapz(type_density_1[:, 1], x=z)
    overlap_area = np.trapz(overlap_density, x=z)
    overlap_percentage = (overlap_area / total_area) * 100
    print(f"The overlap of {type2_name} with {type1_name} represents {overlap_percentage:.2f}% of the total {type1_name} area.")
    return(overlap_percentage)

# %%
def percent_overlap_time_series(results, type1_name, type2_name):
    # Retrieve time-series density arrays from the results
    type_series_1 = results['density'][f'{type1_name}_series']
    type_series_2 = results['density'][f'{type2_name}_series']
    times = results['inter']['total'][:, 0]  # Assuming this time array is appropriate for both densities
    z = results['density'][type1_name][:, 0]  # Assuming the z-axis values are the same for both densities
    if type_series_1.shape != type_series_2.shape:
        raise ValueError("The two time-series density arrays must have the same shape.")
    overlap_percentages = []
    for t in range(len(times)):
        overlap_density = np.minimum(type_series_1[t], type_series_2[t])
        total_area = np.trapz(type_series_1[t], x=z)
        overlap_area = np.trapz(overlap_density, x=z)
        overlap_percentage = (overlap_area / total_area) * 100
        overlap_percentages.append(overlap_percentage)
    overlap_percentages = np.array(overlap_percentages)
    for time, overlap in zip(times, overlap_percentages):
        print(f"At time {time} ns, the overlap of {type2_name} with {type1_name} is {overlap:.2f}%.")

    return times, overlap_percentages

# %%
# Assuming `results_c36` is your results dictionary containing the time-series densities
times1, overlap_evolution1 = percent_overlap_time_series(results_c36, 'PL', 'CORE-TRIO')
times2, overlap_evolution2 = percent_overlap_time_series(results_c36c, 'PL', 'CORE-TRIO')
times3, overlap_evolution3 = percent_overlap_time_series(results_drude, 'PL', 'CORE-TRIO')

times4, overlap_evolution4 = percent_overlap_time_series(results_3mn, 'PL', 'CORE-TRIO')
times5, overlap_evolution5 = percent_overlap_time_series(results_5mn, 'PL', 'CORE-TRIO')
times6, overlap_evolution6 = percent_overlap_time_series(results_early, 'PL', 'CORE-TRIO')
# Out:
# At time 0.0 ns, the overlap of CORE-TRIO with PL is 0.56%.
# At time 10.0 ns, the overlap of CORE-TRIO with PL is 11.37%.
# At time 20.0 ns, the overlap of CORE-TRIO with PL is 12.12%.
# At time 30.0 ns, the overlap of CORE-TRIO with PL is 13.35%.
# At time 40.0 ns, the overlap of CORE-TRIO with PL is 11.37%.
# At time 50.0 ns, the overlap of CORE-TRIO with PL is 11.35%.
# At time 60.0 ns, the overlap of CORE-TRIO with PL is 11.67%.
# At time 70.0 ns, the overlap of CORE-TRIO with PL is 11.70%.
# At time 80.0 ns, the overlap of CORE-TRIO with PL is 11.17%.
# At time 90.0 ns, the overlap of CORE-TRIO with PL is 12.23%.
# At time 100.0 ns, the overlap of CORE-TRIO with PL is 12.80%.
# At time 110.0 ns, the overlap of CORE-TRIO with PL is 10.45%.
# At time 120.0 ns, the overlap of CORE-TRIO with PL is 11.14%.
# At time 130.0 ns, the overlap of CORE-TRIO with PL is 12.23%.
# At time 140.0 ns, the overlap of CORE-TRIO with PL is 10.72%.
# At time 150.0 ns, the overlap of CORE-TRIO with PL is 10.82%.
# At time 160.0 ns, the overlap of CORE-TRIO with PL is 11.61%.
# At time 170.0 ns, the overlap of CORE-TRIO with PL is 12.45%.
# At time 180.0 ns, the overlap of CORE-TRIO with PL is 13.05%.
# At time 190.0 ns, the overlap of CORE-TRIO with PL is 10.99%.
# At time 200.0 ns, the overlap of CORE-TRIO with PL is 12.88%.
# At time 210.0 ns, the overlap of CORE-TRIO with PL is 13.58%.
# At time 220.0 ns, the overlap of CORE-TRIO with PL is 11.44%.
# At time 230.0 ns, the overlap of CORE-TRIO with PL is 12.43%.
# At time 240.0 ns, the overlap of CORE-TRIO with PL is 12.07%.
# At time 250.0 ns, the overlap of CORE-TRIO with PL is 11.95%.
# At time 260.0 ns, the overlap of CORE-TRIO with PL is 13.25%.
# At time 270.0 ns, the overlap of CORE-TRIO with PL is 12.61%.
# At time 280.0 ns, the overlap of CORE-TRIO with PL is 10.90%.
# At time 290.0 ns, the overlap of CORE-TRIO with PL is 10.63%.
# At time 300.0 ns, the overlap of CORE-TRIO with PL is 10.69%.
# At time 310.0 ns, the overlap of CORE-TRIO with PL is 12.44%.
# At time 320.0 ns, the overlap of CORE-TRIO with PL is 12.92%.
# At time 330.0 ns, the overlap of CORE-TRIO with PL is 12.80%.
# At time 340.0 ns, the overlap of CORE-TRIO with PL is 11.50%.
# At time 350.0 ns, the overlap of CORE-TRIO with PL is 12.06%.
# At time 360.0 ns, the overlap of CORE-TRIO with PL is 13.55%.
# At time 370.0 ns, the overlap of CORE-TRIO with PL is 13.38%.
# At time 380.0 ns, the overlap of CORE-TRIO with PL is 10.88%.
# At time 390.0 ns, the overlap of CORE-TRIO with PL is 13.64%.
# At time 400.0 ns, the overlap of CORE-TRIO with PL is 12.94%.
# At time 410.0 ns, the overlap of CORE-TRIO with PL is 12.50%.
# At time 420.0 ns, the overlap of CORE-TRIO with PL is 12.22%.
# At time 430.0 ns, the overlap of CORE-TRIO with PL is 12.78%.
# At time 440.0 ns, the overlap of CORE-TRIO with PL is 13.86%.
# At time 450.0 ns, the overlap of CORE-TRIO with PL is 12.15%.
# At time 460.0 ns, the overlap of CORE-TRIO with PL is 12.88%.
# At time 470.0 ns, the overlap of CORE-TRIO with PL is 10.82%.
# At time 480.0 ns, the overlap of CORE-TRIO with PL is 12.21%.
# At time 490.0 ns, the overlap of CORE-TRIO with PL is 11.86%.
# At time 500.0 ns, the overlap of CORE-TRIO with PL is 11.64%.
# At time 510.0 ns, the overlap of CORE-TRIO with PL is 10.48%.
# At time 520.0 ns, the overlap of CORE-TRIO with PL is 11.76%.
# At time 530.0 ns, the overlap of CORE-TRIO with PL is 12.42%.
# At time 540.0 ns, the overlap of CORE-TRIO with PL is 13.32%.
# At time 550.0 ns, the overlap of CORE-TRIO with PL is 12.20%.
# At time 560.0 ns, the overlap of CORE-TRIO with PL is 12.08%.
# At time 570.0 ns, the overlap of CORE-TRIO with PL is 11.41%.
# At time 580.0 ns, the overlap of CORE-TRIO with PL is 14.29%.
# At time 590.0 ns, the overlap of CORE-TRIO with PL is 13.41%.
# At time 600.0 ns, the overlap of CORE-TRIO with PL is 14.05%.
# At time 610.0 ns, the overlap of CORE-TRIO with PL is 12.40%.
# At time 620.0 ns, the overlap of CORE-TRIO with PL is 13.62%.
# At time 630.0 ns, the overlap of CORE-TRIO with PL is 11.82%.
# At time 640.0 ns, the overlap of CORE-TRIO with PL is 14.00%.
# At time 650.0 ns, the overlap of CORE-TRIO with PL is 13.08%.
# At time 660.0 ns, the overlap of CORE-TRIO with PL is 11.45%.
# At time 670.0 ns, the overlap of CORE-TRIO with PL is 12.41%.
# At time 680.0 ns, the overlap of CORE-TRIO with PL is 13.38%.
# At time 690.0 ns, the overlap of CORE-TRIO with PL is 12.45%.
# At time 700.0 ns, the overlap of CORE-TRIO with PL is 12.31%.
# At time 710.0 ns, the overlap of CORE-TRIO with PL is 12.38%.
# At time 720.0 ns, the overlap of CORE-TRIO with PL is 12.51%.
# At time 730.0 ns, the overlap of CORE-TRIO with PL is 13.58%.
# At time 740.0 ns, the overlap of CORE-TRIO with PL is 12.70%.
# At time 750.0 ns, the overlap of CORE-TRIO with PL is 13.81%.
# At time 760.0 ns, the overlap of CORE-TRIO with PL is 14.82%.
# At time 770.0 ns, the overlap of CORE-TRIO with PL is 10.96%.
# At time 780.0 ns, the overlap of CORE-TRIO with PL is 10.49%.
# At time 790.0 ns, the overlap of CORE-TRIO with PL is 12.23%.
# At time 800.0 ns, the overlap of CORE-TRIO with PL is 13.31%.
# At time 810.0 ns, the overlap of CORE-TRIO with PL is 12.63%.
# At time 820.0 ns, the overlap of CORE-TRIO with PL is 14.52%.
# At time 830.0 ns, the overlap of CORE-TRIO with PL is 11.94%.
# At time 840.0 ns, the overlap of CORE-TRIO with PL is 13.73%.
# At time 850.0 ns, the overlap of CORE-TRIO with PL is 12.11%.
# At time 860.0 ns, the overlap of CORE-TRIO with PL is 13.55%.
# At time 870.0 ns, the overlap of CORE-TRIO with PL is 14.03%.
# At time 880.0 ns, the overlap of CORE-TRIO with PL is 12.43%.
# At time 890.0 ns, the overlap of CORE-TRIO with PL is 12.68%.
# At time 900.0 ns, the overlap of CORE-TRIO with PL is 12.05%.
# At time 910.0 ns, the overlap of CORE-TRIO with PL is 12.51%.
# At time 920.0 ns, the overlap of CORE-TRIO with PL is 11.73%.
# At time 930.0 ns, the overlap of CORE-TRIO with PL is 13.45%.
# At time 940.0 ns, the overlap of CORE-TRIO with PL is 12.13%.
# At time 950.0 ns, the overlap of CORE-TRIO with PL is 13.46%.
# At time 960.0 ns, the overlap of CORE-TRIO with PL is 12.96%.
# At time 970.0 ns, the overlap of CORE-TRIO with PL is 13.76%.
# At time 980.0 ns, the overlap of CORE-TRIO with PL is 14.25%.
# At time 990.0 ns, the overlap of CORE-TRIO with PL is 12.99%.
# At time 1000.0 ns, the overlap of CORE-TRIO with PL is 10.96%.
# At time 1010.0 ns, the overlap of CORE-TRIO with PL is 12.62%.
# At time 1020.0 ns, the overlap of CORE-TRIO with PL is 11.74%.
# At time 1030.0 ns, the overlap of CORE-TRIO with PL is 12.05%.
# At time 1040.0 ns, the overlap of CORE-TRIO with PL is 13.17%.
# At time 1050.0 ns, the overlap of CORE-TRIO with PL is 12.69%.
# At time 1060.0 ns, the overlap of CORE-TRIO with PL is 12.70%.
# At time 1070.0 ns, the overlap of CORE-TRIO with PL is 13.56%.
# At time 1080.0 ns, the overlap of CORE-TRIO with PL is 12.49%.
# At time 0.0 ns, the overlap of CORE-TRIO with PL is 0.56%.
# At time 10.0 ns, the overlap of CORE-TRIO with PL is 12.00%.
# At time 20.0 ns, the overlap of CORE-TRIO with PL is 12.34%.
# At time 30.0 ns, the overlap of CORE-TRIO with PL is 11.98%.
# At time 40.0 ns, the overlap of CORE-TRIO with PL is 13.19%.
# At time 50.0 ns, the overlap of CORE-TRIO with PL is 12.34%.
# At time 60.0 ns, the overlap of CORE-TRIO with PL is 12.62%.
# At time 70.0 ns, the overlap of CORE-TRIO with PL is 12.26%.
# At time 80.0 ns, the overlap of CORE-TRIO with PL is 13.10%.
# At time 90.0 ns, the overlap of CORE-TRIO with PL is 13.60%.
# At time 100.0 ns, the overlap of CORE-TRIO with PL is 11.34%.
# At time 110.0 ns, the overlap of CORE-TRIO with PL is 11.64%.
# At time 120.0 ns, the overlap of CORE-TRIO with PL is 10.98%.
# At time 130.0 ns, the overlap of CORE-TRIO with PL is 13.10%.
# At time 140.0 ns, the overlap of CORE-TRIO with PL is 11.87%.
# At time 150.0 ns, the overlap of CORE-TRIO with PL is 13.01%.
# At time 160.0 ns, the overlap of CORE-TRIO with PL is 13.15%.
# At time 170.0 ns, the overlap of CORE-TRIO with PL is 11.46%.
# At time 180.0 ns, the overlap of CORE-TRIO with PL is 11.90%.
# At time 190.0 ns, the overlap of CORE-TRIO with PL is 12.59%.
# At time 200.0 ns, the overlap of CORE-TRIO with PL is 13.07%.
# At time 210.0 ns, the overlap of CORE-TRIO with PL is 13.02%.
# At time 220.0 ns, the overlap of CORE-TRIO with PL is 12.15%.
# At time 230.0 ns, the overlap of CORE-TRIO with PL is 12.53%.
# At time 240.0 ns, the overlap of CORE-TRIO with PL is 11.80%.
# At time 250.0 ns, the overlap of CORE-TRIO with PL is 11.55%.
# At time 260.0 ns, the overlap of CORE-TRIO with PL is 10.70%.
# At time 270.0 ns, the overlap of CORE-TRIO with PL is 11.07%.
# At time 280.0 ns, the overlap of CORE-TRIO with PL is 12.07%.
# At time 290.0 ns, the overlap of CORE-TRIO with PL is 12.23%.
# At time 300.0 ns, the overlap of CORE-TRIO with PL is 11.26%.
# At time 310.0 ns, the overlap of CORE-TRIO with PL is 12.20%.
# At time 320.0 ns, the overlap of CORE-TRIO with PL is 11.74%.
# At time 330.0 ns, the overlap of CORE-TRIO with PL is 10.76%.
# At time 340.0 ns, the overlap of CORE-TRIO with PL is 12.96%.
# At time 350.0 ns, the overlap of CORE-TRIO with PL is 13.35%.
# At time 360.0 ns, the overlap of CORE-TRIO with PL is 11.15%.
# At time 370.0 ns, the overlap of CORE-TRIO with PL is 11.35%.
# At time 380.0 ns, the overlap of CORE-TRIO with PL is 12.73%.
# At time 390.0 ns, the overlap of CORE-TRIO with PL is 13.22%.
# At time 400.0 ns, the overlap of CORE-TRIO with PL is 13.10%.
# At time 410.0 ns, the overlap of CORE-TRIO with PL is 11.14%.
# At time 420.0 ns, the overlap of CORE-TRIO with PL is 13.34%.
# At time 430.0 ns, the overlap of CORE-TRIO with PL is 14.64%.
# At time 440.0 ns, the overlap of CORE-TRIO with PL is 13.54%.
# At time 450.0 ns, the overlap of CORE-TRIO with PL is 12.34%.
# At time 460.0 ns, the overlap of CORE-TRIO with PL is 14.21%.
# At time 470.0 ns, the overlap of CORE-TRIO with PL is 14.53%.
# At time 480.0 ns, the overlap of CORE-TRIO with PL is 13.06%.
# At time 490.0 ns, the overlap of CORE-TRIO with PL is 12.65%.
# At time 500.0 ns, the overlap of CORE-TRIO with PL is 13.93%.
# At time 510.0 ns, the overlap of CORE-TRIO with PL is 11.74%.
# At time 520.0 ns, the overlap of CORE-TRIO with PL is 13.14%.
# At time 530.0 ns, the overlap of CORE-TRIO with PL is 13.03%.
# At time 540.0 ns, the overlap of CORE-TRIO with PL is 12.60%.
# At time 550.0 ns, the overlap of CORE-TRIO with PL is 10.88%.
# At time 560.0 ns, the overlap of CORE-TRIO with PL is 11.53%.
# At time 570.0 ns, the overlap of CORE-TRIO with PL is 12.41%.
# At time 580.0 ns, the overlap of CORE-TRIO with PL is 11.05%.
# At time 590.0 ns, the overlap of CORE-TRIO with PL is 12.42%.
# At time 600.0 ns, the overlap of CORE-TRIO with PL is 12.70%.
# At time 610.0 ns, the overlap of CORE-TRIO with PL is 13.30%.
# At time 620.0 ns, the overlap of CORE-TRIO with PL is 12.09%.
# At time 630.0 ns, the overlap of CORE-TRIO with PL is 12.43%.
# At time 640.0 ns, the overlap of CORE-TRIO with PL is 12.48%.
# At time 650.0 ns, the overlap of CORE-TRIO with PL is 11.24%.
# At time 660.0 ns, the overlap of CORE-TRIO with PL is 10.47%.
# At time 670.0 ns, the overlap of CORE-TRIO with PL is 12.82%.
# At time 680.0 ns, the overlap of CORE-TRIO with PL is 12.53%.
# At time 690.0 ns, the overlap of CORE-TRIO with PL is 11.63%.
# At time 700.0 ns, the overlap of CORE-TRIO with PL is 12.34%.
# At time 710.0 ns, the overlap of CORE-TRIO with PL is 11.69%.
# At time 720.0 ns, the overlap of CORE-TRIO with PL is 11.87%.
# At time 730.0 ns, the overlap of CORE-TRIO with PL is 13.24%.
# At time 740.0 ns, the overlap of CORE-TRIO with PL is 12.89%.
# At time 750.0 ns, the overlap of CORE-TRIO with PL is 14.87%.
# At time 760.0 ns, the overlap of CORE-TRIO with PL is 13.03%.
# At time 770.0 ns, the overlap of CORE-TRIO with PL is 12.56%.
# At time 780.0 ns, the overlap of CORE-TRIO with PL is 12.91%.
# At time 790.0 ns, the overlap of CORE-TRIO with PL is 12.53%.
# At time 800.0 ns, the overlap of CORE-TRIO with PL is 12.01%.
# At time 810.0 ns, the overlap of CORE-TRIO with PL is 11.78%.
# At time 820.0 ns, the overlap of CORE-TRIO with PL is 14.25%.
# At time 830.0 ns, the overlap of CORE-TRIO with PL is 12.90%.
# At time 840.0 ns, the overlap of CORE-TRIO with PL is 11.58%.
# At time 850.0 ns, the overlap of CORE-TRIO with PL is 13.48%.
# At time 860.0 ns, the overlap of CORE-TRIO with PL is 12.19%.
# At time 870.0 ns, the overlap of CORE-TRIO with PL is 12.22%.
# At time 880.0 ns, the overlap of CORE-TRIO with PL is 11.74%.
# At time 890.0 ns, the overlap of CORE-TRIO with PL is 11.46%.
# At time 900.0 ns, the overlap of CORE-TRIO with PL is 12.47%.
# At time 910.0 ns, the overlap of CORE-TRIO with PL is 12.33%.
# At time 920.0 ns, the overlap of CORE-TRIO with PL is 13.04%.
# At time 930.0 ns, the overlap of CORE-TRIO with PL is 12.77%.
# At time 940.0 ns, the overlap of CORE-TRIO with PL is 12.50%.
# At time 950.0 ns, the overlap of CORE-TRIO with PL is 12.75%.
# At time 960.0 ns, the overlap of CORE-TRIO with PL is 13.10%.
# At time 970.0 ns, the overlap of CORE-TRIO with PL is 10.50%.
# At time 980.0 ns, the overlap of CORE-TRIO with PL is 11.88%.
# At time 990.0 ns, the overlap of CORE-TRIO with PL is 10.86%.
# At time 1000.0 ns, the overlap of CORE-TRIO with PL is 11.53%.
# At time 1010.0 ns, the overlap of CORE-TRIO with PL is 13.39%.
# At time 1020.0 ns, the overlap of CORE-TRIO with PL is 12.14%.
# At time 1030.0 ns, the overlap of CORE-TRIO with PL is 10.52%.
# At time 1040.0 ns, the overlap of CORE-TRIO with PL is 12.10%.
# At time 1050.0 ns, the overlap of CORE-TRIO with PL is 14.17%.
# At time 1060.0 ns, the overlap of CORE-TRIO with PL is 11.75%.
# At time 1070.0 ns, the overlap of CORE-TRIO with PL is 12.94%.
# At time 1080.0 ns, the overlap of CORE-TRIO with PL is 12.48%.
# At time 1090.0 ns, the overlap of CORE-TRIO with PL is 11.71%.
# At time 1100.0 ns, the overlap of CORE-TRIO with PL is 13.62%.
# At time 1110.0 ns, the overlap of CORE-TRIO with PL is 12.82%.
# At time 0.0 ns, the overlap of CORE-TRIO with PL is 11.13%.
# At time 0.0010000000328495406 ns, the overlap of CORE-TRIO with PL is 11.29%.
# At time 0.002000000065699081 ns, the overlap of CORE-TRIO with PL is 10.92%.
# At time 0.0030000000985486216 ns, the overlap of CORE-TRIO with PL is 10.56%.
# At time 0.004000000131398162 ns, the overlap of CORE-TRIO with PL is 10.77%.
# At time 0.005000000164247703 ns, the overlap of CORE-TRIO with PL is 10.19%.
# At time 0.006000000197097243 ns, the overlap of CORE-TRIO with PL is 10.90%.
# At time 0.007000000229946784 ns, the overlap of CORE-TRIO with PL is 10.09%.
# At time 0.008000000262796325 ns, the overlap of CORE-TRIO with PL is 11.01%.
# At time 0.009000000295645865 ns, the overlap of CORE-TRIO with PL is 11.08%.
# At time 0.010000000328495406 ns, the overlap of CORE-TRIO with PL is 11.69%.
# At time 0.011000000361344946 ns, the overlap of CORE-TRIO with PL is 11.52%.
# At time 0.012000000394194486 ns, the overlap of CORE-TRIO with PL is 11.56%.
# At time 0.013000000427044028 ns, the overlap of CORE-TRIO with PL is 11.91%.
# At time 0.014000000459893568 ns, the overlap of CORE-TRIO with PL is 11.38%.
# At time 0.01500000049274311 ns, the overlap of CORE-TRIO with PL is 12.37%.
# At time 0.01600000052559265 ns, the overlap of CORE-TRIO with PL is 12.60%.
# At time 0.017000000558442193 ns, the overlap of CORE-TRIO with PL is 12.41%.
# At time 0.01800000059129173 ns, the overlap of CORE-TRIO with PL is 11.67%.
# At time 0.019000000624141273 ns, the overlap of CORE-TRIO with PL is 12.85%.
# At time 0.020000000656990813 ns, the overlap of CORE-TRIO with PL is 12.34%.
# At time 0.021000000689840353 ns, the overlap of CORE-TRIO with PL is 11.52%.
# At time 0.022000000722689893 ns, the overlap of CORE-TRIO with PL is 11.05%.
# At time 0.023000000755539436 ns, the overlap of CORE-TRIO with PL is 10.41%.
# At time 0.024000000788388973 ns, the overlap of CORE-TRIO with PL is 11.18%.
# At time 0.025000000821238516 ns, the overlap of CORE-TRIO with PL is 10.81%.
# At time 0.026000000854088056 ns, the overlap of CORE-TRIO with PL is 10.94%.
# At time 0.0270000008869376 ns, the overlap of CORE-TRIO with PL is 11.48%.
# At time 0.028000000919787136 ns, the overlap of CORE-TRIO with PL is 11.10%.
# At time 0.02900000095263668 ns, the overlap of CORE-TRIO with PL is 11.84%.
# At time 0.03000000098548622 ns, the overlap of CORE-TRIO with PL is 11.51%.
# At time 0.03100000101833576 ns, the overlap of CORE-TRIO with PL is 11.05%.
# At time 0.0320000010511853 ns, the overlap of CORE-TRIO with PL is 11.90%.
# At time 0.03300000108403484 ns, the overlap of CORE-TRIO with PL is 12.07%.
# At time 0.034000001116884386 ns, the overlap of CORE-TRIO with PL is 12.22%.
# At time 0.03500000114973392 ns, the overlap of CORE-TRIO with PL is 12.60%.
# At time 0.03600000118258346 ns, the overlap of CORE-TRIO with PL is 12.90%.
# At time 0.037000001215433 ns, the overlap of CORE-TRIO with PL is 13.02%.
# At time 0.038000001248282546 ns, the overlap of CORE-TRIO with PL is 12.86%.
# At time 0.03900000128113208 ns, the overlap of CORE-TRIO with PL is 12.11%.
# At time 0.040000001313981626 ns, the overlap of CORE-TRIO with PL is 11.39%.
# At time 0.04100000134683117 ns, the overlap of CORE-TRIO with PL is 12.16%.
# At time 0.042000001379680706 ns, the overlap of CORE-TRIO with PL is 11.62%.
# At time 0.04300000141253025 ns, the overlap of CORE-TRIO with PL is 11.68%.
# At time 0.044000001445379786 ns, the overlap of CORE-TRIO with PL is 12.17%.
# At time 0.04500000147822933 ns, the overlap of CORE-TRIO with PL is 11.68%.
# At time 0.04600000151107887 ns, the overlap of CORE-TRIO with PL is 12.48%.
# At time 0.047000001543928416 ns, the overlap of CORE-TRIO with PL is 12.30%.
# At time 0.048000001576777945 ns, the overlap of CORE-TRIO with PL is 12.24%.
# At time 0.04900000160962749 ns, the overlap of CORE-TRIO with PL is 12.14%.
# At time 0.05000000164247703 ns, the overlap of CORE-TRIO with PL is 11.86%.
# At time 0.051000001675326576 ns, the overlap of CORE-TRIO with PL is 12.57%.
# At time 0.05200000170817611 ns, the overlap of CORE-TRIO with PL is 12.20%.
# At time 0.053000001741025655 ns, the overlap of CORE-TRIO with PL is 12.80%.
# At time 0.0540000017738752 ns, the overlap of CORE-TRIO with PL is 12.17%.
# At time 0.055000001806724735 ns, the overlap of CORE-TRIO with PL is 11.71%.
# At time 0.05600000183957427 ns, the overlap of CORE-TRIO with PL is 11.92%.
# At time 0.057000001872423815 ns, the overlap of CORE-TRIO with PL is 11.51%.
# At time 0.05800000190527336 ns, the overlap of CORE-TRIO with PL is 10.85%.
# At time 0.0590000019381229 ns, the overlap of CORE-TRIO with PL is 11.38%.
# At time 0.06000000197097244 ns, the overlap of CORE-TRIO with PL is 10.83%.
# At time 0.061000002003821975 ns, the overlap of CORE-TRIO with PL is 10.84%.
# At time 0.06200000203667152 ns, the overlap of CORE-TRIO with PL is 10.79%.
# At time 0.06300000206952105 ns, the overlap of CORE-TRIO with PL is 11.57%.
# At time 0.0640000021023706 ns, the overlap of CORE-TRIO with PL is 11.02%.
# At time 0.06500000213522014 ns, the overlap of CORE-TRIO with PL is 11.03%.
# At time 0.06600000216806969 ns, the overlap of CORE-TRIO with PL is 9.92%.
# At time 0.06700000220091923 ns, the overlap of CORE-TRIO with PL is 10.70%.
# At time 0.06800000223376877 ns, the overlap of CORE-TRIO with PL is 10.80%.
# At time 0.06900000226661832 ns, the overlap of CORE-TRIO with PL is 11.16%.
# At time 0.07000000229946785 ns, the overlap of CORE-TRIO with PL is 11.37%.
# At time 0.07100000233231737 ns, the overlap of CORE-TRIO with PL is 10.94%.
# At time 0.07200000236516692 ns, the overlap of CORE-TRIO with PL is 11.50%.
# At time 0.07300000239801646 ns, the overlap of CORE-TRIO with PL is 11.10%.
# At time 0.074000002430866 ns, the overlap of CORE-TRIO with PL is 11.49%.
# At time 0.07500000246371555 ns, the overlap of CORE-TRIO with PL is 10.81%.
# At time 0.07600000249656509 ns, the overlap of CORE-TRIO with PL is 11.83%.
# At time 0.07700000252941464 ns, the overlap of CORE-TRIO with PL is 11.55%.
# At time 0.07800000256226416 ns, the overlap of CORE-TRIO with PL is 11.49%.
# At time 0.07900000259511371 ns, the overlap of CORE-TRIO with PL is 11.68%.
# At time 0.08000000262796325 ns, the overlap of CORE-TRIO with PL is 11.34%.
# At time 0.0810000026608128 ns, the overlap of CORE-TRIO with PL is 10.67%.
# At time 0.08200000269366234 ns, the overlap of CORE-TRIO with PL is 10.91%.
# At time 0.08300000272651188 ns, the overlap of CORE-TRIO with PL is 10.85%.
# At time 0.08400000275936141 ns, the overlap of CORE-TRIO with PL is 11.47%.
# At time 0.08500000279221095 ns, the overlap of CORE-TRIO with PL is 11.48%.
# At time 0.0860000028250605 ns, the overlap of CORE-TRIO with PL is 11.32%.
# At time 0.08700000285791003 ns, the overlap of CORE-TRIO with PL is 11.47%.
# At time 0.08800000289075957 ns, the overlap of CORE-TRIO with PL is 12.17%.
# At time 0.08900000292360911 ns, the overlap of CORE-TRIO with PL is 10.92%.
# At time 0.09000000295645866 ns, the overlap of CORE-TRIO with PL is 10.98%.
# At time 0.0910000029893082 ns, the overlap of CORE-TRIO with PL is 11.42%.
# At time 0.09200000302215774 ns, the overlap of CORE-TRIO with PL is 10.74%.
# At time 0.09300000305500729 ns, the overlap of CORE-TRIO with PL is 11.55%.
# At time 0.09400000308785683 ns, the overlap of CORE-TRIO with PL is 10.97%.
# At time 0.09500000312070636 ns, the overlap of CORE-TRIO with PL is 11.50%.
# At time 0.09600000315355589 ns, the overlap of CORE-TRIO with PL is 11.87%.
# At time 0.09700000318640543 ns, the overlap of CORE-TRIO with PL is 11.93%.
# At time 0.09800000321925498 ns, the overlap of CORE-TRIO with PL is 11.92%.
# At time 0.09900000325210452 ns, the overlap of CORE-TRIO with PL is 11.94%.
# At time 0.10000000328495406 ns, the overlap of CORE-TRIO with PL is 12.04%.
# At time 0.10100000331780361 ns, the overlap of CORE-TRIO with PL is 12.12%.
# At time 0.10200000335065315 ns, the overlap of CORE-TRIO with PL is 11.76%.
# At time 0.10300000338350268 ns, the overlap of CORE-TRIO with PL is 12.25%.
# At time 0.10400000341635222 ns, the overlap of CORE-TRIO with PL is 11.68%.
# At time 0.10500000344920177 ns, the overlap of CORE-TRIO with PL is 11.89%.
# At time 0.10600000348205131 ns, the overlap of CORE-TRIO with PL is 12.56%.
# At time 0.10700000351490085 ns, the overlap of CORE-TRIO with PL is 13.00%.
# At time 0.1080000035477504 ns, the overlap of CORE-TRIO with PL is 12.62%.
# At time 0.10900000358059993 ns, the overlap of CORE-TRIO with PL is 12.56%.
# At time 0.11000000361344947 ns, the overlap of CORE-TRIO with PL is 12.45%.
# At time 0.111000003646299 ns, the overlap of CORE-TRIO with PL is 12.79%.
# At time 0.11200000367914854 ns, the overlap of CORE-TRIO with PL is 12.63%.
# At time 0.11300000371199809 ns, the overlap of CORE-TRIO with PL is 12.76%.
# At time 0.11400000374484763 ns, the overlap of CORE-TRIO with PL is 12.66%.
# At time 0.11500000377769717 ns, the overlap of CORE-TRIO with PL is 12.52%.
# At time 0.11600000381054672 ns, the overlap of CORE-TRIO with PL is 12.61%.
# At time 0.11700000384339626 ns, the overlap of CORE-TRIO with PL is 13.04%.
# At time 0.1180000038762458 ns, the overlap of CORE-TRIO with PL is 13.56%.
# At time 0.11900000390909535 ns, the overlap of CORE-TRIO with PL is 12.80%.
# At time 0.12000000394194488 ns, the overlap of CORE-TRIO with PL is 13.68%.
# At time 0.12100000397479442 ns, the overlap of CORE-TRIO with PL is 12.86%.
# At time 0.12200000400764395 ns, the overlap of CORE-TRIO with PL is 13.75%.
# At time 0.1230000040404935 ns, the overlap of CORE-TRIO with PL is 12.44%.
# At time 0.12400000407334304 ns, the overlap of CORE-TRIO with PL is 12.40%.
# At time 0.12500000410619258 ns, the overlap of CORE-TRIO with PL is 12.11%.
# At time 0.1260000041390421 ns, the overlap of CORE-TRIO with PL is 10.93%.
# At time 0.12700000417189167 ns, the overlap of CORE-TRIO with PL is 11.17%.
# At time 0.1280000042047412 ns, the overlap of CORE-TRIO with PL is 11.88%.
# At time 0.12900000423759073 ns, the overlap of CORE-TRIO with PL is 11.30%.
# At time 0.13000000427044028 ns, the overlap of CORE-TRIO with PL is 12.23%.
# At time 0.1310000043032898 ns, the overlap of CORE-TRIO with PL is 11.20%.
# At time 0.13200000433613937 ns, the overlap of CORE-TRIO with PL is 11.66%.
# At time 0.1330000043689889 ns, the overlap of CORE-TRIO with PL is 11.96%.
# At time 0.13400000440183846 ns, the overlap of CORE-TRIO with PL is 11.39%.
# At time 0.135000004434688 ns, the overlap of CORE-TRIO with PL is 11.71%.
# At time 0.13600000446753754 ns, the overlap of CORE-TRIO with PL is 11.78%.
# At time 0.13700000450038707 ns, the overlap of CORE-TRIO with PL is 12.54%.
# At time 0.13800000453323663 ns, the overlap of CORE-TRIO with PL is 12.58%.
# At time 0.13900000456608616 ns, the overlap of CORE-TRIO with PL is 12.97%.
# At time 0.1400000045989357 ns, the overlap of CORE-TRIO with PL is 11.85%.
# At time 0.14100000463178522 ns, the overlap of CORE-TRIO with PL is 12.57%.
# At time 0.14200000466463475 ns, the overlap of CORE-TRIO with PL is 12.42%.
# At time 0.1430000046974843 ns, the overlap of CORE-TRIO with PL is 12.49%.
# At time 0.14400000473033384 ns, the overlap of CORE-TRIO with PL is 12.74%.
# At time 0.1450000047631834 ns, the overlap of CORE-TRIO with PL is 12.93%.
# At time 0.14600000479603292 ns, the overlap of CORE-TRIO with PL is 12.94%.
# At time 0.14700000482888248 ns, the overlap of CORE-TRIO with PL is 12.89%.
# At time 0.148000004861732 ns, the overlap of CORE-TRIO with PL is 12.55%.
# At time 0.14900000489458157 ns, the overlap of CORE-TRIO with PL is 12.57%.
# At time 0.1500000049274311 ns, the overlap of CORE-TRIO with PL is 12.24%.
# At time 0.15100000496028065 ns, the overlap of CORE-TRIO with PL is 13.22%.
# At time 0.15200000499313018 ns, the overlap of CORE-TRIO with PL is 13.41%.
# At time 0.15300000502597974 ns, the overlap of CORE-TRIO with PL is 12.49%.
# At time 0.15400000505882927 ns, the overlap of CORE-TRIO with PL is 12.19%.
# At time 0.1550000050916788 ns, the overlap of CORE-TRIO with PL is 12.63%.
# At time 0.15600000512452833 ns, the overlap of CORE-TRIO with PL is 11.80%.
# At time 0.15700000515737786 ns, the overlap of CORE-TRIO with PL is 11.84%.
# At time 0.15800000519022742 ns, the overlap of CORE-TRIO with PL is 11.49%.
# At time 0.15900000522307695 ns, the overlap of CORE-TRIO with PL is 11.97%.
# At time 0.1600000052559265 ns, the overlap of CORE-TRIO with PL is 11.99%.
# At time 0.16100000528877603 ns, the overlap of CORE-TRIO with PL is 12.20%.
# At time 0.1620000053216256 ns, the overlap of CORE-TRIO with PL is 12.03%.
# At time 0.16300000535447512 ns, the overlap of CORE-TRIO with PL is 12.00%.
# At time 0.16400000538732468 ns, the overlap of CORE-TRIO with PL is 12.98%.
# At time 0.1650000054201742 ns, the overlap of CORE-TRIO with PL is 13.64%.
# At time 0.16600000545302376 ns, the overlap of CORE-TRIO with PL is 12.75%.
# At time 0.1670000054858733 ns, the overlap of CORE-TRIO with PL is 13.53%.
# At time 0.16800000551872282 ns, the overlap of CORE-TRIO with PL is 13.91%.
# At time 0.16900000555157238 ns, the overlap of CORE-TRIO with PL is 12.17%.
# At time 0.1700000055844219 ns, the overlap of CORE-TRIO with PL is 11.99%.
# At time 0.17100000561727147 ns, the overlap of CORE-TRIO with PL is 12.59%.
# At time 0.172000005650121 ns, the overlap of CORE-TRIO with PL is 11.60%.
# At time 0.17300000568297053 ns, the overlap of CORE-TRIO with PL is 11.46%.
# At time 0.17400000571582006 ns, the overlap of CORE-TRIO with PL is 11.67%.
# At time 0.1750000057486696 ns, the overlap of CORE-TRIO with PL is 11.16%.
# At time 0.17600000578151914 ns, the overlap of CORE-TRIO with PL is 12.59%.
# At time 0.1770000058143687 ns, the overlap of CORE-TRIO with PL is 11.99%.
# At time 0.17800000584721823 ns, the overlap of CORE-TRIO with PL is 11.19%.
# At time 0.1790000058800678 ns, the overlap of CORE-TRIO with PL is 11.77%.
# At time 0.18000000591291732 ns, the overlap of CORE-TRIO with PL is 12.65%.
# At time 0.18100000594576685 ns, the overlap of CORE-TRIO with PL is 11.96%.
# At time 0.1820000059786164 ns, the overlap of CORE-TRIO with PL is 11.93%.
# At time 0.18300000601146593 ns, the overlap of CORE-TRIO with PL is 12.44%.
# At time 0.1840000060443155 ns, the overlap of CORE-TRIO with PL is 11.96%.
# At time 0.18500000607716502 ns, the overlap of CORE-TRIO with PL is 11.62%.
# At time 0.18600000611001458 ns, the overlap of CORE-TRIO with PL is 11.99%.
# At time 0.1870000061428641 ns, the overlap of CORE-TRIO with PL is 11.46%.
# At time 0.18800000617571366 ns, the overlap of CORE-TRIO with PL is 11.68%.
# At time 0.18900000620856316 ns, the overlap of CORE-TRIO with PL is 12.56%.
# At time 0.19000000624141272 ns, the overlap of CORE-TRIO with PL is 12.01%.
# At time 0.19100000627426225 ns, the overlap of CORE-TRIO with PL is 12.30%.
# At time 0.19200000630711178 ns, the overlap of CORE-TRIO with PL is 12.70%.
# At time 0.19300000633996134 ns, the overlap of CORE-TRIO with PL is 11.95%.
# At time 0.19400000637281087 ns, the overlap of CORE-TRIO with PL is 13.12%.
# At time 0.19500000640566043 ns, the overlap of CORE-TRIO with PL is 12.17%.
# At time 0.19600000643850995 ns, the overlap of CORE-TRIO with PL is 12.27%.
# At time 0.1970000064713595 ns, the overlap of CORE-TRIO with PL is 11.85%.
# At time 0.19800000650420904 ns, the overlap of CORE-TRIO with PL is 11.36%.
# At time 0.1990000065370586 ns, the overlap of CORE-TRIO with PL is 11.50%.
# At time 0.20000000656990813 ns, the overlap of CORE-TRIO with PL is 11.55%.
# At time 0.20100000660275769 ns, the overlap of CORE-TRIO with PL is 11.53%.
# At time 0.20200000663560722 ns, the overlap of CORE-TRIO with PL is 11.89%.
# At time 0.20300000666845677 ns, the overlap of CORE-TRIO with PL is 12.67%.
# At time 0.2040000067013063 ns, the overlap of CORE-TRIO with PL is 12.86%.
# At time 0.2050000067341558 ns, the overlap of CORE-TRIO with PL is 12.96%.
# At time 0.20600000676700536 ns, the overlap of CORE-TRIO with PL is 12.54%.
# At time 0.2070000067998549 ns, the overlap of CORE-TRIO with PL is 11.92%.
# At time 0.20800000683270445 ns, the overlap of CORE-TRIO with PL is 12.99%.
# At time 0.20900000686555398 ns, the overlap of CORE-TRIO with PL is 12.41%.
# At time 0.21000000689840354 ns, the overlap of CORE-TRIO with PL is 13.08%.
# At time 0.21100000693125306 ns, the overlap of CORE-TRIO with PL is 13.74%.
# At time 0.21200000696410262 ns, the overlap of CORE-TRIO with PL is 13.02%.
# At time 0.21300000699695215 ns, the overlap of CORE-TRIO with PL is 13.26%.
# At time 0.2140000070298017 ns, the overlap of CORE-TRIO with PL is 12.60%.
# At time 0.21500000706265124 ns, the overlap of CORE-TRIO with PL is 12.39%.
# At time 0.2160000070955008 ns, the overlap of CORE-TRIO with PL is 12.40%.
# At time 0.21700000712835033 ns, the overlap of CORE-TRIO with PL is 13.53%.
# At time 0.21800000716119985 ns, the overlap of CORE-TRIO with PL is 13.28%.
# At time 0.2190000071940494 ns, the overlap of CORE-TRIO with PL is 12.91%.
# At time 0.22000000722689894 ns, the overlap of CORE-TRIO with PL is 12.92%.
# At time 0.2210000072597485 ns, the overlap of CORE-TRIO with PL is 11.82%.
# At time 0.222000007292598 ns, the overlap of CORE-TRIO with PL is 12.47%.
# At time 0.22300000732544756 ns, the overlap of CORE-TRIO with PL is 12.11%.
# At time 0.2240000073582971 ns, the overlap of CORE-TRIO with PL is 11.61%.
# At time 0.22500000739114664 ns, the overlap of CORE-TRIO with PL is 11.78%.
# At time 0.22600000742399617 ns, the overlap of CORE-TRIO with PL is 11.55%.
# At time 0.22700000745684573 ns, the overlap of CORE-TRIO with PL is 11.24%.
# At time 0.22800000748969526 ns, the overlap of CORE-TRIO with PL is 11.20%.
# At time 0.22900000752254482 ns, the overlap of CORE-TRIO with PL is 11.88%.
# At time 0.23000000755539435 ns, the overlap of CORE-TRIO with PL is 12.03%.
# At time 0.23100000758824388 ns, the overlap of CORE-TRIO with PL is 12.74%.
# At time 0.23200000762109343 ns, the overlap of CORE-TRIO with PL is 12.02%.
# At time 0.23300000765394296 ns, the overlap of CORE-TRIO with PL is 12.65%.
# At time 0.23400000768679252 ns, the overlap of CORE-TRIO with PL is 11.94%.
# At time 0.23500000771964205 ns, the overlap of CORE-TRIO with PL is 12.52%.
# At time 0.2360000077524916 ns, the overlap of CORE-TRIO with PL is 11.69%.
# At time 0.23700000778534114 ns, the overlap of CORE-TRIO with PL is 11.66%.
# At time 0.2380000078181907 ns, the overlap of CORE-TRIO with PL is 11.43%.
# At time 0.2390000078510402 ns, the overlap of CORE-TRIO with PL is 12.22%.
# At time 0.24000000788388975 ns, the overlap of CORE-TRIO with PL is 12.49%.
# At time 0.24100000791673928 ns, the overlap of CORE-TRIO with PL is 11.54%.
# At time 0.24200000794958884 ns, the overlap of CORE-TRIO with PL is 12.16%.
# At time 0.24300000798243837 ns, the overlap of CORE-TRIO with PL is 12.46%.
# At time 0.2440000080152879 ns, the overlap of CORE-TRIO with PL is 12.44%.
# At time 0.24500000804813746 ns, the overlap of CORE-TRIO with PL is 11.84%.
# At time 0.246000008080987 ns, the overlap of CORE-TRIO with PL is 11.03%.
# At time 0.24700000811383654 ns, the overlap of CORE-TRIO with PL is 11.64%.
# At time 0.24800000814668607 ns, the overlap of CORE-TRIO with PL is 11.37%.
# At time 0.24900000817953563 ns, the overlap of CORE-TRIO with PL is 11.44%.
# At time 0.25000000821238516 ns, the overlap of CORE-TRIO with PL is 11.54%.
# At time 0.2510000082452347 ns, the overlap of CORE-TRIO with PL is 11.65%.
# At time 0.2520000082780842 ns, the overlap of CORE-TRIO with PL is 11.91%.
# At time 0.2530000083109338 ns, the overlap of CORE-TRIO with PL is 11.97%.
# At time 0.25400000834378333 ns, the overlap of CORE-TRIO with PL is 12.09%.
# At time 0.2550000083766329 ns, the overlap of CORE-TRIO with PL is 11.61%.
# At time 0.2560000084094824 ns, the overlap of CORE-TRIO with PL is 11.72%.
# At time 0.25700000844233195 ns, the overlap of CORE-TRIO with PL is 11.28%.
# At time 0.25800000847518145 ns, the overlap of CORE-TRIO with PL is 10.71%.
# At time 0.25900000850803107 ns, the overlap of CORE-TRIO with PL is 11.27%.
# At time 0.26000000854088057 ns, the overlap of CORE-TRIO with PL is 11.38%.
# At time 0.2610000085737301 ns, the overlap of CORE-TRIO with PL is 11.76%.
# At time 0.2620000086065796 ns, the overlap of CORE-TRIO with PL is 11.90%.
# At time 0.2630000086394292 ns, the overlap of CORE-TRIO with PL is 11.58%.
# At time 0.26400000867227874 ns, the overlap of CORE-TRIO with PL is 11.53%.
# At time 0.26500000870512824 ns, the overlap of CORE-TRIO with PL is 11.66%.
# At time 0.2660000087379778 ns, the overlap of CORE-TRIO with PL is 11.08%.
# At time 0.26700000877082736 ns, the overlap of CORE-TRIO with PL is 10.05%.
# At time 0.2680000088036769 ns, the overlap of CORE-TRIO with PL is 10.76%.
# At time 0.2690000088365264 ns, the overlap of CORE-TRIO with PL is 11.10%.
# At time 0.270000008869376 ns, the overlap of CORE-TRIO with PL is 11.15%.
# At time 0.2710000089022255 ns, the overlap of CORE-TRIO with PL is 11.23%.
# At time 0.2720000089350751 ns, the overlap of CORE-TRIO with PL is 11.39%.
# At time 0.2730000089679246 ns, the overlap of CORE-TRIO with PL is 12.11%.
# At time 0.27400000900077415 ns, the overlap of CORE-TRIO with PL is 11.75%.
# At time 0.27500000903362365 ns, the overlap of CORE-TRIO with PL is 11.77%.
# At time 0.27600000906647326 ns, the overlap of CORE-TRIO with PL is 11.63%.
# At time 0.27700000909932276 ns, the overlap of CORE-TRIO with PL is 11.57%.
# At time 0.2780000091321723 ns, the overlap of CORE-TRIO with PL is 11.36%.
# At time 0.2790000091650218 ns, the overlap of CORE-TRIO with PL is 11.80%.
# At time 0.2800000091978714 ns, the overlap of CORE-TRIO with PL is 12.00%.
# At time 0.28100000923072094 ns, the overlap of CORE-TRIO with PL is 12.15%.
# At time 0.28200000926357044 ns, the overlap of CORE-TRIO with PL is 11.88%.
# At time 0.28300000929642 ns, the overlap of CORE-TRIO with PL is 11.90%.
# At time 0.2840000093292695 ns, the overlap of CORE-TRIO with PL is 12.05%.
# At time 0.2850000093621191 ns, the overlap of CORE-TRIO with PL is 10.50%.
# At time 0.2860000093949686 ns, the overlap of CORE-TRIO with PL is 11.28%.
# At time 0.28700000942781817 ns, the overlap of CORE-TRIO with PL is 10.37%.
# At time 0.28800000946066767 ns, the overlap of CORE-TRIO with PL is 10.62%.
# At time 0.2890000094935173 ns, the overlap of CORE-TRIO with PL is 10.32%.
# At time 0.2900000095263668 ns, the overlap of CORE-TRIO with PL is 10.18%.
# At time 0.29100000955921634 ns, the overlap of CORE-TRIO with PL is 10.28%.
# At time 0.29200000959206585 ns, the overlap of CORE-TRIO with PL is 10.40%.
# At time 0.29300000962491546 ns, the overlap of CORE-TRIO with PL is 10.39%.
# At time 0.29400000965776496 ns, the overlap of CORE-TRIO with PL is 10.57%.
# At time 0.2950000096906145 ns, the overlap of CORE-TRIO with PL is 10.24%.
# At time 0.296000009723464 ns, the overlap of CORE-TRIO with PL is 9.48%.
# At time 0.2970000097563135 ns, the overlap of CORE-TRIO with PL is 10.18%.
# At time 0.29800000978916313 ns, the overlap of CORE-TRIO with PL is 9.80%.
# At time 0.29900000982201264 ns, the overlap of CORE-TRIO with PL is 9.30%.
# At time 0.3000000098548622 ns, the overlap of CORE-TRIO with PL is 9.49%.
# At time 0.3010000098877117 ns, the overlap of CORE-TRIO with PL is 10.23%.
# At time 0.3020000099205613 ns, the overlap of CORE-TRIO with PL is 9.36%.
# At time 0.3030000099534108 ns, the overlap of CORE-TRIO with PL is 10.58%.
# At time 0.30400000998626037 ns, the overlap of CORE-TRIO with PL is 9.82%.
# At time 0.30500001001910987 ns, the overlap of CORE-TRIO with PL is 10.60%.
# At time 0.3060000100519595 ns, the overlap of CORE-TRIO with PL is 10.17%.
# At time 0.307000010084809 ns, the overlap of CORE-TRIO with PL is 11.45%.
# At time 0.30800001011765854 ns, the overlap of CORE-TRIO with PL is 10.45%.
# At time 0.30900001015050804 ns, the overlap of CORE-TRIO with PL is 10.73%.
# At time 0.3100000101833576 ns, the overlap of CORE-TRIO with PL is 9.73%.
# At time 0.31100001021620716 ns, the overlap of CORE-TRIO with PL is 10.51%.
# At time 0.31200001024905666 ns, the overlap of CORE-TRIO with PL is 10.36%.
# At time 0.3130000102819062 ns, the overlap of CORE-TRIO with PL is 9.61%.
# At time 0.3140000103147557 ns, the overlap of CORE-TRIO with PL is 9.81%.
# At time 0.31500001034760533 ns, the overlap of CORE-TRIO with PL is 10.04%.
# At time 0.31600001038045483 ns, the overlap of CORE-TRIO with PL is 9.81%.
# At time 0.3170000104133044 ns, the overlap of CORE-TRIO with PL is 10.40%.
# At time 0.3180000104461539 ns, the overlap of CORE-TRIO with PL is 10.37%.
# At time 0.3190000104790035 ns, the overlap of CORE-TRIO with PL is 10.12%.
# At time 0.320000010511853 ns, the overlap of CORE-TRIO with PL is 10.77%.
# At time 0.32100001054470256 ns, the overlap of CORE-TRIO with PL is 11.17%.
# At time 0.32200001057755206 ns, the overlap of CORE-TRIO with PL is 11.20%.
# At time 0.3230000106104016 ns, the overlap of CORE-TRIO with PL is 11.63%.
# At time 0.3240000106432512 ns, the overlap of CORE-TRIO with PL is 11.10%.
# At time 0.32500001067610074 ns, the overlap of CORE-TRIO with PL is 11.73%.
# At time 0.32600001070895024 ns, the overlap of CORE-TRIO with PL is 13.16%.
# At time 0.3270000107417998 ns, the overlap of CORE-TRIO with PL is 12.81%.
# At time 0.32800001077464935 ns, the overlap of CORE-TRIO with PL is 12.45%.
# At time 0.32900001080749885 ns, the overlap of CORE-TRIO with PL is 13.04%.
# At time 0.3300000108403484 ns, the overlap of CORE-TRIO with PL is 11.58%.
# At time 0.3310000108731979 ns, the overlap of CORE-TRIO with PL is 13.06%.
# At time 0.3320000109060475 ns, the overlap of CORE-TRIO with PL is 11.66%.
# At time 0.33300001093889703 ns, the overlap of CORE-TRIO with PL is 11.19%.
# At time 0.3340000109717466 ns, the overlap of CORE-TRIO with PL is 11.48%.
# At time 0.3350000110045961 ns, the overlap of CORE-TRIO with PL is 11.34%.
# At time 0.33600001103744565 ns, the overlap of CORE-TRIO with PL is 12.02%.
# At time 0.3370000110702952 ns, the overlap of CORE-TRIO with PL is 11.58%.
# At time 0.33800001110314476 ns, the overlap of CORE-TRIO with PL is 11.10%.
# At time 0.33900001113599426 ns, the overlap of CORE-TRIO with PL is 10.05%.
# At time 0.3400000111688438 ns, the overlap of CORE-TRIO with PL is 9.93%.
# At time 0.3410000112016934 ns, the overlap of CORE-TRIO with PL is 10.87%.
# At time 0.34200001123454293 ns, the overlap of CORE-TRIO with PL is 10.84%.
# At time 0.34300001126739244 ns, the overlap of CORE-TRIO with PL is 10.72%.
# At time 0.344000011300242 ns, the overlap of CORE-TRIO with PL is 11.36%.
# At time 0.34500001133309155 ns, the overlap of CORE-TRIO with PL is 11.65%.
# At time 0.34600001136594105 ns, the overlap of CORE-TRIO with PL is 11.66%.
# At time 0.3470000113987906 ns, the overlap of CORE-TRIO with PL is 11.53%.
# At time 0.3480000114316401 ns, the overlap of CORE-TRIO with PL is 11.86%.
# At time 0.34900001146448967 ns, the overlap of CORE-TRIO with PL is 11.61%.
# At time 0.3500000114973392 ns, the overlap of CORE-TRIO with PL is 11.62%.
# At time 0.3510000115301888 ns, the overlap of CORE-TRIO with PL is 10.77%.
# At time 0.3520000115630383 ns, the overlap of CORE-TRIO with PL is 10.66%.
# At time 0.35300001159588784 ns, the overlap of CORE-TRIO with PL is 11.21%.
# At time 0.3540000116287374 ns, the overlap of CORE-TRIO with PL is 11.23%.
# At time 0.35500001166158696 ns, the overlap of CORE-TRIO with PL is 11.76%.
# At time 0.35600001169443646 ns, the overlap of CORE-TRIO with PL is 11.32%.
# At time 0.357000011727286 ns, the overlap of CORE-TRIO with PL is 11.97%.
# At time 0.3580000117601356 ns, the overlap of CORE-TRIO with PL is 11.09%.
# At time 0.35900001179298513 ns, the overlap of CORE-TRIO with PL is 12.74%.
# At time 0.36000001182583463 ns, the overlap of CORE-TRIO with PL is 12.48%.
# At time 0.36100001185868413 ns, the overlap of CORE-TRIO with PL is 11.36%.
# At time 0.3620000118915337 ns, the overlap of CORE-TRIO with PL is 11.42%.
# At time 0.36300001192438325 ns, the overlap of CORE-TRIO with PL is 10.59%.
# At time 0.3640000119572328 ns, the overlap of CORE-TRIO with PL is 10.89%.
# At time 0.3650000119900823 ns, the overlap of CORE-TRIO with PL is 11.67%.
# At time 0.36600001202293186 ns, the overlap of CORE-TRIO with PL is 11.43%.
# At time 0.3670000120557814 ns, the overlap of CORE-TRIO with PL is 11.52%.
# At time 0.368000012088631 ns, the overlap of CORE-TRIO with PL is 10.65%.
# At time 0.3690000121214805 ns, the overlap of CORE-TRIO with PL is 9.91%.
# At time 0.37000001215433004 ns, the overlap of CORE-TRIO with PL is 11.18%.
# At time 0.3710000121871796 ns, the overlap of CORE-TRIO with PL is 11.21%.
# At time 0.37200001222002915 ns, the overlap of CORE-TRIO with PL is 11.70%.
# At time 0.37300001225287865 ns, the overlap of CORE-TRIO with PL is 10.94%.
# At time 0.3740000122857282 ns, the overlap of CORE-TRIO with PL is 10.75%.
# At time 0.3750000123185777 ns, the overlap of CORE-TRIO with PL is 11.34%.
# At time 0.3760000123514273 ns, the overlap of CORE-TRIO with PL is 10.00%.
# At time 0.37700001238427683 ns, the overlap of CORE-TRIO with PL is 10.63%.
# At time 0.37800001241712633 ns, the overlap of CORE-TRIO with PL is 10.87%.
# At time 0.3790000124499759 ns, the overlap of CORE-TRIO with PL is 11.30%.
# At time 0.38000001248282544 ns, the overlap of CORE-TRIO with PL is 10.90%.
# At time 0.381000012515675 ns, the overlap of CORE-TRIO with PL is 11.10%.
# At time 0.3820000125485245 ns, the overlap of CORE-TRIO with PL is 11.24%.
# At time 0.38300001258137406 ns, the overlap of CORE-TRIO with PL is 10.81%.
# At time 0.38400001261422356 ns, the overlap of CORE-TRIO with PL is 12.26%.
# At time 0.3850000126470732 ns, the overlap of CORE-TRIO with PL is 11.24%.
# At time 0.3860000126799227 ns, the overlap of CORE-TRIO with PL is 11.40%.
# At time 0.38700001271277223 ns, the overlap of CORE-TRIO with PL is 10.40%.
# At time 0.38800001274562174 ns, the overlap of CORE-TRIO with PL is 11.03%.
# At time 0.38900001277847135 ns, the overlap of CORE-TRIO with PL is 11.95%.
# At time 0.39000001281132085 ns, the overlap of CORE-TRIO with PL is 11.83%.
# At time 0.3910000128441704 ns, the overlap of CORE-TRIO with PL is 10.59%.
# At time 0.3920000128770199 ns, the overlap of CORE-TRIO with PL is 10.70%.
# At time 0.3930000129098695 ns, the overlap of CORE-TRIO with PL is 11.02%.
# At time 0.394000012942719 ns, the overlap of CORE-TRIO with PL is 11.39%.
# At time 0.3950000129755685 ns, the overlap of CORE-TRIO with PL is 11.04%.
# At time 0.3960000130084181 ns, the overlap of CORE-TRIO with PL is 11.64%.
# At time 0.3970000130412676 ns, the overlap of CORE-TRIO with PL is 11.94%.
# At time 0.3980000130741172 ns, the overlap of CORE-TRIO with PL is 11.01%.
# At time 0.3990000131069667 ns, the overlap of CORE-TRIO with PL is 11.69%.
# At time 0.40000001313981626 ns, the overlap of CORE-TRIO with PL is 11.66%.
# At time 0.40100001317266576 ns, the overlap of CORE-TRIO with PL is 11.52%.
# At time 0.40200001320551537 ns, the overlap of CORE-TRIO with PL is 11.15%.
# At time 0.4030000132383649 ns, the overlap of CORE-TRIO with PL is 12.51%.
# At time 0.40400001327121443 ns, the overlap of CORE-TRIO with PL is 11.45%.
# At time 0.40500001330406393 ns, the overlap of CORE-TRIO with PL is 11.58%.
# At time 0.40600001333691355 ns, the overlap of CORE-TRIO with PL is 11.32%.
# At time 0.40700001336976305 ns, the overlap of CORE-TRIO with PL is 12.26%.
# At time 0.4080000134026126 ns, the overlap of CORE-TRIO with PL is 12.75%.
# At time 0.4090000134354621 ns, the overlap of CORE-TRIO with PL is 11.63%.
# At time 0.4100000134683116 ns, the overlap of CORE-TRIO with PL is 10.80%.
# At time 0.4110000135011612 ns, the overlap of CORE-TRIO with PL is 11.43%.
# At time 0.4120000135340107 ns, the overlap of CORE-TRIO with PL is 11.17%.
# At time 0.4130000135668603 ns, the overlap of CORE-TRIO with PL is 11.60%.
# At time 0.4140000135997098 ns, the overlap of CORE-TRIO with PL is 12.54%.
# At time 0.4150000136325594 ns, the overlap of CORE-TRIO with PL is 13.42%.
# At time 0.4160000136654089 ns, the overlap of CORE-TRIO with PL is 12.51%.
# At time 0.41700001369825845 ns, the overlap of CORE-TRIO with PL is 13.01%.
# At time 0.41800001373110796 ns, the overlap of CORE-TRIO with PL is 11.78%.
# At time 0.41900001376395757 ns, the overlap of CORE-TRIO with PL is 11.87%.
# At time 0.42000001379680707 ns, the overlap of CORE-TRIO with PL is 12.07%.
# At time 0.4210000138296566 ns, the overlap of CORE-TRIO with PL is 11.03%.
# At time 0.42200001386250613 ns, the overlap of CORE-TRIO with PL is 11.97%.
# At time 0.4230000138953557 ns, the overlap of CORE-TRIO with PL is 12.37%.
# At time 0.42400001392820524 ns, the overlap of CORE-TRIO with PL is 11.36%.
# At time 0.4250000139610548 ns, the overlap of CORE-TRIO with PL is 11.22%.
# At time 0.4260000139939043 ns, the overlap of CORE-TRIO with PL is 11.15%.
# At time 0.4270000140267538 ns, the overlap of CORE-TRIO with PL is 10.92%.
# At time 0.4280000140596034 ns, the overlap of CORE-TRIO with PL is 11.17%.
# At time 0.4290000140924529 ns, the overlap of CORE-TRIO with PL is 11.39%.
# At time 0.4300000141253025 ns, the overlap of CORE-TRIO with PL is 11.57%.
# At time 0.431000014158152 ns, the overlap of CORE-TRIO with PL is 11.83%.
# At time 0.4320000141910016 ns, the overlap of CORE-TRIO with PL is 11.37%.
# At time 0.4330000142238511 ns, the overlap of CORE-TRIO with PL is 10.97%.
# At time 0.43400001425670065 ns, the overlap of CORE-TRIO with PL is 11.60%.
# At time 0.43500001428955015 ns, the overlap of CORE-TRIO with PL is 10.73%.
# At time 0.4360000143223997 ns, the overlap of CORE-TRIO with PL is 11.14%.
# At time 0.43700001435524927 ns, the overlap of CORE-TRIO with PL is 11.86%.
# At time 0.4380000143880988 ns, the overlap of CORE-TRIO with PL is 11.75%.
# At time 0.4390000144209483 ns, the overlap of CORE-TRIO with PL is 11.94%.
# At time 0.4400000144537979 ns, the overlap of CORE-TRIO with PL is 11.89%.
# At time 0.44100001448664744 ns, the overlap of CORE-TRIO with PL is 11.50%.
# At time 0.442000014519497 ns, the overlap of CORE-TRIO with PL is 10.88%.
# At time 0.4430000145523465 ns, the overlap of CORE-TRIO with PL is 11.66%.
# At time 0.444000014585196 ns, the overlap of CORE-TRIO with PL is 10.87%.
# At time 0.4450000146180456 ns, the overlap of CORE-TRIO with PL is 11.21%.
# At time 0.4460000146508951 ns, the overlap of CORE-TRIO with PL is 11.35%.
# At time 0.4470000146837447 ns, the overlap of CORE-TRIO with PL is 12.11%.
# At time 0.4480000147165942 ns, the overlap of CORE-TRIO with PL is 11.97%.
# At time 0.44900001474944373 ns, the overlap of CORE-TRIO with PL is 11.31%.
# At time 0.4500000147822933 ns, the overlap of CORE-TRIO with PL is 11.78%.
# At time 0.45100001481514285 ns, the overlap of CORE-TRIO with PL is 12.37%.
# At time 0.45200001484799235 ns, the overlap of CORE-TRIO with PL is 11.98%.
# ...
# At time 0.111000003646299 ns, the overlap of CORE-TRIO with PL is 15.15%.
# At time 0.11200000367914854 ns, the overlap of CORE-TRIO with PL is 14.82%.
# At time 0.11300000371199809 ns, the overlap of CORE-TRIO with PL is 14.93%.
# At time 0.11400000374484763 ns, the overlap of CORE-TRIO with PL is 15.03%.
# At time 0.11500000377769717 ns, the overlap of CORE-TRIO with PL is 14.51%.
# At time 0.11600000381054672 ns, the overlap of CORE-TRIO with PL is 14.62%.
# At time 0.11700000384339626 ns, the overlap of CORE-TRIO with PL is 14.87%.
# At time 0.1180000038762458 ns, the overlap of CORE-TRIO with PL is 15.17%.
# At time 0.11900000390909535 ns, the overlap of CORE-TRIO with PL is 15.10%.
# At time 0.12000000394194488 ns, the overlap of CORE-TRIO with PL is 15.06%.
# At time 0.12100000397479442 ns, the overlap of CORE-TRIO with PL is 14.42%.
# At time 0.12200000400764395 ns, the overlap of CORE-TRIO with PL is 13.91%.
# At time 0.1230000040404935 ns, the overlap of CORE-TRIO with PL is 13.84%.
# At time 0.12400000407334304 ns, the overlap of CORE-TRIO with PL is 14.05%.
# At time 0.12500000410619258 ns, the overlap of CORE-TRIO with PL is 14.17%.
# At time 0.1260000041390421 ns, the overlap of CORE-TRIO with PL is 13.52%.
# At time 0.12700000417189167 ns, the overlap of CORE-TRIO with PL is 13.72%.
# At time 0.1280000042047412 ns, the overlap of CORE-TRIO with PL is 13.66%.
# At time 0.12900000423759073 ns, the overlap of CORE-TRIO with PL is 13.97%.
# At time 0.13000000427044028 ns, the overlap of CORE-TRIO with PL is 14.20%.
# At time 0.1310000043032898 ns, the overlap of CORE-TRIO with PL is 13.76%.
# At time 0.13200000433613937 ns, the overlap of CORE-TRIO with PL is 13.80%.
# At time 0.1330000043689889 ns, the overlap of CORE-TRIO with PL is 13.76%.
# At time 0.13400000440183846 ns, the overlap of CORE-TRIO with PL is 14.15%.
# At time 0.135000004434688 ns, the overlap of CORE-TRIO with PL is 13.66%.
# At time 0.13600000446753754 ns, the overlap of CORE-TRIO with PL is 14.28%.
# At time 0.13700000450038707 ns, the overlap of CORE-TRIO with PL is 13.77%.
# At time 0.13800000453323663 ns, the overlap of CORE-TRIO with PL is 13.27%.
# At time 0.13900000456608616 ns, the overlap of CORE-TRIO with PL is 13.33%.
# At time 0.1400000045989357 ns, the overlap of CORE-TRIO with PL is 13.49%.
# At time 0.14100000463178522 ns, the overlap of CORE-TRIO with PL is 13.80%.
# At time 0.14200000466463475 ns, the overlap of CORE-TRIO with PL is 13.82%.
# At time 0.1430000046974843 ns, the overlap of CORE-TRIO with PL is 13.13%.
# At time 0.14400000473033384 ns, the overlap of CORE-TRIO with PL is 13.32%.
# At time 0.1450000047631834 ns, the overlap of CORE-TRIO with PL is 13.21%.
# At time 0.14600000479603292 ns, the overlap of CORE-TRIO with PL is 13.87%.
# At time 0.14700000482888248 ns, the overlap of CORE-TRIO with PL is 13.58%.
# At time 0.148000004861732 ns, the overlap of CORE-TRIO with PL is 13.00%.
# At time 0.14900000489458157 ns, the overlap of CORE-TRIO with PL is 13.17%.
# At time 0.1500000049274311 ns, the overlap of CORE-TRIO with PL is 13.41%.
# At time 0.15100000496028065 ns, the overlap of CORE-TRIO with PL is 12.94%.
# At time 0.15200000499313018 ns, the overlap of CORE-TRIO with PL is 14.01%.
# At time 0.15300000502597974 ns, the overlap of CORE-TRIO with PL is 13.65%.
# At time 0.15400000505882927 ns, the overlap of CORE-TRIO with PL is 13.53%.
# At time 0.1550000050916788 ns, the overlap of CORE-TRIO with PL is 13.43%.
# At time 0.15600000512452833 ns, the overlap of CORE-TRIO with PL is 13.64%.
# At time 0.15700000515737786 ns, the overlap of CORE-TRIO with PL is 14.31%.
# At time 0.15800000519022742 ns, the overlap of CORE-TRIO with PL is 14.01%.
# At time 0.15900000522307695 ns, the overlap of CORE-TRIO with PL is 13.65%.
# At time 0.1600000052559265 ns, the overlap of CORE-TRIO with PL is 13.12%.
# At time 0.16100000528877603 ns, the overlap of CORE-TRIO with PL is 13.73%.
# At time 0.1620000053216256 ns, the overlap of CORE-TRIO with PL is 13.34%.
# At time 0.16300000535447512 ns, the overlap of CORE-TRIO with PL is 13.04%.
# At time 0.16400000538732468 ns, the overlap of CORE-TRIO with PL is 12.97%.
# At time 0.1650000054201742 ns, the overlap of CORE-TRIO with PL is 12.80%.
# At time 0.16600000545302376 ns, the overlap of CORE-TRIO with PL is 12.88%.
# At time 0.1670000054858733 ns, the overlap of CORE-TRIO with PL is 12.79%.
# At time 0.16800000551872282 ns, the overlap of CORE-TRIO with PL is 11.83%.
# At time 0.16900000555157238 ns, the overlap of CORE-TRIO with PL is 12.30%.
# At time 0.1700000055844219 ns, the overlap of CORE-TRIO with PL is 12.05%.
# At time 0.17100000561727147 ns, the overlap of CORE-TRIO with PL is 12.32%.
# At time 0.172000005650121 ns, the overlap of CORE-TRIO with PL is 12.40%.
# At time 0.17300000568297053 ns, the overlap of CORE-TRIO with PL is 12.35%.
# At time 0.17400000571582006 ns, the overlap of CORE-TRIO with PL is 13.12%.
# At time 0.1750000057486696 ns, the overlap of CORE-TRIO with PL is 13.05%.
# At time 0.17600000578151914 ns, the overlap of CORE-TRIO with PL is 12.55%.
# At time 0.1770000058143687 ns, the overlap of CORE-TRIO with PL is 13.15%.
# At time 0.17800000584721823 ns, the overlap of CORE-TRIO with PL is 12.86%.
# At time 0.1790000058800678 ns, the overlap of CORE-TRIO with PL is 13.09%.
# At time 0.18000000591291732 ns, the overlap of CORE-TRIO with PL is 12.97%.
# At time 0.18100000594576685 ns, the overlap of CORE-TRIO with PL is 12.97%.
# At time 0.1820000059786164 ns, the overlap of CORE-TRIO with PL is 12.73%.
# At time 0.18300000601146593 ns, the overlap of CORE-TRIO with PL is 13.06%.
# At time 0.1840000060443155 ns, the overlap of CORE-TRIO with PL is 13.53%.
# At time 0.18500000607716502 ns, the overlap of CORE-TRIO with PL is 13.73%.
# At time 0.18600000611001458 ns, the overlap of CORE-TRIO with PL is 13.71%.
# At time 0.1870000061428641 ns, the overlap of CORE-TRIO with PL is 13.46%.
# At time 0.18800000617571366 ns, the overlap of CORE-TRIO with PL is 13.57%.
# At time 0.18900000620856316 ns, the overlap of CORE-TRIO with PL is 13.21%.
# At time 0.19000000624141272 ns, the overlap of CORE-TRIO with PL is 13.16%.
# At time 0.19100000627426225 ns, the overlap of CORE-TRIO with PL is 13.20%.
# At time 0.19200000630711178 ns, the overlap of CORE-TRIO with PL is 12.66%.
# At time 0.19300000633996134 ns, the overlap of CORE-TRIO with PL is 12.67%.
# At time 0.19400000637281087 ns, the overlap of CORE-TRIO with PL is 12.63%.
# At time 0.19500000640566043 ns, the overlap of CORE-TRIO with PL is 13.72%.
# At time 0.19600000643850995 ns, the overlap of CORE-TRIO with PL is 14.17%.
# At time 0.1970000064713595 ns, the overlap of CORE-TRIO with PL is 14.30%.
# At time 0.19800000650420904 ns, the overlap of CORE-TRIO with PL is 14.19%.
# At time 0.1990000065370586 ns, the overlap of CORE-TRIO with PL is 13.32%.
# At time 0.20000000656990813 ns, the overlap of CORE-TRIO with PL is 13.24%.
# At time 0.20100000660275769 ns, the overlap of CORE-TRIO with PL is 14.36%.
# At time 0.20200000663560722 ns, the overlap of CORE-TRIO with PL is 13.74%.
# At time 0.20300000666845677 ns, the overlap of CORE-TRIO with PL is 13.75%.
# At time 0.2040000067013063 ns, the overlap of CORE-TRIO with PL is 12.96%.
# At time 0.2050000067341558 ns, the overlap of CORE-TRIO with PL is 12.80%.
# At time 0.20600000676700536 ns, the overlap of CORE-TRIO with PL is 12.97%.
# At time 0.2070000067998549 ns, the overlap of CORE-TRIO with PL is 12.55%.
# At time 0.20800000683270445 ns, the overlap of CORE-TRIO with PL is 12.10%.
# At time 0.20900000686555398 ns, the overlap of CORE-TRIO with PL is 12.46%.
# At time 0.21000000689840354 ns, the overlap of CORE-TRIO with PL is 12.45%.
# At time 0.21100000693125306 ns, the overlap of CORE-TRIO with PL is 12.90%.
# At time 0.21200000696410262 ns, the overlap of CORE-TRIO with PL is 11.96%.
# At time 0.21300000699695215 ns, the overlap of CORE-TRIO with PL is 12.77%.
# At time 0.2140000070298017 ns, the overlap of CORE-TRIO with PL is 12.61%.
# At time 0.21500000706265124 ns, the overlap of CORE-TRIO with PL is 12.56%.
# At time 0.2160000070955008 ns, the overlap of CORE-TRIO with PL is 12.10%.
# At time 0.21700000712835033 ns, the overlap of CORE-TRIO with PL is 12.60%.
# At time 0.21800000716119985 ns, the overlap of CORE-TRIO with PL is 12.76%.
# At time 0.2190000071940494 ns, the overlap of CORE-TRIO with PL is 11.86%.
# At time 0.22000000722689894 ns, the overlap of CORE-TRIO with PL is 12.90%.
# At time 0.0 ns, the overlap of CORE-TRIO with PL is 11.13%.
# At time 0.0010000000328495406 ns, the overlap of CORE-TRIO with PL is 11.29%.
# At time 0.002000000065699081 ns, the overlap of CORE-TRIO with PL is 10.92%.
# At time 0.0030000000985486216 ns, the overlap of CORE-TRIO with PL is 10.56%.
# At time 0.004000000131398162 ns, the overlap of CORE-TRIO with PL is 10.77%.
# At time 0.005000000164247703 ns, the overlap of CORE-TRIO with PL is 10.19%.
# At time 0.006000000197097243 ns, the overlap of CORE-TRIO with PL is 10.90%.
# At time 0.007000000229946784 ns, the overlap of CORE-TRIO with PL is 10.09%.
# At time 0.008000000262796325 ns, the overlap of CORE-TRIO with PL is 11.01%.
# At time 0.009000000295645865 ns, the overlap of CORE-TRIO with PL is 11.08%.
# At time 0.010000000328495406 ns, the overlap of CORE-TRIO with PL is 11.69%.
# At time 0.011000000361344946 ns, the overlap of CORE-TRIO with PL is 11.52%.
# At time 0.012000000394194486 ns, the overlap of CORE-TRIO with PL is 11.56%.
# At time 0.013000000427044028 ns, the overlap of CORE-TRIO with PL is 11.91%.
# At time 0.014000000459893568 ns, the overlap of CORE-TRIO with PL is 11.38%.
# At time 0.01500000049274311 ns, the overlap of CORE-TRIO with PL is 12.37%.
# At time 0.01600000052559265 ns, the overlap of CORE-TRIO with PL is 12.60%.
# At time 0.017000000558442193 ns, the overlap of CORE-TRIO with PL is 12.41%.
# At time 0.01800000059129173 ns, the overlap of CORE-TRIO with PL is 11.67%.
# At time 0.019000000624141273 ns, the overlap of CORE-TRIO with PL is 12.85%.
# At time 0.020000000656990813 ns, the overlap of CORE-TRIO with PL is 12.34%.
# At time 0.021000000689840353 ns, the overlap of CORE-TRIO with PL is 11.52%.
# At time 0.022000000722689893 ns, the overlap of CORE-TRIO with PL is 11.05%.
# At time 0.023000000755539436 ns, the overlap of CORE-TRIO with PL is 10.41%.
# At time 0.024000000788388973 ns, the overlap of CORE-TRIO with PL is 11.18%.
# At time 0.025000000821238516 ns, the overlap of CORE-TRIO with PL is 10.81%.
# At time 0.026000000854088056 ns, the overlap of CORE-TRIO with PL is 10.94%.
# At time 0.0270000008869376 ns, the overlap of CORE-TRIO with PL is 11.48%.
# At time 0.028000000919787136 ns, the overlap of CORE-TRIO with PL is 11.10%.
# At time 0.02900000095263668 ns, the overlap of CORE-TRIO with PL is 11.84%.
# At time 0.03000000098548622 ns, the overlap of CORE-TRIO with PL is 11.51%.
# At time 0.03100000101833576 ns, the overlap of CORE-TRIO with PL is 11.05%.
# At time 0.0320000010511853 ns, the overlap of CORE-TRIO with PL is 11.90%.
# At time 0.03300000108403484 ns, the overlap of CORE-TRIO with PL is 12.07%.
# At time 0.034000001116884386 ns, the overlap of CORE-TRIO with PL is 12.22%.
# At time 0.03500000114973392 ns, the overlap of CORE-TRIO with PL is 12.60%.
# At time 0.03600000118258346 ns, the overlap of CORE-TRIO with PL is 12.90%.
# At time 0.037000001215433 ns, the overlap of CORE-TRIO with PL is 13.02%.
# At time 0.038000001248282546 ns, the overlap of CORE-TRIO with PL is 12.86%.
# At time 0.03900000128113208 ns, the overlap of CORE-TRIO with PL is 12.11%.
# At time 0.040000001313981626 ns, the overlap of CORE-TRIO with PL is 11.39%.
# At time 0.04100000134683117 ns, the overlap of CORE-TRIO with PL is 12.16%.
# At time 0.042000001379680706 ns, the overlap of CORE-TRIO with PL is 11.62%.
# At time 0.04300000141253025 ns, the overlap of CORE-TRIO with PL is 11.68%.
# At time 0.044000001445379786 ns, the overlap of CORE-TRIO with PL is 12.17%.
# At time 0.04500000147822933 ns, the overlap of CORE-TRIO with PL is 11.68%.
# At time 0.04600000151107887 ns, the overlap of CORE-TRIO with PL is 12.48%.
# At time 0.047000001543928416 ns, the overlap of CORE-TRIO with PL is 12.30%.
# At time 0.048000001576777945 ns, the overlap of CORE-TRIO with PL is 12.24%.
# At time 0.04900000160962749 ns, the overlap of CORE-TRIO with PL is 12.14%.
# At time 0.05000000164247703 ns, the overlap of CORE-TRIO with PL is 11.86%.
# At time 0.051000001675326576 ns, the overlap of CORE-TRIO with PL is 12.57%.
# At time 0.05200000170817611 ns, the overlap of CORE-TRIO with PL is 12.20%.
# At time 0.053000001741025655 ns, the overlap of CORE-TRIO with PL is 12.80%.
# At time 0.0540000017738752 ns, the overlap of CORE-TRIO with PL is 12.17%.
# At time 0.055000001806724735 ns, the overlap of CORE-TRIO with PL is 11.71%.
# At time 0.05600000183957427 ns, the overlap of CORE-TRIO with PL is 11.92%.
# At time 0.057000001872423815 ns, the overlap of CORE-TRIO with PL is 11.51%.
# At time 0.05800000190527336 ns, the overlap of CORE-TRIO with PL is 10.85%.
# At time 0.0590000019381229 ns, the overlap of CORE-TRIO with PL is 11.38%.
# At time 0.06000000197097244 ns, the overlap of CORE-TRIO with PL is 10.83%.
# At time 0.061000002003821975 ns, the overlap of CORE-TRIO with PL is 10.84%.
# At time 0.06200000203667152 ns, the overlap of CORE-TRIO with PL is 10.79%.
# At time 0.06300000206952105 ns, the overlap of CORE-TRIO with PL is 11.57%.
# At time 0.0640000021023706 ns, the overlap of CORE-TRIO with PL is 11.02%.
# At time 0.06500000213522014 ns, the overlap of CORE-TRIO with PL is 11.03%.
# At time 0.06600000216806969 ns, the overlap of CORE-TRIO with PL is 9.92%.
# At time 0.06700000220091923 ns, the overlap of CORE-TRIO with PL is 10.70%.
# At time 0.06800000223376877 ns, the overlap of CORE-TRIO with PL is 10.80%.
# At time 0.06900000226661832 ns, the overlap of CORE-TRIO with PL is 11.16%.
# At time 0.07000000229946785 ns, the overlap of CORE-TRIO with PL is 11.37%.
# At time 0.07100000233231737 ns, the overlap of CORE-TRIO with PL is 10.94%.
# At time 0.07200000236516692 ns, the overlap of CORE-TRIO with PL is 11.50%.
# At time 0.07300000239801646 ns, the overlap of CORE-TRIO with PL is 11.10%.
# At time 0.074000002430866 ns, the overlap of CORE-TRIO with PL is 11.49%.
# At time 0.07500000246371555 ns, the overlap of CORE-TRIO with PL is 10.81%.
# At time 0.07600000249656509 ns, the overlap of CORE-TRIO with PL is 11.83%.
# At time 0.07700000252941464 ns, the overlap of CORE-TRIO with PL is 11.55%.
# At time 0.07800000256226416 ns, the overlap of CORE-TRIO with PL is 11.49%.
# At time 0.07900000259511371 ns, the overlap of CORE-TRIO with PL is 11.68%.
# At time 0.08000000262796325 ns, the overlap of CORE-TRIO with PL is 11.34%.
# At time 0.0810000026608128 ns, the overlap of CORE-TRIO with PL is 10.67%.
# At time 0.08200000269366234 ns, the overlap of CORE-TRIO with PL is 10.91%.
# At time 0.08300000272651188 ns, the overlap of CORE-TRIO with PL is 10.85%.
# At time 0.08400000275936141 ns, the overlap of CORE-TRIO with PL is 11.47%.
# At time 0.08500000279221095 ns, the overlap of CORE-TRIO with PL is 11.48%.
# At time 0.0860000028250605 ns, the overlap of CORE-TRIO with PL is 11.32%.
# At time 0.08700000285791003 ns, the overlap of CORE-TRIO with PL is 11.47%.
# At time 0.08800000289075957 ns, the overlap of CORE-TRIO with PL is 12.17%.
# At time 0.08900000292360911 ns, the overlap of CORE-TRIO with PL is 10.92%.
# At time 0.09000000295645866 ns, the overlap of CORE-TRIO with PL is 10.98%.
# At time 0.0910000029893082 ns, the overlap of CORE-TRIO with PL is 11.42%.
# At time 0.09200000302215774 ns, the overlap of CORE-TRIO with PL is 10.74%.
# At time 0.09300000305500729 ns, the overlap of CORE-TRIO with PL is 11.55%.
# At time 0.09400000308785683 ns, the overlap of CORE-TRIO with PL is 10.97%.
# At time 0.09500000312070636 ns, the overlap of CORE-TRIO with PL is 11.50%.
# At time 0.09600000315355589 ns, the overlap of CORE-TRIO with PL is 11.87%.
# At time 0.09700000318640543 ns, the overlap of CORE-TRIO with PL is 11.93%.
# At time 0.09800000321925498 ns, the overlap of CORE-TRIO with PL is 11.92%.
# At time 0.09900000325210452 ns, the overlap of CORE-TRIO with PL is 11.94%.

# %%
def plot_overlap_evolution(times, overlap_evolution):
    plt.rc('font', size=12, weight='bold')
    plt.rc('axes', titlesize=14, labelsize=12, titleweight='bold')
    plt.rc('legend', fontsize=10)

    # Create the plot
    plt.figure(figsize=(5, 3))
    plt.plot(times, overlap_evolution, marker='o', markersize=3, linewidth=2.5, label='Overlap Evolution')
    plt.title('Overlap Percentage Over Time')
    plt.xlabel('Time (ns)')
    plt.ylabel('Overlap Percentage (%)')
    plt.ylim(0, 20)
    plt.grid(True)
    plt.show()

# %%
plot_overlap_evolution(times1, overlap_evolution1)
plot_overlap_evolution(times2, overlap_evolution2)
plot_overlap_evolution(times3, overlap_evolution3)
plot_overlap_evolution(times4, overlap_evolution4)
plot_overlap_evolution(times5, overlap_evolution5)
plot_overlap_evolution(times6, overlap_evolution6)

# %%
percent_overlap(results_drude, 'PL', 'SURF-TRIO')
# Out:
# The overlap of SURF-TRIO with PL represents 1.18% of the total PL area.
# 1.1805354907013377

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_ov(results, type_1_name, type_2_name):
    # Retrieve density data from the results
    type_1 = results['density'][type_1_name]
    type_2 = results['density'][type_2_name]
    z = type_1[:, 0]  # Adjust the 'end' and 'num' based on your data specifics

    # Set font properties globally
    plt.rc('font', size=12, weight='bold')  # Increase font size and weight
    plt.rc('axes', titlesize=14, labelsize=12, titleweight='bold')
    plt.rc('legend', fontsize=10)

    # Create the plot
    plt.figure(figsize=(5, 2))  # Larger figure for more space around legend
    plt.plot(z, type_1[:, 1], label=f'{type_1_name} Density', color='blue', linewidth=3.5)
    plt.plot(z, type_2[:, 1], label=f'{type_2_name} Density', color='red', linewidth=3.5)
    plt.fill_between(z, 0, np.minimum(type_1[:, 1], type_2[:, 1]), color='purple', alpha=0.8, label='Overlap Region')
    plt.title('Density Distribution with Overlap (C36)')
    plt.xlabel('Depth (z)')
    plt.ylabel('Density')

    # Position legend outside of the plot
#     plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
#     plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust the plot to fit the legend
    plt.grid(True)
    plt.show()

# %%
plot_ov(results_c36, 'PL', 'CORE-TRIO')
plot_ov(results_c36c, 'PL', 'CORE-TRIO')
plot_ov(results_drude, 'PL', 'CORE-TRIO')
plot_ov(results_3mn, 'PL', 'CORE-TRIO')
plot_ov(results_5mn, 'PL', 'CORE-TRIO')
plot_ov(results_early, 'PL', 'CORE-TRIO')

# %%
# z = np.linspace(0, 100, num=len(pl_density[:, 1]))
z = pl_density[:,0] 
area_under_curve = np.trapz(pl_density[:, 1], x=z)

# %%
# Minimum of PL and TG densities at each point along the z-axis
overlap_density = np.minimum(pl_density[:, 1], surf_density[:, 1])
overlap_area = np.trapz(overlap_density, x=z)
total_pl_area = np.trapz(pl_density[:, 1], x=z)
overlap_percentage = (overlap_area / total_pl_area) * 100
print(f"The overlap of TG with PL represents {overlap_percentage:.2f}% of the total PL area.")
# Out:
# The overlap of TG with PL represents 8.38% of the total PL area.
