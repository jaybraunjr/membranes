# %%
import MDAnalysis as mda
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import sys

# %%
base_dir = os.path.abspath(os.path.join('..', 'membrane'))
sys.path.append(base_dir)

# %%
from analysis import InterdigitationAnalysis,  Membrane_overlap_distance, MicAnalysis, OverlapAnalysis

# %%
def loader(topology_path, trajectory_path):
    u = mda.Universe(topology_path, trajectory_path)
    return u

# %%
u1 = loader('../../trajs/gro.gro', '../../trajs/c36.xtc')
u2 = loader('../../trajs/gro.gro', '../../trajs/v_eq.xtc')
u3 = loader('../../trajs/ld.psf', '../../trajs/drude_skip100.dcd')
u4 = loader('../../trajs/ld.psf', '../../trajs/eq.dcd')
u5 = loader('../../trajs/ld.psf', '../../trajs/st3.dcd')
# u6 = loader('../../trajs/ld.psf', '../../trajs/st5.dcd')
# u7 = loader('../../trajs/ld.psf', '../../trajs/20mn.dcd')

# %% [markdown]
# First we calculate the average distance that the TG tails intercalate with the PL monolayer

# %%
def manager(u, start_frame=0, end_frame=None, method='all',
            atom_name='C316', lipid_1='POPC', lipid_2='DOPE', 
            lipid_3='SAPI', neutral_lipid='TRIO'):
    
    instance = Membrane_overlap_distance(u, start_frame, end_frame)
    instance.setup_groups(atom_name, lipid_1, lipid_2, lipid_3, neutral_lipid)
    results = instance.analyze_trajectory(method)
    df = instance.analysis_to_df(results)
    
    analysis = OverlapAnalysis(df, method='all')
    analysis.print_analysis()
    overlap_overtime = analysis.calculate_average_overlap_depth()
    overlap_average = analysis.calculate_average_depth_overall()
    overlap_number = analysis.calculate_number_of_overlaps_per_frame()

    return df, overlap_overtime, overlap_number

# %%
# Define a function that calls manager with appropriate arguments
def load_dataset(universe, start_frame=0, end_frame=None):
    return manager(
        universe, start_frame=start_frame, end_frame=end_frame, method='all',
        atom_name='C316', lipid_1='POPC', lipid_2='DOPE',
        lipid_3='SAPI', neutral_lipid='TRIO'
    )

# Now, load all datasets using the function
df_c36, time_c36, number_c36 = load_dataset(u1)
df_c36c, time_c36c, number_c36c = load_dataset(u2)
df_drude, time_drude, number_drude = load_dataset(u3)
df_eq, time_eq, number_eq = load_dataset(u4)
df_3mn, time_3mn, number_3mn = load_dataset(u5)
# df_5mn, time_5mn, number_5mn = load_dataset(u6)
# df_20mn, time_20mn, number_20mn = load_dataset(u7)
# Out:
# Overall Average Overlap Depth: 4.2597275
# Overall Average Overlap Depth: 4.219953
# Overall Average Overlap Depth: 3.88166
# Overall Average Overlap Depth: 3.667035
# Overall Average Overlap Depth: 4.3440194

# %%
def plot_overlap(df, title="Average Overlap Depth over Time", x_label="Time (ns)", y_label="Average Overlap Depth (Å)", ylim=(1, 7), figsize=(5, 3)):
    """
    Plots Average Overlap Depth over Time.

    Parameters:
    - df: Pandas DataFrame containing the data
    - time_col: Name of the column for the x-axis (time)
    - overlap_col: Name of the column for the y-axis (average overlap depth)
    - title: Title of the plot
    - x_label: Label for the x-axis
    - y_label: Label for the y-axis
    - ylim: Tuple specifying the y-axis limits
    - figsize: Tuple specifying the figure size
    """
    plt.figure(figsize=figsize)
    plt.plot(df["Time"], df["Average_Overlap_Depth"], marker='o', linestyle='-', color='teal', label='Average Overlap Depth')

    # Adding titles and labels with smaller font sizes
    plt.title(title, fontsize=12)
    plt.xlabel(x_label, fontsize=10)
    plt.ylabel(y_label, fontsize=10)
    plt.ylim(ylim)

    # Adding gridlines, legend, and customizing the plot
    plt.grid(visible=True, linestyle='--', alpha=0.7)
    plt.legend(fontsize=10)
    plt.tight_layout()
    plt.show()

def plot_overlap_number(df, title="Number over Time", x_label="Time (ns)", y_label="Average Overlap Depth (Å)", ylim=(0, 100), figsize=(6, 3)):
    """
    Plots Average Overlap Depth over Time.

    Parameters:
    - df: Pandas DataFrame containing the data
    - time_col: Name of the column for the x-axis (time)
    - overlap_col: Name of the column for the y-axis (average overlap depth)
    - title: Title of the plot
    - x_label: Label for the x-axis
    - y_label: Label for the y-axis
    - ylim: Tuple specifying the y-axis limits
    - figsize: Tuple specifying the figure size
    """
    plt.figure(figsize=figsize)
    plt.plot(df["Time"], df["Number_of_Overlaps"], marker='o', linestyle='-', color='teal', label='Average Overlap Depth')

    # Adding titles and labels with smaller font sizes
    plt.title(title, fontsize=12)
    plt.xlabel(x_label, fontsize=10)
    plt.ylabel(y_label, fontsize=10)
    plt.ylim(ylim)

    # Adding gridlines, legend, and customizing the plot
    plt.grid(visible=True, linestyle='--', alpha=0.7)
    plt.legend(fontsize=10)
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt

def plot_all_overlaps(dfs, titles, ncols=3):
    """
    Create subplots for Average Overlap Depth over multiple datasets.

    Parameters:
    - dfs (list): List of DataFrames containing the data.
    - titles (list): List of titles for each plot.
    - ncols (int): Number of columns in the subplot grid.
    """
    nrows = (len(dfs) + ncols - 1) // ncols  # Calculate the number of rows needed
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols*5, nrows*3))
    axes = axes.flatten()

    for i, (df, title) in enumerate(zip(dfs, titles)):
        axes[i].plot(df["Time"], df["Average_Overlap_Depth"], marker='o', linestyle='-', color='teal', label='Average Overlap Depth')
        axes[i].set_title(title, fontsize=12)
        axes[i].set_xlabel("Time (ns)", fontsize=10)
        axes[i].set_ylabel("Average Overlap Depth (Å)", fontsize=10)
        axes[i].set_ylim(1, 7)
        axes[i].grid(visible=True, linestyle='--', alpha=0.7)
        axes[i].legend(fontsize=10)

    # Hide any unused subplot axes
    for i in range(len(dfs), len(axes)):
        fig.delaxes(axes[i])

    plt.tight_layout()
#     plt.savefig('depth_ov.png',dpi=400)
    plt.show()

# Example datasets
dfs = [time_c36, time_c36c, time_drude, time_eq, time_3mn, time_5mn, time_20mn]
titles = ['c36', 'c36c', 'drude no equilibration', 'drude equilibrated', 'drude 2.5mn']
plot_all_overlaps(dfs, titles)

# %%
def plot_all_overlap_numbers(dfs, titles, ncols=3):
    """
    Create subplots for Number of Overlaps over multiple datasets.

    Parameters:
    - dfs (list): List of DataFrames containing the data.
    - titles (list): List of titles for each plot.
    - ncols (int): Number of columns in the subplot grid.
    """
    nrows = (len(dfs) + ncols - 1) // ncols  # Calculate the number of rows needed
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols*6, nrows*3))
    axes = axes.flatten()

    for i, (df, title) in enumerate(zip(dfs, titles)):
        axes[i].plot(df["Time"], df["Number_of_Overlaps"], marker='o', linestyle='-', color='teal', label='Number of Overlaps')
        axes[i].set_title(title, fontsize=12)
        axes[i].set_xlabel("Time (ns)", fontsize=10)
        axes[i].set_ylabel("Number of Overlaps", fontsize=10)
        axes[i].set_ylim(0, 130)
        axes[i].grid(visible=True, linestyle='--', alpha=0.7)
        axes[i].legend(fontsize=10)

    # Hide any unused subplot axes
    for i in range(len(dfs), len(axes)):
        fig.delaxes(axes[i])

    plt.tight_layout()
    plt.savefig('number_ov.png',dpi=400)
    plt.show()

# Example datasets
dfs_numbers = [number_c36, number_c36c, number_drude, number_eq, number_3mn, number_5mn, number_20mn]
titles_numbers = ['c36', 'c36c', 'drude', 'drude equilibrated', 'drude 2.5mn']
plot_all_overlap_numbers(dfs_numbers, titles_numbers)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def histo_overlap(df, title):
    plt.figure(figsize=(4, 3))
    sns.histplot(df["Max_Overlap_Distance"], kde=True, bins=30, color='teal', stat='density')

    # Adding labels and title
    plt.title(title, fontsize=10)
    plt.xlabel("Max Overlap Distance (Å)", fontsize=14)
    plt.ylabel("Probability Density", fontsize=14)
    plt.grid(visible=True, linestyle='--', alpha=0.7)
    plt.ylim(0,0.3)
    plt.xlim(0,20)
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def histo_overlap_all(dfs, titles, ncols=3, plot_width=20, plot_height=15):
    """
    Create histograms for multiple datasets as subplots with custom plot dimensions.

    Parameters:
    - dfs (list): List of DataFrames containing the data.
    - titles (list): List of titles corresponding to each DataFrame.
    - ncols (int): Number of columns in the subplot grid.
    - plot_width (float): Width of the entire plot in inches.
    - plot_height (float): Height of the entire plot in inches.

    Returns:
    - None
    """
    nrows = (len(dfs) + ncols - 1) // ncols  # Calculate the number of rows needed
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(plot_width, plot_height))

    axes = axes.flatten()  # Flatten axes array for easier indexing

    for i, (df, title) in enumerate(zip(dfs, titles)):
        sns.histplot(df["Max_Overlap_Distance"], kde=True, bins=30, color='teal', stat='density', ax=axes[i])

        # Adding labels and title
        axes[i].set_title(title, fontsize=10)
        axes[i].set_xlabel("Overlap Distance (Å)", fontsize=12)
        axes[i].set_ylabel("Probability Density", fontsize=9)
        axes[i].grid(visible=True, linestyle='--', alpha=0.7)
        axes[i].set_ylim(0, 0.21)
        axes[i].set_xlim(0, 20)

    # Hide any unused subplot axes
    for i in range(len(dfs), len(axes)):
        fig.delaxes(axes[i])

    plt.tight_layout()
    plt.savefig('ov_histo.png',dpi=400)
    plt.show()

# Example usage:
dataframes = [df_c36, df_c36c, df_drude, df_eq, df_3mn, df_5mn, df_20mn]
titles = ['c36', 'c36c', 'drude no equilibration', 'drude equilibrated', '2.5mn']
histo_overlap_all(dataframes, titles, ncols=3, plot_width=10, plot_height=6)

# %%
histo_overlap(df_c36,'c36')
histo_overlap(df_c36c, 'c36c')
histo_overlap(df_drude,'drude no equilibration')
histo_overlap(df_eq,'drude equilibrated')
histo_overlap(df_3mn,'2.5mn')
histo_overlap(df_5mn,'5mn')
histo_overlap(df_20mn,'20mn')

# %% [markdown]
# # Interdigitation, overlap, densities

# %%
# Define a function to perform the analysis
def run_interdigitation_analysis(universe, lipids, neutral_lipid, solvent, nbins=100, b=0, e=None):
    analysis = InterdigitationAnalysis(universe, lipids, neutral_lipid, solvent)
    return analysis.interdigit(nbins=nbins, b=b, e=e)

# Use the function to perform the analyses
results_c36 = run_interdigitation_analysis(u1, ['POPC', 'DOPE', 'SAPI'], 'TRIO', 'TIP3')
results_c36c = run_interdigitation_analysis(u2, ['POPC', 'DOPE', 'SAPI'], 'TRIO', 'TIP3')
results_drude = run_interdigitation_analysis(u3, ['POPC', 'DOPE'], 'TRIO', 'SWM4')
results_eq = run_interdigitation_analysis(u4, ['POPC', 'DOPE'], 'TRIO', 'SWM4')
results_3mn = run_interdigitation_analysis(u5, ['POPC', 'DOPE'], 'TRIO', 'SWM4')
# results_5mn = run_interdigitation_analysis(u6, ['POPC', 'DOPE'], 'TRIO', 'SWM4')
# results_20mn = run_interdigitation_analysis(u7, ['POPC', 'DOPE'], 'TRIO', 'SWM4')
# Out:
# analyzing 2 us....
# units: Z (nm), interdigitation (nm), time (ns), density (g/m3)
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# units: Z (nm), interdigitation (nm), time (ns), density (g/m3)
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# analyzing 0 us....
# units: Z (nm), interdigitation (nm), time (ns), density (g/m3)
# units: Z (nm), interdigitation (nm), time (ns), density (g/m3)
# units: Z (nm), interdigitation (nm), time (ns), density (g/m3)

# %%
def plot_interdigitation_over_time(results):
    # Extract data for plotting
    total_interdigitation = results['inter']['total']
    strong_interdigitation = results['inter']['strong']
    weak_interdigitation = results['inter']['weak']

    # Extract time and interdigitation values
    time_total, inter_total = total_interdigitation[:, 0], total_interdigitation[:, 1]
    time_strong, inter_strong = strong_interdigitation[:, 0], strong_interdigitation[:, 1]
    time_weak, inter_weak = weak_interdigitation[:, 0], weak_interdigitation[:, 1]

    # Create the plot
    plt.figure(figsize=(5, 2))
    plt.plot(time_total, inter_total, label='Total Intedigitation', color='blue')
    plt.plot(time_strong, inter_strong, label='Strong Intedigitation', color='green')
    plt.plot(time_weak, inter_weak, label='Weak Intedigitation', color='red')

    plt.title('Interdigitation Over Time')
    plt.xlabel('Time (ns)')
    plt.ylabel('Interdigitation (nm)')
    plt.ylim(0, 2.9)
#     plt.legend()
    plt.grid(True)
    plt.show()
def plot_overlap(results):
    # Extract data for plotting
    total_overlap = results['ov']['total']
    strong_overlap = results['ov']['strong']
    weak_overlap = results['ov']['weak']

    # Extract z-coordinates and overlap values
    z_coords, ov_total = total_overlap[:, 0], total_overlap[:, 1]
    _, ov_strong = strong_overlap[:, 0], strong_overlap[:, 1]
    _, ov_weak = weak_overlap[:, 0], weak_overlap[:, 1]

    # Create the plot
    plt.figure(figsize=(5, 2))
    plt.plot(z_coords, ov_total, label='Total Overlap', color='blue', linewidth=2)
    plt.plot(z_coords, ov_strong, label='Strong Overlap', color='green', linewidth=2)
    plt.plot(z_coords, ov_weak, label='Weak Overlap', color='red', linewidth=2)

    plt.title('Overlap as a Function of Z-coordinate')
    plt.xlabel('Z-coordinate (nm)')
    plt.ylabel('Overlap (dimensionless)')
    plt.ylim(0, 1)
#     plt.legend()
    plt.grid(True)
    plt.show()

# Assuming 'results' is your data dictionary loaded as per your simulation outputs


def plot_densities(results):
    # Extract density data
    pl_density = results['density']['PL']
    trio_density = results['density']['TRIO']
    surf_trio_density = results['density']['SURF-TRIO']
    core_trio_density = results['density']['CORE-TRIO']
    water_density = results['density']['water']

    # Extract z-coordinates and density values
    z_coords, den_pl = pl_density[:, 0], pl_density[:, 1]
    _, den_trio = trio_density[:, 0], trio_density[:, 1]
    _, den_surf_trio = surf_trio_density[:, 0], surf_trio_density[:, 1]
    _, den_core_trio = core_trio_density[:, 0], core_trio_density[:, 1]
    _, den_water = water_density[:, 0], water_density[:, 1]

    # Create the plot
    plt.figure(figsize=(5, 2))
    plt.plot(z_coords, den_pl, label='PL Density', color='blue', linewidth=2)
    plt.plot(z_coords, den_trio, label='TRIO Density', color='green', linewidth=2)
    plt.plot(z_coords, den_surf_trio, label='SURF-TRIO Density', color='red', linewidth=2)
    plt.plot(z_coords, den_core_trio, label='CORE-TRIO Density', color='purple', linewidth=2)
    plt.plot(z_coords, den_water, label='Water Density', color='cyan', linewidth=2)
#     plt.ylim(0,0.02)

    plt.title('Density Profiles Along Z-Coordinate')
    plt.xlabel('Z-coordinate (nm)')
    plt.ylabel('Density (g/m³)')
#     plt.legend()
    plt.grid(True)
    plt.show()

def plot_ratios(results):
    # Extract data for plotting
    num_ratio = results['ratio']['num']          # Number of strong interdigitating molecules over time
    trio_to_pl_ratio = results['ratio']['trio-to-pl']  # Ratio of strong interdigitating molecules to phospholipids
    trio_to_pl_trio_ratio = results['ratio']['trio-to-pl+trio']  # Ratio of strong interdigitating molecules to the sum of phospholipids and strong interdigitating molecules

    # Extract time and ratio values
    time_num, ratio_num = num_ratio[:, 0], num_ratio[:, 1]
    time_trio_to_pl, ratio_trio_to_pl = trio_to_pl_ratio[:, 0], trio_to_pl_ratio[:, 1]
    time_trio_to_pl_trio, ratio_trio_to_pl_trio = trio_to_pl_trio_ratio[:, 0], trio_to_pl_trio_ratio[:, 1]

    # Create the plot
    plt.figure(figsize=(8, 6))
    plt.subplot(311)  # 3 rows, 1 column, 1st subplot
    plt.plot(time_num, ratio_num, label='Number of Strong Interdigitators', color='blue', linewidth=2)
    plt.title('Number of Strong Interdigitating Molecules Over Time')
    plt.xlabel('Time (ns)')
    plt.ylabel('Number')
    plt.ylim(0,30)
#     plt.legend()
    plt.grid(True)

#     plt.subplot(312)  # 3 rows, 1 column, 2nd subplot
#     plt.plot(time_trio_to_pl, ratio_trio_to_pl, label='Ratio of Strong Interdigitators to PL', color='green', linewidth=2)
#     plt.title('Ratio of Strong Interdigitating Molecules to Phospholipids')
#     plt.xlabel('Time (ns)')
#     plt.ylabel('Ratio')
# #     plt.legend()
#     plt.grid(True)

#     plt.subplot(313)  # 3 rows, 1 column, 3rd subplot
#     plt.plot(time_trio_to_pl_trio, ratio_trio_to_pl_trio, label='Ratio of Strong Interdigitators to PL+Strong Interdigitators', color='red', linewidth=2)
#     plt.title('Ratio of Strong Interdigitating Molecules to Total (PL + Strong Interdigitators)')
#     plt.xlabel('Time (ns)')
#     plt.ylabel('Ratio')
# #     plt.legend()
#     plt.grid(True)

    plt.tight_layout()  # Adjust subplots to fit into figure area.
    plt.show()

# %%
import matplotlib.pyplot as plt

def plot_interdigitation_over_time_all(results_list, titles, ncols=3):
    """
    Plot interdigitation over time for multiple datasets as subplots, with a single shared legend outside the plots.

    Parameters:
    - results_list (list): List of dictionaries containing the simulation data for each dataset.
    - titles (list): List of titles for each subplot.
    - ncols (int): Number of columns in the subplot grid.
    """
    nrows = (len(results_list) + ncols - 1) // ncols  # Calculate the number of rows needed
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols * 5, nrows * 3))
    axes = axes.flatten()  # Flatten axes array for easier indexing

    lines = []  # To store plot lines for legend
    labels = []  # To store labels for legend

    for i, results in enumerate(results_list):
        # Extract data for plotting
        total_interdigitation = results['inter']['total']
        strong_interdigitation = results['inter']['strong']
        weak_interdigitation = results['inter']['weak']

        # Extract time and interdigitation values
        time_total, inter_total = total_interdigitation[:, 0], total_interdigitation[:, 1]
        time_strong, inter_strong = strong_interdigitation[:, 0], strong_interdigitation[:, 1]
        time_weak, inter_weak = weak_interdigitation[:, 0], weak_interdigitation[:, 1]

        # Plot on respective axes
        line1, = axes[i].plot(time_total, inter_total, label='Total Intedigitation', color='blue')
        line2, = axes[i].plot(time_strong, inter_strong, label='Strong Intedigitation', color='green')
        line3, = axes[i].plot(time_weak, inter_weak, label='Weak Intedigitation', color='red')

#         axes[i].set_title(titles[i])
        axes[i].set_xlabel('Time (ns)')
        axes[i].set_ylabel('Interdigitation (nm)')
        axes[i].set_ylim(0, 2.9)
        axes[i].grid(True)

        if i == 0:  # Only add to legend list once
            lines.extend([line1, line2, line3])
            labels.extend([line.get_label() for line in [line1, line2, line3]])

    # Place a single legend outside the right side of the last axes
    fig.legend(lines, labels, loc='lower right', bbox_to_anchor=(0.6, 0.2), fontsize='large')

    # Hide any unused subplot axes
    for j in range(len(results_list), len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.savefig('interdigig.png',dpi=400)
    plt.show()

# Example usage with a hypothetical set of data:
results_list = [results_c36, results_c36c, results_drude, results_eq, results_3mn, results_5mn, results_20mn]
titles = ['c36', 'c36c', 'drude no equilibration', 'drude equilibrated', '2.5mn']
plot_interdigitation_over_time_all(results_list, titles)

# %%
# Assuming 'results' is your data dictionary loaded as per your simulation outputs
plot_interdigitation_over_time(results_c36)
plot_interdigitation_over_time(results_c36c)
plot_interdigitation_over_time(results_drude)
plot_interdigitation_over_time(results_eq)
plot_interdigitation_over_time(results_3mn)
plot_interdigitation_over_time(results_5mn)
plot_interdigitation_over_time(results_20mn)

# %%
plot_overlap(results_c36)
plot_overlap(results_c36c)
plot_overlap(results_drude)
plot_overlap(results_eq)
plot_overlap(results_3mn)
plot_overlap(results_5mn)
plot_overlap(results_20mn)

# %%
# Assuming 'results' is your data dictionary loaded as per your simulation outputs
plot_densities(results_c36)
plot_densities(results_c36c)
plot_densities(results_drude)
plot_densities(results_eq)
plot_densities(results_3mn)
plot_densities(results_5mn)
plot_densities(results_20mn)

# %%
plot_ratios(results_c36)
plot_ratios(results_c36c)
plot_ratios(results_drude)
plot_ratios(results_eq)
plot_ratios(results_3mn)
# plot_ratios(results_5mn)
# plot_ratios(results_20mn)

# %% [markdown]
# # Develop method for new interdigitation

# %%
def percent_overlap(results, type1_name, type2_name):
    # Retrieve density arrays from the results using the provided names
    type_density_1 = results['density'][type1_name]
    type_density_2 = results['density'][type2_name]
    z = type_density_1[:, 0]
    if type_density_1.shape != type_density_2.shape:
        raise ValueError("The two density arrays must have the same shape.")
    overlap_density = np.minimum(type_density_1[:, 1], type_density_2[:, 1])
    total_area = np.trapz(type_density_1[:, 1], x=z)
    overlap_area = np.trapz(overlap_density, x=z)
    overlap_percentage = (overlap_area / total_area) * 100
    print(f"The overlap of {type2_name} with {type1_name} represents {overlap_percentage:.2f}% of the total {type1_name} area.")
    return(overlap_percentage)

# %%
def percent_overlap_time_series(results, type1_name, type2_name):
    # Retrieve time-series density arrays from the results
    type_series_1 = results['density'][f'{type1_name}_series']
    type_series_2 = results['density'][f'{type2_name}_series']
    times = results['inter']['total'][:, 0]  # Assuming this time array is appropriate for both densities
    z = results['density'][type1_name][:, 0]  # Assuming the z-axis values are the same for both densities
    if type_series_1.shape != type_series_2.shape:
        raise ValueError("The two time-series density arrays must have the same shape.")
    overlap_percentages = []
    for t in range(len(times)):
        overlap_density = np.minimum(type_series_1[t], type_series_2[t])
        total_area = np.trapz(type_series_1[t], x=z)
        overlap_area = np.trapz(overlap_density, x=z)
        overlap_percentage = (overlap_area / total_area) * 100
        overlap_percentages.append(overlap_percentage)
    overlap_percentages = np.array(overlap_percentages)
    for time, overlap in zip(times, overlap_percentages):
        print(f"At time {time} ns, the overlap of {type2_name} with {type1_name} is {overlap:.2f}%.")

    return times, overlap_percentages

# %%
# Assuming `results_c36` is your results dictionary containing the time-series densities
times1, overlap_evolution1 = percent_overlap_time_series(results_c36, 'PL', 'CORE-TRIO')
times2, overlap_evolution2 = percent_overlap_time_series(results_c36c, 'PL', 'CORE-TRIO')
times3, overlap_evolution3 = percent_overlap_time_series(results_drude, 'PL', 'CORE-TRIO')
times4, overlap_evolution4 = percent_overlap_time_series(results_eq, 'PL', 'CORE-TRIO')
times5, overlap_evolution5 = percent_overlap_time_series(results_3mn, 'PL', 'CORE-TRIO')
# times6, overlap_evolution6 = percent_overlap_time_series(results_5mn, 'PL', 'CORE-TRIO')
# times7, overlap_evolution7 = percent_overlap_time_series(results_20mn, 'PL', 'CORE-TRIO')
# Out:
# At time 1979.6 ns, the overlap of CORE-TRIO with PL is 13.18%.
# At time 1980.6 ns, the overlap of CORE-TRIO with PL is 14.61%.
# At time 1981.6 ns, the overlap of CORE-TRIO with PL is 14.29%.
# At time 1982.6 ns, the overlap of CORE-TRIO with PL is 13.25%.
# At time 1983.6 ns, the overlap of CORE-TRIO with PL is 12.88%.
# At time 1984.6 ns, the overlap of CORE-TRIO with PL is 13.74%.
# At time 1985.6 ns, the overlap of CORE-TRIO with PL is 13.73%.
# At time 1986.6 ns, the overlap of CORE-TRIO with PL is 13.82%.
# At time 1987.6 ns, the overlap of CORE-TRIO with PL is 11.58%.
# At time 1988.6 ns, the overlap of CORE-TRIO with PL is 13.99%.
# At time 1989.6 ns, the overlap of CORE-TRIO with PL is 14.04%.
# At time 1990.6 ns, the overlap of CORE-TRIO with PL is 14.23%.
# At time 1991.6 ns, the overlap of CORE-TRIO with PL is 13.70%.
# At time 1992.6 ns, the overlap of CORE-TRIO with PL is 13.21%.
# At time 1993.6 ns, the overlap of CORE-TRIO with PL is 14.65%.
# At time 1994.6 ns, the overlap of CORE-TRIO with PL is 15.13%.
# At time 1995.6 ns, the overlap of CORE-TRIO with PL is 13.95%.
# At time 1996.6 ns, the overlap of CORE-TRIO with PL is 14.44%.
# At time 1997.6 ns, the overlap of CORE-TRIO with PL is 14.27%.
# At time 1998.6 ns, the overlap of CORE-TRIO with PL is 12.89%.
# At time 1999.6 ns, the overlap of CORE-TRIO with PL is 12.80%.
# At time 2000.6 ns, the overlap of CORE-TRIO with PL is 11.49%.
# At time 2001.6 ns, the overlap of CORE-TRIO with PL is 13.87%.
# At time 2002.6 ns, the overlap of CORE-TRIO with PL is 13.39%.
# At time 2003.6 ns, the overlap of CORE-TRIO with PL is 13.80%.
# At time 2004.6 ns, the overlap of CORE-TRIO with PL is 11.59%.
# At time 2005.6 ns, the overlap of CORE-TRIO with PL is 12.33%.
# At time 2006.6 ns, the overlap of CORE-TRIO with PL is 12.10%.
# At time 2007.6 ns, the overlap of CORE-TRIO with PL is 13.02%.
# At time 2008.6 ns, the overlap of CORE-TRIO with PL is 13.18%.
# At time 2009.6 ns, the overlap of CORE-TRIO with PL is 16.12%.
# At time 2010.6 ns, the overlap of CORE-TRIO with PL is 14.33%.
# At time 2011.6 ns, the overlap of CORE-TRIO with PL is 14.47%.
# At time 2012.6 ns, the overlap of CORE-TRIO with PL is 13.35%.
# At time 2013.6 ns, the overlap of CORE-TRIO with PL is 15.28%.
# At time 2014.6 ns, the overlap of CORE-TRIO with PL is 14.10%.
# At time 2015.6 ns, the overlap of CORE-TRIO with PL is 14.48%.
# At time 2016.6 ns, the overlap of CORE-TRIO with PL is 15.35%.
# At time 2017.6 ns, the overlap of CORE-TRIO with PL is 14.38%.
# At time 2018.6 ns, the overlap of CORE-TRIO with PL is 12.95%.
# At time 2019.6 ns, the overlap of CORE-TRIO with PL is 12.35%.
# At time 2020.6 ns, the overlap of CORE-TRIO with PL is 14.12%.
# At time 2021.6 ns, the overlap of CORE-TRIO with PL is 13.56%.
# At time 2022.6 ns, the overlap of CORE-TRIO with PL is 12.64%.
# At time 2023.6 ns, the overlap of CORE-TRIO with PL is 13.21%.
# At time 2024.6 ns, the overlap of CORE-TRIO with PL is 13.18%.
# At time 2025.6 ns, the overlap of CORE-TRIO with PL is 12.71%.
# At time 2026.6 ns, the overlap of CORE-TRIO with PL is 12.21%.
# At time 2027.6 ns, the overlap of CORE-TRIO with PL is 11.98%.
# At time 2028.6 ns, the overlap of CORE-TRIO with PL is 11.97%.
# At time 2029.6 ns, the overlap of CORE-TRIO with PL is 13.03%.
# At time 2030.6 ns, the overlap of CORE-TRIO with PL is 12.01%.
# At time 2031.6 ns, the overlap of CORE-TRIO with PL is 13.59%.
# At time 2032.6 ns, the overlap of CORE-TRIO with PL is 14.99%.
# At time 2033.6 ns, the overlap of CORE-TRIO with PL is 13.97%.
# At time 2034.6 ns, the overlap of CORE-TRIO with PL is 12.85%.
# At time 2035.6 ns, the overlap of CORE-TRIO with PL is 12.79%.
# At time 2036.6 ns, the overlap of CORE-TRIO with PL is 12.09%.
# At time 2037.6 ns, the overlap of CORE-TRIO with PL is 12.48%.
# At time 2038.6 ns, the overlap of CORE-TRIO with PL is 12.64%.
# At time 2039.6 ns, the overlap of CORE-TRIO with PL is 15.70%.
# At time 2040.6 ns, the overlap of CORE-TRIO with PL is 13.34%.
# At time 2041.6 ns, the overlap of CORE-TRIO with PL is 13.09%.
# At time 2042.6 ns, the overlap of CORE-TRIO with PL is 13.50%.
# At time 2043.6 ns, the overlap of CORE-TRIO with PL is 15.23%.
# At time 2044.6 ns, the overlap of CORE-TRIO with PL is 12.31%.
# At time 2045.6 ns, the overlap of CORE-TRIO with PL is 12.98%.
# At time 2046.6 ns, the overlap of CORE-TRIO with PL is 13.68%.
# At time 2047.6 ns, the overlap of CORE-TRIO with PL is 12.58%.
# At time 2048.6 ns, the overlap of CORE-TRIO with PL is 11.70%.
# At time 2049.6 ns, the overlap of CORE-TRIO with PL is 14.61%.
# At time 2050.6 ns, the overlap of CORE-TRIO with PL is 13.04%.
# At time 2051.6 ns, the overlap of CORE-TRIO with PL is 14.88%.
# At time 2052.6 ns, the overlap of CORE-TRIO with PL is 13.86%.
# At time 2053.6 ns, the overlap of CORE-TRIO with PL is 12.90%.
# At time 2054.6 ns, the overlap of CORE-TRIO with PL is 12.30%.
# At time 2055.6 ns, the overlap of CORE-TRIO with PL is 11.44%.
# At time 2056.6 ns, the overlap of CORE-TRIO with PL is 12.30%.
# At time 2057.6 ns, the overlap of CORE-TRIO with PL is 12.81%.
# At time 2058.6 ns, the overlap of CORE-TRIO with PL is 13.65%.
# At time 2059.6 ns, the overlap of CORE-TRIO with PL is 12.73%.
# At time 2060.6 ns, the overlap of CORE-TRIO with PL is 11.78%.
# At time 2061.6 ns, the overlap of CORE-TRIO with PL is 13.31%.
# At time 2062.6 ns, the overlap of CORE-TRIO with PL is 12.46%.
# At time 2063.6 ns, the overlap of CORE-TRIO with PL is 10.72%.
# At time 2064.6 ns, the overlap of CORE-TRIO with PL is 11.99%.
# At time 2065.6 ns, the overlap of CORE-TRIO with PL is 11.82%.
# At time 2066.6 ns, the overlap of CORE-TRIO with PL is 11.74%.
# At time 2067.6 ns, the overlap of CORE-TRIO with PL is 11.84%.
# At time 2068.6 ns, the overlap of CORE-TRIO with PL is 12.19%.
# At time 2069.6 ns, the overlap of CORE-TRIO with PL is 11.53%.
# At time 2070.6 ns, the overlap of CORE-TRIO with PL is 11.77%.
# At time 2071.6 ns, the overlap of CORE-TRIO with PL is 11.89%.
# At time 2072.6 ns, the overlap of CORE-TRIO with PL is 11.08%.
# At time 2073.6 ns, the overlap of CORE-TRIO with PL is 11.13%.
# At time 2074.6 ns, the overlap of CORE-TRIO with PL is 11.17%.
# At time 2075.6 ns, the overlap of CORE-TRIO with PL is 11.66%.
# At time 2076.6 ns, the overlap of CORE-TRIO with PL is 11.76%.
# At time 2077.6 ns, the overlap of CORE-TRIO with PL is 10.91%.
# At time 2078.6 ns, the overlap of CORE-TRIO with PL is 11.30%.
# At time 2079.6 ns, the overlap of CORE-TRIO with PL is 11.49%.
# At time 2080.6 ns, the overlap of CORE-TRIO with PL is 13.29%.
# At time 2081.6 ns, the overlap of CORE-TRIO with PL is 13.01%.
# At time 2082.6 ns, the overlap of CORE-TRIO with PL is 13.65%.
# At time 2083.6 ns, the overlap of CORE-TRIO with PL is 14.19%.
# At time 2084.6 ns, the overlap of CORE-TRIO with PL is 11.47%.
# At time 2085.6 ns, the overlap of CORE-TRIO with PL is 11.51%.
# At time 2086.6 ns, the overlap of CORE-TRIO with PL is 11.36%.
# At time 2087.6 ns, the overlap of CORE-TRIO with PL is 12.16%.
# At time 2088.6 ns, the overlap of CORE-TRIO with PL is 11.84%.
# At time 2089.6 ns, the overlap of CORE-TRIO with PL is 11.65%.
# At time 2090.6 ns, the overlap of CORE-TRIO with PL is 12.85%.
# At time 2091.6 ns, the overlap of CORE-TRIO with PL is 11.54%.
# At time 2092.6 ns, the overlap of CORE-TRIO with PL is 11.42%.
# At time 2093.6 ns, the overlap of CORE-TRIO with PL is 11.98%.
# At time 2094.6 ns, the overlap of CORE-TRIO with PL is 11.48%.
# At time 2095.6 ns, the overlap of CORE-TRIO with PL is 12.53%.
# At time 2096.6 ns, the overlap of CORE-TRIO with PL is 12.44%.
# At time 2097.6 ns, the overlap of CORE-TRIO with PL is 12.89%.
# At time 2098.6 ns, the overlap of CORE-TRIO with PL is 14.13%.
# At time 2099.6 ns, the overlap of CORE-TRIO with PL is 14.64%.
# At time 2100.6 ns, the overlap of CORE-TRIO with PL is 14.99%.
# At time 2101.6 ns, the overlap of CORE-TRIO with PL is 15.13%.
# At time 2102.6 ns, the overlap of CORE-TRIO with PL is 15.54%.
# At time 2103.6 ns, the overlap of CORE-TRIO with PL is 14.29%.
# At time 2104.6 ns, the overlap of CORE-TRIO with PL is 12.90%.
# At time 2105.6 ns, the overlap of CORE-TRIO with PL is 13.55%.
# At time 2106.6 ns, the overlap of CORE-TRIO with PL is 12.02%.
# At time 2107.6 ns, the overlap of CORE-TRIO with PL is 13.19%.
# At time 2108.6 ns, the overlap of CORE-TRIO with PL is 13.33%.
# At time 2109.6 ns, the overlap of CORE-TRIO with PL is 14.34%.
# At time 2110.6 ns, the overlap of CORE-TRIO with PL is 14.62%.
# At time 2111.6 ns, the overlap of CORE-TRIO with PL is 13.73%.
# At time 2112.6 ns, the overlap of CORE-TRIO with PL is 12.82%.
# At time 2113.6 ns, the overlap of CORE-TRIO with PL is 13.55%.
# At time 2114.6 ns, the overlap of CORE-TRIO with PL is 13.33%.
# At time 2115.6 ns, the overlap of CORE-TRIO with PL is 13.26%.
# At time 2116.6 ns, the overlap of CORE-TRIO with PL is 13.77%.
# At time 2117.6 ns, the overlap of CORE-TRIO with PL is 14.87%.
# At time 2118.6 ns, the overlap of CORE-TRIO with PL is 13.19%.
# At time 2119.6 ns, the overlap of CORE-TRIO with PL is 11.93%.
# At time 2120.6 ns, the overlap of CORE-TRIO with PL is 14.11%.
# At time 2121.6 ns, the overlap of CORE-TRIO with PL is 14.61%.
# At time 2122.6 ns, the overlap of CORE-TRIO with PL is 15.00%.
# At time 2123.6 ns, the overlap of CORE-TRIO with PL is 16.03%.
# At time 2124.6 ns, the overlap of CORE-TRIO with PL is 16.46%.
# At time 2125.6 ns, the overlap of CORE-TRIO with PL is 15.91%.
# At time 2126.6 ns, the overlap of CORE-TRIO with PL is 15.55%.
# At time 2127.6 ns, the overlap of CORE-TRIO with PL is 15.74%.
# At time 2128.6 ns, the overlap of CORE-TRIO with PL is 18.24%.
# At time 2129.6 ns, the overlap of CORE-TRIO with PL is 15.23%.
# At time 2130.6 ns, the overlap of CORE-TRIO with PL is 15.95%.
# At time 2131.6 ns, the overlap of CORE-TRIO with PL is 14.87%.
# At time 2132.6 ns, the overlap of CORE-TRIO with PL is 15.76%.
# At time 2133.6 ns, the overlap of CORE-TRIO with PL is 15.08%.
# At time 2134.6 ns, the overlap of CORE-TRIO with PL is 16.26%.
# At time 2135.6 ns, the overlap of CORE-TRIO with PL is 16.94%.
# At time 2136.6 ns, the overlap of CORE-TRIO with PL is 15.92%.
# At time 2137.6 ns, the overlap of CORE-TRIO with PL is 13.13%.
# At time 2138.6 ns, the overlap of CORE-TRIO with PL is 12.09%.
# At time 2139.6 ns, the overlap of CORE-TRIO with PL is 12.84%.
# At time 2140.6 ns, the overlap of CORE-TRIO with PL is 11.18%.
# At time 2141.6 ns, the overlap of CORE-TRIO with PL is 11.91%.
# At time 2142.6 ns, the overlap of CORE-TRIO with PL is 10.96%.
# At time 2143.6 ns, the overlap of CORE-TRIO with PL is 10.86%.
# At time 2144.6 ns, the overlap of CORE-TRIO with PL is 11.52%.
# At time 2145.6 ns, the overlap of CORE-TRIO with PL is 13.28%.
# At time 2146.6 ns, the overlap of CORE-TRIO with PL is 11.88%.
# At time 2147.6 ns, the overlap of CORE-TRIO with PL is 12.90%.
# At time 2148.6 ns, the overlap of CORE-TRIO with PL is 12.35%.
# At time 2149.6 ns, the overlap of CORE-TRIO with PL is 12.84%.
# At time 2150.6 ns, the overlap of CORE-TRIO with PL is 12.84%.
# At time 2151.6 ns, the overlap of CORE-TRIO with PL is 11.75%.
# At time 2152.6 ns, the overlap of CORE-TRIO with PL is 11.94%.
# At time 2153.6 ns, the overlap of CORE-TRIO with PL is 11.33%.
# At time 2154.6 ns, the overlap of CORE-TRIO with PL is 12.78%.
# At time 2155.6 ns, the overlap of CORE-TRIO with PL is 12.66%.
# At time 2156.6 ns, the overlap of CORE-TRIO with PL is 13.82%.
# At time 2157.6 ns, the overlap of CORE-TRIO with PL is 13.70%.
# At time 2158.6 ns, the overlap of CORE-TRIO with PL is 13.05%.
# At time 2159.6 ns, the overlap of CORE-TRIO with PL is 12.47%.
# At time 2160.6 ns, the overlap of CORE-TRIO with PL is 13.42%.
# At time 2161.6 ns, the overlap of CORE-TRIO with PL is 10.59%.
# At time 2162.6 ns, the overlap of CORE-TRIO with PL is 12.13%.
# At time 2163.6 ns, the overlap of CORE-TRIO with PL is 10.46%.
# At time 2164.6 ns, the overlap of CORE-TRIO with PL is 13.96%.
# At time 2165.6 ns, the overlap of CORE-TRIO with PL is 12.29%.
# At time 2166.6 ns, the overlap of CORE-TRIO with PL is 13.23%.
# At time 2167.6 ns, the overlap of CORE-TRIO with PL is 13.77%.
# At time 2168.6 ns, the overlap of CORE-TRIO with PL is 13.84%.
# At time 2169.6 ns, the overlap of CORE-TRIO with PL is 14.05%.
# At time 2170.6 ns, the overlap of CORE-TRIO with PL is 14.15%.
# At time 2171.6 ns, the overlap of CORE-TRIO with PL is 13.64%.
# At time 2172.6 ns, the overlap of CORE-TRIO with PL is 13.47%.
# At time 2173.6 ns, the overlap of CORE-TRIO with PL is 12.57%.
# At time 2174.6 ns, the overlap of CORE-TRIO with PL is 12.49%.
# At time 2175.6 ns, the overlap of CORE-TRIO with PL is 13.77%.
# At time 2176.6 ns, the overlap of CORE-TRIO with PL is 12.66%.
# At time 2177.6 ns, the overlap of CORE-TRIO with PL is 10.51%.
# At time 2178.6 ns, the overlap of CORE-TRIO with PL is 12.62%.
# At time 2179.6 ns, the overlap of CORE-TRIO with PL is 12.89%.
# At time 2180.6 ns, the overlap of CORE-TRIO with PL is 12.72%.
# At time 2181.6 ns, the overlap of CORE-TRIO with PL is 13.56%.
# At time 2182.6 ns, the overlap of CORE-TRIO with PL is 12.98%.
# At time 2183.6 ns, the overlap of CORE-TRIO with PL is 12.82%.
# At time 2184.6 ns, the overlap of CORE-TRIO with PL is 13.05%.
# At time 2185.6 ns, the overlap of CORE-TRIO with PL is 11.71%.
# At time 2186.6 ns, the overlap of CORE-TRIO with PL is 13.03%.
# At time 2187.6 ns, the overlap of CORE-TRIO with PL is 12.29%.
# At time 2188.6 ns, the overlap of CORE-TRIO with PL is 11.57%.
# At time 2189.6 ns, the overlap of CORE-TRIO with PL is 12.44%.
# At time 2190.6 ns, the overlap of CORE-TRIO with PL is 13.36%.
# At time 2191.6 ns, the overlap of CORE-TRIO with PL is 13.81%.
# At time 2192.6 ns, the overlap of CORE-TRIO with PL is 12.90%.
# At time 2193.6 ns, the overlap of CORE-TRIO with PL is 12.11%.
# At time 2194.6 ns, the overlap of CORE-TRIO with PL is 13.01%.
# At time 2195.6 ns, the overlap of CORE-TRIO with PL is 13.38%.
# At time 2196.6 ns, the overlap of CORE-TRIO with PL is 12.72%.
# At time 2197.6 ns, the overlap of CORE-TRIO with PL is 12.16%.
# At time 2198.6 ns, the overlap of CORE-TRIO with PL is 11.35%.
# At time 2199.6 ns, the overlap of CORE-TRIO with PL is 13.05%.
# At time 2200.6 ns, the overlap of CORE-TRIO with PL is 12.86%.
# At time 2201.6 ns, the overlap of CORE-TRIO with PL is 12.21%.
# At time 2202.6 ns, the overlap of CORE-TRIO with PL is 11.91%.
# At time 2203.6 ns, the overlap of CORE-TRIO with PL is 11.38%.
# At time 2204.6 ns, the overlap of CORE-TRIO with PL is 11.21%.
# At time 2205.6 ns, the overlap of CORE-TRIO with PL is 11.35%.
# At time 2206.6 ns, the overlap of CORE-TRIO with PL is 10.54%.
# At time 2207.6 ns, the overlap of CORE-TRIO with PL is 11.07%.
# At time 2208.6 ns, the overlap of CORE-TRIO with PL is 11.38%.
# At time 2209.6 ns, the overlap of CORE-TRIO with PL is 11.07%.
# At time 2210.6 ns, the overlap of CORE-TRIO with PL is 11.29%.
# At time 2211.6 ns, the overlap of CORE-TRIO with PL is 10.63%.
# At time 2212.6 ns, the overlap of CORE-TRIO with PL is 13.80%.
# At time 2213.6 ns, the overlap of CORE-TRIO with PL is 13.38%.
# At time 2214.6 ns, the overlap of CORE-TRIO with PL is 13.73%.
# At time 0.0 ns, the overlap of CORE-TRIO with PL is 13.53%.
# At time 0.1 ns, the overlap of CORE-TRIO with PL is 13.36%.
# At time 0.2 ns, the overlap of CORE-TRIO with PL is 13.34%.
# At time 0.3 ns, the overlap of CORE-TRIO with PL is 13.88%.
# At time 0.4 ns, the overlap of CORE-TRIO with PL is 13.05%.
# At time 0.5 ns, the overlap of CORE-TRIO with PL is 13.63%.
# At time 0.6 ns, the overlap of CORE-TRIO with PL is 13.53%.
# At time 0.7 ns, the overlap of CORE-TRIO with PL is 13.01%.
# At time 0.8 ns, the overlap of CORE-TRIO with PL is 13.42%.
# At time 0.9 ns, the overlap of CORE-TRIO with PL is 14.67%.
# At time 1.0 ns, the overlap of CORE-TRIO with PL is 14.01%.
# At time 1.1 ns, the overlap of CORE-TRIO with PL is 13.29%.
# At time 1.2 ns, the overlap of CORE-TRIO with PL is 13.71%.
# At time 1.3 ns, the overlap of CORE-TRIO with PL is 12.40%.
# At time 1.4 ns, the overlap of CORE-TRIO with PL is 12.67%.
# At time 1.5 ns, the overlap of CORE-TRIO with PL is 12.40%.
# At time 1.6 ns, the overlap of CORE-TRIO with PL is 13.00%.
# At time 1.7 ns, the overlap of CORE-TRIO with PL is 13.12%.
# At time 1.8 ns, the overlap of CORE-TRIO with PL is 13.44%.
# At time 1.9 ns, the overlap of CORE-TRIO with PL is 14.01%.
# At time 2.0 ns, the overlap of CORE-TRIO with PL is 14.80%.
# At time 2.1 ns, the overlap of CORE-TRIO with PL is 14.21%.
# At time 2.2 ns, the overlap of CORE-TRIO with PL is 12.64%.
# At time 2.3 ns, the overlap of CORE-TRIO with PL is 12.20%.
# At time 2.4 ns, the overlap of CORE-TRIO with PL is 13.83%.
# At time 2.5 ns, the overlap of CORE-TRIO with PL is 13.55%.
# At time 2.6 ns, the overlap of CORE-TRIO with PL is 14.37%.
# At time 2.7 ns, the overlap of CORE-TRIO with PL is 13.24%.
# At time 2.8 ns, the overlap of CORE-TRIO with PL is 13.26%.
# At time 2.9 ns, the overlap of CORE-TRIO with PL is 13.73%.
# At time 3.0 ns, the overlap of CORE-TRIO with PL is 13.59%.
# At time 3.1 ns, the overlap of CORE-TRIO with PL is 14.48%.
# At time 3.2 ns, the overlap of CORE-TRIO with PL is 14.37%.
# At time 3.3 ns, the overlap of CORE-TRIO with PL is 13.39%.
# At time 3.4 ns, the overlap of CORE-TRIO with PL is 13.91%.
# At time 3.5 ns, the overlap of CORE-TRIO with PL is 15.15%.
# At time 3.6 ns, the overlap of CORE-TRIO with PL is 14.22%.
# At time 3.7 ns, the overlap of CORE-TRIO with PL is 15.07%.
# At time 3.8 ns, the overlap of CORE-TRIO with PL is 14.13%.
# At time 3.9 ns, the overlap of CORE-TRIO with PL is 13.63%.
# At time 4.0 ns, the overlap of CORE-TRIO with PL is 14.92%.
# At time 4.1 ns, the overlap of CORE-TRIO with PL is 15.96%.
# At time 4.2 ns, the overlap of CORE-TRIO with PL is 15.50%.
# At time 4.3 ns, the overlap of CORE-TRIO with PL is 15.34%.
# At time 4.4 ns, the overlap of CORE-TRIO with PL is 14.96%.
# At time 4.5 ns, the overlap of CORE-TRIO with PL is 15.43%.
# At time 4.6 ns, the overlap of CORE-TRIO with PL is 14.63%.
# At time 4.7 ns, the overlap of CORE-TRIO with PL is 14.43%.
# At time 4.8 ns, the overlap of CORE-TRIO with PL is 14.02%.
# At time 4.9 ns, the overlap of CORE-TRIO with PL is 15.32%.
# At time 5.0 ns, the overlap of CORE-TRIO with PL is 15.35%.
# At time 5.1 ns, the overlap of CORE-TRIO with PL is 14.65%.
# At time 5.2 ns, the overlap of CORE-TRIO with PL is 14.65%.
# At time 5.3 ns, the overlap of CORE-TRIO with PL is 15.12%.
# At time 5.4 ns, the overlap of CORE-TRIO with PL is 14.69%.
# At time 5.5 ns, the overlap of CORE-TRIO with PL is 14.43%.
# At time 5.6 ns, the overlap of CORE-TRIO with PL is 14.62%.
# At time 5.7 ns, the overlap of CORE-TRIO with PL is 14.52%.
# At time 5.8 ns, the overlap of CORE-TRIO with PL is 12.99%.
# At time 5.9 ns, the overlap of CORE-TRIO with PL is 13.36%.
# At time 6.0 ns, the overlap of CORE-TRIO with PL is 13.55%.
# At time 6.1 ns, the overlap of CORE-TRIO with PL is 12.94%.
# At time 6.2 ns, the overlap of CORE-TRIO with PL is 13.02%.
# At time 6.3 ns, the overlap of CORE-TRIO with PL is 12.41%.
# At time 6.4 ns, the overlap of CORE-TRIO with PL is 12.42%.
# At time 6.5 ns, the overlap of CORE-TRIO with PL is 12.89%.
# At time 6.6 ns, the overlap of CORE-TRIO with PL is 12.40%.
# At time 6.7 ns, the overlap of CORE-TRIO with PL is 11.67%.
# At time 6.8 ns, the overlap of CORE-TRIO with PL is 11.83%.
# At time 6.9 ns, the overlap of CORE-TRIO with PL is 11.83%.
# At time 7.0 ns, the overlap of CORE-TRIO with PL is 11.57%.
# At time 7.1 ns, the overlap of CORE-TRIO with PL is 11.89%.
# At time 7.2 ns, the overlap of CORE-TRIO with PL is 11.02%.
# At time 7.3 ns, the overlap of CORE-TRIO with PL is 11.78%.
# At time 7.4 ns, the overlap of CORE-TRIO with PL is 10.92%.
# At time 7.5 ns, the overlap of CORE-TRIO with PL is 11.08%.
# At time 7.6 ns, the overlap of CORE-TRIO with PL is 10.92%.
# At time 7.7 ns, the overlap of CORE-TRIO with PL is 10.51%.
# At time 7.8 ns, the overlap of CORE-TRIO with PL is 11.19%.
# At time 7.9 ns, the overlap of CORE-TRIO with PL is 11.45%.
# At time 8.0 ns, the overlap of CORE-TRIO with PL is 11.45%.
# At time 8.1 ns, the overlap of CORE-TRIO with PL is 11.53%.
# At time 8.2 ns, the overlap of CORE-TRIO with PL is 11.46%.
# At time 8.3 ns, the overlap of CORE-TRIO with PL is 10.67%.
# At time 8.4 ns, the overlap of CORE-TRIO with PL is 11.48%.
# At time 8.5 ns, the overlap of CORE-TRIO with PL is 12.47%.
# At time 8.6 ns, the overlap of CORE-TRIO with PL is 12.46%.
# At time 8.7 ns, the overlap of CORE-TRIO with PL is 11.95%.
# At time 8.8 ns, the overlap of CORE-TRIO with PL is 12.59%.
# At time 8.9 ns, the overlap of CORE-TRIO with PL is 13.24%.
# At time 9.0 ns, the overlap of CORE-TRIO with PL is 13.68%.
# At time 9.1 ns, the overlap of CORE-TRIO with PL is 13.73%.
# At time 9.2 ns, the overlap of CORE-TRIO with PL is 13.20%.
# At time 9.3 ns, the overlap of CORE-TRIO with PL is 13.55%.
# At time 9.4 ns, the overlap of CORE-TRIO with PL is 13.38%.
# At time 9.5 ns, the overlap of CORE-TRIO with PL is 13.37%.
# At time 9.6 ns, the overlap of CORE-TRIO with PL is 13.80%.
# At time 9.7 ns, the overlap of CORE-TRIO with PL is 14.11%.
# At time 0.0 ns, the overlap of CORE-TRIO with PL is 11.13%.
# At time 0.0010000000328495406 ns, the overlap of CORE-TRIO with PL is 11.29%.
# At time 0.002000000065699081 ns, the overlap of CORE-TRIO with PL is 10.92%.
# At time 0.0030000000985486216 ns, the overlap of CORE-TRIO with PL is 10.56%.
# At time 0.004000000131398162 ns, the overlap of CORE-TRIO with PL is 10.77%.
# At time 0.005000000164247703 ns, the overlap of CORE-TRIO with PL is 10.19%.
# At time 0.006000000197097243 ns, the overlap of CORE-TRIO with PL is 10.90%.
# At time 0.007000000229946784 ns, the overlap of CORE-TRIO with PL is 10.09%.
# At time 0.008000000262796325 ns, the overlap of CORE-TRIO with PL is 11.01%.
# At time 0.009000000295645865 ns, the overlap of CORE-TRIO with PL is 11.08%.
# At time 0.010000000328495406 ns, the overlap of CORE-TRIO with PL is 11.69%.
# At time 0.011000000361344946 ns, the overlap of CORE-TRIO with PL is 11.52%.
# At time 0.012000000394194486 ns, the overlap of CORE-TRIO with PL is 11.56%.
# At time 0.013000000427044028 ns, the overlap of CORE-TRIO with PL is 11.91%.
# At time 0.014000000459893568 ns, the overlap of CORE-TRIO with PL is 11.38%.
# At time 0.01500000049274311 ns, the overlap of CORE-TRIO with PL is 12.37%.
# At time 0.01600000052559265 ns, the overlap of CORE-TRIO with PL is 12.60%.
# At time 0.017000000558442193 ns, the overlap of CORE-TRIO with PL is 12.41%.
# At time 0.01800000059129173 ns, the overlap of CORE-TRIO with PL is 11.67%.
# At time 0.019000000624141273 ns, the overlap of CORE-TRIO with PL is 12.85%.
# At time 0.020000000656990813 ns, the overlap of CORE-TRIO with PL is 12.34%.
# At time 0.021000000689840353 ns, the overlap of CORE-TRIO with PL is 11.52%.
# At time 0.022000000722689893 ns, the overlap of CORE-TRIO with PL is 11.05%.
# At time 0.023000000755539436 ns, the overlap of CORE-TRIO with PL is 10.41%.
# At time 0.024000000788388973 ns, the overlap of CORE-TRIO with PL is 11.18%.
# At time 0.025000000821238516 ns, the overlap of CORE-TRIO with PL is 10.81%.
# At time 0.026000000854088056 ns, the overlap of CORE-TRIO with PL is 10.94%.
# At time 0.0270000008869376 ns, the overlap of CORE-TRIO with PL is 11.48%.
# At time 0.028000000919787136 ns, the overlap of CORE-TRIO with PL is 11.10%.
# At time 0.02900000095263668 ns, the overlap of CORE-TRIO with PL is 11.84%.
# At time 0.03000000098548622 ns, the overlap of CORE-TRIO with PL is 11.51%.
# At time 0.03100000101833576 ns, the overlap of CORE-TRIO with PL is 11.05%.
# At time 0.0320000010511853 ns, the overlap of CORE-TRIO with PL is 11.90%.
# At time 0.03300000108403484 ns, the overlap of CORE-TRIO with PL is 12.07%.
# At time 0.034000001116884386 ns, the overlap of CORE-TRIO with PL is 12.22%.
# At time 0.03500000114973392 ns, the overlap of CORE-TRIO with PL is 12.60%.
# At time 0.03600000118258346 ns, the overlap of CORE-TRIO with PL is 12.90%.
# At time 0.037000001215433 ns, the overlap of CORE-TRIO with PL is 13.02%.
# At time 0.038000001248282546 ns, the overlap of CORE-TRIO with PL is 12.86%.
# At time 0.03900000128113208 ns, the overlap of CORE-TRIO with PL is 12.11%.
# At time 0.040000001313981626 ns, the overlap of CORE-TRIO with PL is 11.39%.
# At time 0.04100000134683117 ns, the overlap of CORE-TRIO with PL is 12.16%.
# At time 0.042000001379680706 ns, the overlap of CORE-TRIO with PL is 11.62%.
# At time 0.04300000141253025 ns, the overlap of CORE-TRIO with PL is 11.68%.
# At time 0.044000001445379786 ns, the overlap of CORE-TRIO with PL is 12.17%.
# At time 0.04500000147822933 ns, the overlap of CORE-TRIO with PL is 11.68%.
# At time 0.04600000151107887 ns, the overlap of CORE-TRIO with PL is 12.48%.
# At time 0.047000001543928416 ns, the overlap of CORE-TRIO with PL is 12.30%.
# At time 0.048000001576777945 ns, the overlap of CORE-TRIO with PL is 12.24%.
# At time 0.04900000160962749 ns, the overlap of CORE-TRIO with PL is 12.14%.
# At time 0.05000000164247703 ns, the overlap of CORE-TRIO with PL is 11.86%.
# At time 0.051000001675326576 ns, the overlap of CORE-TRIO with PL is 12.57%.
# At time 0.05200000170817611 ns, the overlap of CORE-TRIO with PL is 12.20%.
# At time 0.053000001741025655 ns, the overlap of CORE-TRIO with PL is 12.80%.
# At time 0.0540000017738752 ns, the overlap of CORE-TRIO with PL is 12.17%.
# At time 0.055000001806724735 ns, the overlap of CORE-TRIO with PL is 11.71%.
# At time 0.05600000183957427 ns, the overlap of CORE-TRIO with PL is 11.92%.
# At time 0.057000001872423815 ns, the overlap of CORE-TRIO with PL is 11.51%.
# At time 0.05800000190527336 ns, the overlap of CORE-TRIO with PL is 10.85%.
# At time 0.0590000019381229 ns, the overlap of CORE-TRIO with PL is 11.38%.
# At time 0.06000000197097244 ns, the overlap of CORE-TRIO with PL is 10.83%.
# At time 0.061000002003821975 ns, the overlap of CORE-TRIO with PL is 10.84%.
# At time 0.06200000203667152 ns, the overlap of CORE-TRIO with PL is 10.79%.
# At time 0.06300000206952105 ns, the overlap of CORE-TRIO with PL is 11.57%.
# At time 0.0640000021023706 ns, the overlap of CORE-TRIO with PL is 11.02%.
# At time 0.06500000213522014 ns, the overlap of CORE-TRIO with PL is 11.03%.
# At time 0.06600000216806969 ns, the overlap of CORE-TRIO with PL is 9.92%.
# At time 0.06700000220091923 ns, the overlap of CORE-TRIO with PL is 10.70%.
# At time 0.06800000223376877 ns, the overlap of CORE-TRIO with PL is 10.80%.
# At time 0.06900000226661832 ns, the overlap of CORE-TRIO with PL is 11.16%.
# At time 0.07000000229946785 ns, the overlap of CORE-TRIO with PL is 11.37%.
# At time 0.07100000233231737 ns, the overlap of CORE-TRIO with PL is 10.94%.
# At time 0.07200000236516692 ns, the overlap of CORE-TRIO with PL is 11.50%.
# At time 0.07300000239801646 ns, the overlap of CORE-TRIO with PL is 11.10%.
# At time 0.074000002430866 ns, the overlap of CORE-TRIO with PL is 11.49%.
# At time 0.07500000246371555 ns, the overlap of CORE-TRIO with PL is 10.81%.
# At time 0.07600000249656509 ns, the overlap of CORE-TRIO with PL is 11.83%.
# At time 0.07700000252941464 ns, the overlap of CORE-TRIO with PL is 11.55%.
# At time 0.07800000256226416 ns, the overlap of CORE-TRIO with PL is 11.49%.
# At time 0.07900000259511371 ns, the overlap of CORE-TRIO with PL is 11.68%.
# At time 0.08000000262796325 ns, the overlap of CORE-TRIO with PL is 11.34%.
# At time 0.0810000026608128 ns, the overlap of CORE-TRIO with PL is 10.67%.
# At time 0.08200000269366234 ns, the overlap of CORE-TRIO with PL is 10.91%.
# At time 0.08300000272651188 ns, the overlap of CORE-TRIO with PL is 10.85%.
# At time 0.08400000275936141 ns, the overlap of CORE-TRIO with PL is 11.47%.
# At time 0.08500000279221095 ns, the overlap of CORE-TRIO with PL is 11.48%.
# At time 0.0860000028250605 ns, the overlap of CORE-TRIO with PL is 11.32%.
# At time 0.08700000285791003 ns, the overlap of CORE-TRIO with PL is 11.47%.
# At time 0.08800000289075957 ns, the overlap of CORE-TRIO with PL is 12.17%.
# At time 0.08900000292360911 ns, the overlap of CORE-TRIO with PL is 10.92%.
# At time 0.09000000295645866 ns, the overlap of CORE-TRIO with PL is 10.98%.
# At time 0.0910000029893082 ns, the overlap of CORE-TRIO with PL is 11.42%.
# At time 0.09200000302215774 ns, the overlap of CORE-TRIO with PL is 10.74%.
# At time 0.09300000305500729 ns, the overlap of CORE-TRIO with PL is 11.55%.
# At time 0.09400000308785683 ns, the overlap of CORE-TRIO with PL is 10.97%.
# At time 0.09500000312070636 ns, the overlap of CORE-TRIO with PL is 11.50%.
# At time 0.09600000315355589 ns, the overlap of CORE-TRIO with PL is 11.87%.
# At time 0.09700000318640543 ns, the overlap of CORE-TRIO with PL is 11.93%.
# At time 0.09800000321925498 ns, the overlap of CORE-TRIO with PL is 11.92%.
# At time 0.09900000325210452 ns, the overlap of CORE-TRIO with PL is 11.94%.
# At time 0.10000000328495406 ns, the overlap of CORE-TRIO with PL is 12.04%.
# At time 0.10100000331780361 ns, the overlap of CORE-TRIO with PL is 12.12%.
# At time 0.10200000335065315 ns, the overlap of CORE-TRIO with PL is 11.76%.
# At time 0.10300000338350268 ns, the overlap of CORE-TRIO with PL is 12.25%.
# At time 0.10400000341635222 ns, the overlap of CORE-TRIO with PL is 11.68%.
# At time 0.10500000344920177 ns, the overlap of CORE-TRIO with PL is 11.89%.
# At time 0.10600000348205131 ns, the overlap of CORE-TRIO with PL is 12.56%.
# At time 0.10700000351490085 ns, the overlap of CORE-TRIO with PL is 13.00%.
# At time 0.1080000035477504 ns, the overlap of CORE-TRIO with PL is 12.62%.
# At time 0.10900000358059993 ns, the overlap of CORE-TRIO with PL is 12.56%.
# At time 0.11000000361344947 ns, the overlap of CORE-TRIO with PL is 12.45%.
# At time 0.111000003646299 ns, the overlap of CORE-TRIO with PL is 12.79%.
# At time 0.11200000367914854 ns, the overlap of CORE-TRIO with PL is 12.63%.
# At time 0.11300000371199809 ns, the overlap of CORE-TRIO with PL is 12.76%.
# At time 0.11400000374484763 ns, the overlap of CORE-TRIO with PL is 12.66%.
# At time 0.11500000377769717 ns, the overlap of CORE-TRIO with PL is 12.52%.
# At time 0.11600000381054672 ns, the overlap of CORE-TRIO with PL is 12.61%.
# At time 0.11700000384339626 ns, the overlap of CORE-TRIO with PL is 13.04%.
# At time 0.1180000038762458 ns, the overlap of CORE-TRIO with PL is 13.56%.
# At time 0.11900000390909535 ns, the overlap of CORE-TRIO with PL is 12.80%.
# At time 0.12000000394194488 ns, the overlap of CORE-TRIO with PL is 13.68%.
# At time 0.12100000397479442 ns, the overlap of CORE-TRIO with PL is 12.86%.
# At time 0.12200000400764395 ns, the overlap of CORE-TRIO with PL is 13.75%.
# At time 0.1230000040404935 ns, the overlap of CORE-TRIO with PL is 12.44%.
# At time 0.12400000407334304 ns, the overlap of CORE-TRIO with PL is 12.40%.
# At time 0.12500000410619258 ns, the overlap of CORE-TRIO with PL is 12.11%.
# At time 0.1260000041390421 ns, the overlap of CORE-TRIO with PL is 10.93%.
# At time 0.12700000417189167 ns, the overlap of CORE-TRIO with PL is 11.17%.
# At time 0.1280000042047412 ns, the overlap of CORE-TRIO with PL is 11.88%.
# At time 0.12900000423759073 ns, the overlap of CORE-TRIO with PL is 11.30%.
# At time 0.13000000427044028 ns, the overlap of CORE-TRIO with PL is 12.23%.
# At time 0.1310000043032898 ns, the overlap of CORE-TRIO with PL is 11.20%.
# At time 0.13200000433613937 ns, the overlap of CORE-TRIO with PL is 11.66%.
# At time 0.1330000043689889 ns, the overlap of CORE-TRIO with PL is 11.96%.
# At time 0.13400000440183846 ns, the overlap of CORE-TRIO with PL is 11.39%.
# At time 0.135000004434688 ns, the overlap of CORE-TRIO with PL is 11.71%.
# At time 0.13600000446753754 ns, the overlap of CORE-TRIO with PL is 11.78%.
# At time 0.13700000450038707 ns, the overlap of CORE-TRIO with PL is 12.54%.
# At time 0.13800000453323663 ns, the overlap of CORE-TRIO with PL is 12.58%.
# At time 0.13900000456608616 ns, the overlap of CORE-TRIO with PL is 12.97%.
# At time 0.1400000045989357 ns, the overlap of CORE-TRIO with PL is 11.85%.
# At time 0.14100000463178522 ns, the overlap of CORE-TRIO with PL is 12.57%.
# At time 0.14200000466463475 ns, the overlap of CORE-TRIO with PL is 12.42%.
# At time 0.1430000046974843 ns, the overlap of CORE-TRIO with PL is 12.49%.
# At time 0.14400000473033384 ns, the overlap of CORE-TRIO with PL is 12.74%.
# At time 0.1450000047631834 ns, the overlap of CORE-TRIO with PL is 12.93%.
# At time 0.14600000479603292 ns, the overlap of CORE-TRIO with PL is 12.94%.
# At time 0.14700000482888248 ns, the overlap of CORE-TRIO with PL is 12.89%.
# At time 0.148000004861732 ns, the overlap of CORE-TRIO with PL is 12.55%.
# At time 0.14900000489458157 ns, the overlap of CORE-TRIO with PL is 12.57%.
# At time 0.1500000049274311 ns, the overlap of CORE-TRIO with PL is 12.24%.
# At time 0.15100000496028065 ns, the overlap of CORE-TRIO with PL is 13.22%.
# At time 0.15200000499313018 ns, the overlap of CORE-TRIO with PL is 13.41%.
# At time 0.15300000502597974 ns, the overlap of CORE-TRIO with PL is 12.49%.
# At time 0.15400000505882927 ns, the overlap of CORE-TRIO with PL is 12.19%.
# At time 0.1550000050916788 ns, the overlap of CORE-TRIO with PL is 12.63%.
# At time 0.15600000512452833 ns, the overlap of CORE-TRIO with PL is 11.80%.
# At time 0.15700000515737786 ns, the overlap of CORE-TRIO with PL is 11.84%.
# At time 0.15800000519022742 ns, the overlap of CORE-TRIO with PL is 11.49%.
# At time 0.15900000522307695 ns, the overlap of CORE-TRIO with PL is 11.97%.
# At time 0.1600000052559265 ns, the overlap of CORE-TRIO with PL is 11.99%.
# At time 0.16100000528877603 ns, the overlap of CORE-TRIO with PL is 12.20%.
# At time 0.1620000053216256 ns, the overlap of CORE-TRIO with PL is 12.03%.
# At time 0.16300000535447512 ns, the overlap of CORE-TRIO with PL is 12.00%.
# At time 0.16400000538732468 ns, the overlap of CORE-TRIO with PL is 12.98%.
# At time 0.1650000054201742 ns, the overlap of CORE-TRIO with PL is 13.64%.
# At time 0.16600000545302376 ns, the overlap of CORE-TRIO with PL is 12.75%.
# At time 0.1670000054858733 ns, the overlap of CORE-TRIO with PL is 13.53%.
# At time 0.16800000551872282 ns, the overlap of CORE-TRIO with PL is 13.91%.
# At time 0.16900000555157238 ns, the overlap of CORE-TRIO with PL is 12.17%.
# At time 0.1700000055844219 ns, the overlap of CORE-TRIO with PL is 11.99%.
# At time 0.17100000561727147 ns, the overlap of CORE-TRIO with PL is 12.59%.
# At time 0.172000005650121 ns, the overlap of CORE-TRIO with PL is 11.60%.
# At time 0.17300000568297053 ns, the overlap of CORE-TRIO with PL is 11.46%.
# At time 0.17400000571582006 ns, the overlap of CORE-TRIO with PL is 11.67%.
# At time 0.1750000057486696 ns, the overlap of CORE-TRIO with PL is 11.16%.
# At time 0.17600000578151914 ns, the overlap of CORE-TRIO with PL is 12.59%.
# At time 0.1770000058143687 ns, the overlap of CORE-TRIO with PL is 11.99%.
# At time 0.17800000584721823 ns, the overlap of CORE-TRIO with PL is 11.19%.
# At time 0.1790000058800678 ns, the overlap of CORE-TRIO with PL is 11.77%.
# At time 0.18000000591291732 ns, the overlap of CORE-TRIO with PL is 12.65%.
# At time 0.18100000594576685 ns, the overlap of CORE-TRIO with PL is 11.96%.
# At time 0.1820000059786164 ns, the overlap of CORE-TRIO with PL is 11.93%.
# At time 0.18300000601146593 ns, the overlap of CORE-TRIO with PL is 12.44%.
# At time 0.1840000060443155 ns, the overlap of CORE-TRIO with PL is 11.96%.
# At time 0.18500000607716502 ns, the overlap of CORE-TRIO with PL is 11.62%.
# At time 0.18600000611001458 ns, the overlap of CORE-TRIO with PL is 11.99%.
# At time 0.1870000061428641 ns, the overlap of CORE-TRIO with PL is 11.46%.
# At time 0.18800000617571366 ns, the overlap of CORE-TRIO with PL is 11.68%.
# At time 0.18900000620856316 ns, the overlap of CORE-TRIO with PL is 12.56%.
# At time 0.19000000624141272 ns, the overlap of CORE-TRIO with PL is 12.01%.
# At time 0.19100000627426225 ns, the overlap of CORE-TRIO with PL is 12.30%.
# At time 0.19200000630711178 ns, the overlap of CORE-TRIO with PL is 12.70%.
# At time 0.19300000633996134 ns, the overlap of CORE-TRIO with PL is 11.95%.
# At time 0.19400000637281087 ns, the overlap of CORE-TRIO with PL is 13.12%.
# At time 0.19500000640566043 ns, the overlap of CORE-TRIO with PL is 12.17%.
# At time 0.19600000643850995 ns, the overlap of CORE-TRIO with PL is 12.27%.
# At time 0.1970000064713595 ns, the overlap of CORE-TRIO with PL is 11.85%.
# At time 0.19800000650420904 ns, the overlap of CORE-TRIO with PL is 11.36%.
# At time 0.1990000065370586 ns, the overlap of CORE-TRIO with PL is 11.50%.
# At time 0.20000000656990813 ns, the overlap of CORE-TRIO with PL is 11.55%.
# At time 0.20100000660275769 ns, the overlap of CORE-TRIO with PL is 11.53%.
# At time 0.20200000663560722 ns, the overlap of CORE-TRIO with PL is 11.89%.
# At time 0.20300000666845677 ns, the overlap of CORE-TRIO with PL is 12.67%.
# At time 0.2040000067013063 ns, the overlap of CORE-TRIO with PL is 12.86%.
# At time 0.2050000067341558 ns, the overlap of CORE-TRIO with PL is 12.96%.
# At time 0.20600000676700536 ns, the overlap of CORE-TRIO with PL is 12.54%.
# At time 0.2070000067998549 ns, the overlap of CORE-TRIO with PL is 11.92%.
# At time 0.20800000683270445 ns, the overlap of CORE-TRIO with PL is 12.99%.
# At time 0.20900000686555398 ns, the overlap of CORE-TRIO with PL is 12.41%.
# At time 0.21000000689840354 ns, the overlap of CORE-TRIO with PL is 13.08%.
# At time 0.21100000693125306 ns, the overlap of CORE-TRIO with PL is 13.74%.
# At time 0.21200000696410262 ns, the overlap of CORE-TRIO with PL is 13.02%.
# At time 0.21300000699695215 ns, the overlap of CORE-TRIO with PL is 13.26%.
# At time 0.2140000070298017 ns, the overlap of CORE-TRIO with PL is 12.60%.
# At time 0.21500000706265124 ns, the overlap of CORE-TRIO with PL is 12.39%.
# At time 0.2160000070955008 ns, the overlap of CORE-TRIO with PL is 12.40%.
# At time 0.21700000712835033 ns, the overlap of CORE-TRIO with PL is 13.53%.
# At time 0.21800000716119985 ns, the overlap of CORE-TRIO with PL is 13.28%.
# At time 0.2190000071940494 ns, the overlap of CORE-TRIO with PL is 12.91%.
# At time 0.22000000722689894 ns, the overlap of CORE-TRIO with PL is 12.92%.
# At time 0.2210000072597485 ns, the overlap of CORE-TRIO with PL is 11.82%.
# At time 0.222000007292598 ns, the overlap of CORE-TRIO with PL is 12.47%.
# At time 0.22300000732544756 ns, the overlap of CORE-TRIO with PL is 12.11%.
# At time 0.2240000073582971 ns, the overlap of CORE-TRIO with PL is 11.61%.
# At time 0.22500000739114664 ns, the overlap of CORE-TRIO with PL is 11.78%.
# At time 0.22600000742399617 ns, the overlap of CORE-TRIO with PL is 11.55%.
# At time 0.22700000745684573 ns, the overlap of CORE-TRIO with PL is 11.24%.
# At time 0.22800000748969526 ns, the overlap of CORE-TRIO with PL is 11.20%.
# At time 0.22900000752254482 ns, the overlap of CORE-TRIO with PL is 11.88%.
# At time 0.23000000755539435 ns, the overlap of CORE-TRIO with PL is 12.03%.
# At time 0.23100000758824388 ns, the overlap of CORE-TRIO with PL is 12.74%.
# At time 0.23200000762109343 ns, the overlap of CORE-TRIO with PL is 12.02%.
# At time 0.23300000765394296 ns, the overlap of CORE-TRIO with PL is 12.65%.
# At time 0.23400000768679252 ns, the overlap of CORE-TRIO with PL is 11.94%.
# At time 0.23500000771964205 ns, the overlap of CORE-TRIO with PL is 12.52%.
# At time 0.2360000077524916 ns, the overlap of CORE-TRIO with PL is 11.69%.
# At time 0.23700000778534114 ns, the overlap of CORE-TRIO with PL is 11.66%.
# At time 0.2380000078181907 ns, the overlap of CORE-TRIO with PL is 11.43%.
# At time 0.2390000078510402 ns, the overlap of CORE-TRIO with PL is 12.22%.
# At time 0.24000000788388975 ns, the overlap of CORE-TRIO with PL is 12.49%.
# At time 0.24100000791673928 ns, the overlap of CORE-TRIO with PL is 11.54%.
# At time 0.24200000794958884 ns, the overlap of CORE-TRIO with PL is 12.16%.
# At time 0.24300000798243837 ns, the overlap of CORE-TRIO with PL is 12.46%.
# At time 0.2440000080152879 ns, the overlap of CORE-TRIO with PL is 12.44%.
# At time 0.24500000804813746 ns, the overlap of CORE-TRIO with PL is 11.84%.
# At time 0.246000008080987 ns, the overlap of CORE-TRIO with PL is 11.03%.
# At time 0.24700000811383654 ns, the overlap of CORE-TRIO with PL is 11.64%.
# At time 0.24800000814668607 ns, the overlap of CORE-TRIO with PL is 11.37%.
# At time 0.24900000817953563 ns, the overlap of CORE-TRIO with PL is 11.44%.
# At time 0.25000000821238516 ns, the overlap of CORE-TRIO with PL is 11.54%.
# At time 0.2510000082452347 ns, the overlap of CORE-TRIO with PL is 11.65%.
# At time 0.2520000082780842 ns, the overlap of CORE-TRIO with PL is 11.91%.
# At time 0.2530000083109338 ns, the overlap of CORE-TRIO with PL is 11.97%.
# At time 0.25400000834378333 ns, the overlap of CORE-TRIO with PL is 12.09%.
# At time 0.2550000083766329 ns, the overlap of CORE-TRIO with PL is 11.61%.
# At time 0.2560000084094824 ns, the overlap of CORE-TRIO with PL is 11.72%.
# At time 0.25700000844233195 ns, the overlap of CORE-TRIO with PL is 11.28%.
# At time 0.25800000847518145 ns, the overlap of CORE-TRIO with PL is 10.71%.
# At time 0.25900000850803107 ns, the overlap of CORE-TRIO with PL is 11.27%.
# At time 0.26000000854088057 ns, the overlap of CORE-TRIO with PL is 11.38%.
# At time 0.2610000085737301 ns, the overlap of CORE-TRIO with PL is 11.76%.
# At time 0.2620000086065796 ns, the overlap of CORE-TRIO with PL is 11.90%.
# At time 0.2630000086394292 ns, the overlap of CORE-TRIO with PL is 11.58%.
# At time 0.26400000867227874 ns, the overlap of CORE-TRIO with PL is 11.53%.
# At time 0.26500000870512824 ns, the overlap of CORE-TRIO with PL is 11.66%.
# At time 0.2660000087379778 ns, the overlap of CORE-TRIO with PL is 11.08%.
# At time 0.26700000877082736 ns, the overlap of CORE-TRIO with PL is 10.05%.
# At time 0.2680000088036769 ns, the overlap of CORE-TRIO with PL is 10.76%.
# At time 0.2690000088365264 ns, the overlap of CORE-TRIO with PL is 11.10%.
# At time 0.270000008869376 ns, the overlap of CORE-TRIO with PL is 11.15%.
# At time 0.2710000089022255 ns, the overlap of CORE-TRIO with PL is 11.23%.
# At time 0.2720000089350751 ns, the overlap of CORE-TRIO with PL is 11.39%.
# At time 0.2730000089679246 ns, the overlap of CORE-TRIO with PL is 12.11%.
# At time 0.27400000900077415 ns, the overlap of CORE-TRIO with PL is 11.75%.
# At time 0.27500000903362365 ns, the overlap of CORE-TRIO with PL is 11.77%.
# At time 0.27600000906647326 ns, the overlap of CORE-TRIO with PL is 11.63%.
# At time 0.27700000909932276 ns, the overlap of CORE-TRIO with PL is 11.57%.
# At time 0.2780000091321723 ns, the overlap of CORE-TRIO with PL is 11.36%.
# At time 0.2790000091650218 ns, the overlap of CORE-TRIO with PL is 11.80%.
# At time 0.2800000091978714 ns, the overlap of CORE-TRIO with PL is 12.00%.
# At time 0.28100000923072094 ns, the overlap of CORE-TRIO with PL is 12.15%.
# At time 0.28200000926357044 ns, the overlap of CORE-TRIO with PL is 11.88%.
# At time 0.28300000929642 ns, the overlap of CORE-TRIO with PL is 11.90%.
# At time 0.2840000093292695 ns, the overlap of CORE-TRIO with PL is 12.05%.
# At time 0.2850000093621191 ns, the overlap of CORE-TRIO with PL is 10.50%.
# At time 0.2860000093949686 ns, the overlap of CORE-TRIO with PL is 11.28%.
# At time 0.28700000942781817 ns, the overlap of CORE-TRIO with PL is 10.37%.
# At time 0.28800000946066767 ns, the overlap of CORE-TRIO with PL is 10.62%.
# At time 0.2890000094935173 ns, the overlap of CORE-TRIO with PL is 10.32%.
# At time 0.2900000095263668 ns, the overlap of CORE-TRIO with PL is 10.18%.
# At time 0.29100000955921634 ns, the overlap of CORE-TRIO with PL is 10.28%.
# At time 0.29200000959206585 ns, the overlap of CORE-TRIO with PL is 10.40%.
# At time 0.29300000962491546 ns, the overlap of CORE-TRIO with PL is 10.39%.
# At time 0.29400000965776496 ns, the overlap of CORE-TRIO with PL is 10.57%.
# At time 0.2950000096906145 ns, the overlap of CORE-TRIO with PL is 10.24%.
# At time 0.296000009723464 ns, the overlap of CORE-TRIO with PL is 9.48%.
# At time 0.2970000097563135 ns, the overlap of CORE-TRIO with PL is 10.18%.
# At time 0.29800000978916313 ns, the overlap of CORE-TRIO with PL is 9.80%.
# At time 0.29900000982201264 ns, the overlap of CORE-TRIO with PL is 9.30%.
# At time 0.3000000098548622 ns, the overlap of CORE-TRIO with PL is 9.49%.
# At time 0.3010000098877117 ns, the overlap of CORE-TRIO with PL is 10.23%.
# At time 0.3020000099205613 ns, the overlap of CORE-TRIO with PL is 9.36%.
# At time 0.3030000099534108 ns, the overlap of CORE-TRIO with PL is 10.58%.
# At time 0.30400000998626037 ns, the overlap of CORE-TRIO with PL is 9.82%.
# At time 0.30500001001910987 ns, the overlap of CORE-TRIO with PL is 10.60%.
# At time 0.3060000100519595 ns, the overlap of CORE-TRIO with PL is 10.17%.
# At time 0.307000010084809 ns, the overlap of CORE-TRIO with PL is 11.45%.
# At time 0.30800001011765854 ns, the overlap of CORE-TRIO with PL is 10.45%.
# At time 0.30900001015050804 ns, the overlap of CORE-TRIO with PL is 10.73%.
# At time 0.3100000101833576 ns, the overlap of CORE-TRIO with PL is 9.73%.
# At time 0.31100001021620716 ns, the overlap of CORE-TRIO with PL is 10.51%.
# At time 0.31200001024905666 ns, the overlap of CORE-TRIO with PL is 10.36%.
# At time 0.3130000102819062 ns, the overlap of CORE-TRIO with PL is 9.61%.
# At time 0.3140000103147557 ns, the overlap of CORE-TRIO with PL is 9.81%.
# At time 0.31500001034760533 ns, the overlap of CORE-TRIO with PL is 10.04%.
# At time 0.31600001038045483 ns, the overlap of CORE-TRIO with PL is 9.81%.
# At time 0.3170000104133044 ns, the overlap of CORE-TRIO with PL is 10.40%.
# At time 0.3180000104461539 ns, the overlap of CORE-TRIO with PL is 10.37%.
# At time 0.3190000104790035 ns, the overlap of CORE-TRIO with PL is 10.12%.
# At time 0.320000010511853 ns, the overlap of CORE-TRIO with PL is 10.77%.
# At time 0.32100001054470256 ns, the overlap of CORE-TRIO with PL is 11.17%.
# At time 0.32200001057755206 ns, the overlap of CORE-TRIO with PL is 11.20%.
# At time 0.3230000106104016 ns, the overlap of CORE-TRIO with PL is 11.63%.
# At time 0.3240000106432512 ns, the overlap of CORE-TRIO with PL is 11.10%.
# At time 0.32500001067610074 ns, the overlap of CORE-TRIO with PL is 11.73%.
# At time 0.32600001070895024 ns, the overlap of CORE-TRIO with PL is 13.16%.
# At time 0.3270000107417998 ns, the overlap of CORE-TRIO with PL is 12.81%.
# At time 0.32800001077464935 ns, the overlap of CORE-TRIO with PL is 12.45%.
# At time 0.32900001080749885 ns, the overlap of CORE-TRIO with PL is 13.04%.
# At time 0.3300000108403484 ns, the overlap of CORE-TRIO with PL is 11.58%.
# At time 0.3310000108731979 ns, the overlap of CORE-TRIO with PL is 13.06%.
# At time 0.3320000109060475 ns, the overlap of CORE-TRIO with PL is 11.66%.
# At time 0.33300001093889703 ns, the overlap of CORE-TRIO with PL is 11.19%.
# At time 0.3340000109717466 ns, the overlap of CORE-TRIO with PL is 11.48%.
# At time 0.3350000110045961 ns, the overlap of CORE-TRIO with PL is 11.34%.
# At time 0.33600001103744565 ns, the overlap of CORE-TRIO with PL is 12.02%.
# At time 0.3370000110702952 ns, the overlap of CORE-TRIO with PL is 11.58%.
# At time 0.33800001110314476 ns, the overlap of CORE-TRIO with PL is 11.10%.
# At time 0.33900001113599426 ns, the overlap of CORE-TRIO with PL is 10.05%.
# At time 0.3400000111688438 ns, the overlap of CORE-TRIO with PL is 9.93%.
# At time 0.3410000112016934 ns, the overlap of CORE-TRIO with PL is 10.87%.
# At time 0.34200001123454293 ns, the overlap of CORE-TRIO with PL is 10.84%.
# At time 0.34300001126739244 ns, the overlap of CORE-TRIO with PL is 10.72%.
# At time 0.344000011300242 ns, the overlap of CORE-TRIO with PL is 11.36%.
# At time 0.34500001133309155 ns, the overlap of CORE-TRIO with PL is 11.65%.
# At time 0.34600001136594105 ns, the overlap of CORE-TRIO with PL is 11.66%.
# At time 0.3470000113987906 ns, the overlap of CORE-TRIO with PL is 11.53%.
# At time 0.3480000114316401 ns, the overlap of CORE-TRIO with PL is 11.86%.
# At time 0.34900001146448967 ns, the overlap of CORE-TRIO with PL is 11.61%.
# At time 0.3500000114973392 ns, the overlap of CORE-TRIO with PL is 11.62%.
# At time 0.3510000115301888 ns, the overlap of CORE-TRIO with PL is 10.77%.
# At time 0.3520000115630383 ns, the overlap of CORE-TRIO with PL is 10.66%.
# At time 0.35300001159588784 ns, the overlap of CORE-TRIO with PL is 11.21%.
# At time 0.3540000116287374 ns, the overlap of CORE-TRIO with PL is 11.23%.
# At time 0.35500001166158696 ns, the overlap of CORE-TRIO with PL is 11.76%.
# At time 0.35600001169443646 ns, the overlap of CORE-TRIO with PL is 11.32%.
# At time 0.357000011727286 ns, the overlap of CORE-TRIO with PL is 11.97%.
# At time 0.3580000117601356 ns, the overlap of CORE-TRIO with PL is 11.09%.
# At time 0.35900001179298513 ns, the overlap of CORE-TRIO with PL is 12.74%.
# ...
# At time 0.5930000194797777 ns, the overlap of CORE-TRIO with PL is 12.26%.
# At time 0.594000019512627 ns, the overlap of CORE-TRIO with PL is 12.66%.
# At time 0.5950000195454767 ns, the overlap of CORE-TRIO with PL is 11.94%.
# At time 0.5960000195783263 ns, the overlap of CORE-TRIO with PL is 12.34%.
# At time 0.5970000196111758 ns, the overlap of CORE-TRIO with PL is 11.77%.
# At time 0.5980000196440253 ns, the overlap of CORE-TRIO with PL is 12.33%.
# At time 0.5990000196768749 ns, the overlap of CORE-TRIO with PL is 12.00%.
# At time 0.6000000197097244 ns, the overlap of CORE-TRIO with PL is 12.08%.
# At time 0.601000019742574 ns, the overlap of CORE-TRIO with PL is 11.68%.
# At time 0.6020000197754234 ns, the overlap of CORE-TRIO with PL is 11.89%.
# At time 0.603000019808273 ns, the overlap of CORE-TRIO with PL is 12.54%.
# At time 0.6040000198411226 ns, the overlap of CORE-TRIO with PL is 11.96%.
# At time 0.6050000198739721 ns, the overlap of CORE-TRIO with PL is 11.78%.
# At time 0.6060000199068216 ns, the overlap of CORE-TRIO with PL is 12.18%.
# At time 0.6070000199396711 ns, the overlap of CORE-TRIO with PL is 10.80%.
# At time 0.6080000199725207 ns, the overlap of CORE-TRIO with PL is 11.64%.
# At time 0.6090000200053702 ns, the overlap of CORE-TRIO with PL is 12.04%.
# At time 0.6100000200382197 ns, the overlap of CORE-TRIO with PL is 12.18%.
# At time 0.6110000200710693 ns, the overlap of CORE-TRIO with PL is 12.17%.
# At time 0.612000020103919 ns, the overlap of CORE-TRIO with PL is 13.18%.
# At time 0.6130000201367684 ns, the overlap of CORE-TRIO with PL is 12.32%.
# At time 0.614000020169618 ns, the overlap of CORE-TRIO with PL is 12.76%.
# At time 0.6150000202024675 ns, the overlap of CORE-TRIO with PL is 11.80%.
# At time 0.6160000202353171 ns, the overlap of CORE-TRIO with PL is 11.40%.
# At time 0.6170000202681666 ns, the overlap of CORE-TRIO with PL is 11.58%.
# At time 0.6180000203010161 ns, the overlap of CORE-TRIO with PL is 12.09%.
# At time 0.6190000203338657 ns, the overlap of CORE-TRIO with PL is 13.22%.
# At time 0.6200000203667152 ns, the overlap of CORE-TRIO with PL is 12.51%.
# At time 0.6210000203995647 ns, the overlap of CORE-TRIO with PL is 11.64%.
# At time 0.6220000204324143 ns, the overlap of CORE-TRIO with PL is 13.11%.
# At time 0.6230000204652638 ns, the overlap of CORE-TRIO with PL is 12.05%.
# At time 0.6240000204981133 ns, the overlap of CORE-TRIO with PL is 11.80%.
# At time 0.6250000205309629 ns, the overlap of CORE-TRIO with PL is 12.62%.
# At time 0.6260000205638124 ns, the overlap of CORE-TRIO with PL is 11.36%.
# At time 0.627000020596662 ns, the overlap of CORE-TRIO with PL is 10.77%.
# At time 0.6280000206295114 ns, the overlap of CORE-TRIO with PL is 10.72%.
# At time 0.629000020662361 ns, the overlap of CORE-TRIO with PL is 11.89%.
# At time 0.6300000206952107 ns, the overlap of CORE-TRIO with PL is 11.86%.
# At time 0.6310000207280602 ns, the overlap of CORE-TRIO with PL is 11.70%.
# At time 96.64000028812305 ns, the overlap of CORE-TRIO with PL is 11.12%.
# At time 96.65000028815287 ns, the overlap of CORE-TRIO with PL is 11.22%.
# At time 96.66000028818269 ns, the overlap of CORE-TRIO with PL is 11.30%.
# At time 96.67000028821248 ns, the overlap of CORE-TRIO with PL is 11.17%.
# At time 96.6800002882423 ns, the overlap of CORE-TRIO with PL is 10.86%.
# At time 96.69000028827212 ns, the overlap of CORE-TRIO with PL is 10.96%.
# At time 96.70000028830194 ns, the overlap of CORE-TRIO with PL is 10.88%.
# At time 96.71000028833176 ns, the overlap of CORE-TRIO with PL is 10.89%.
# At time 96.72000028836155 ns, the overlap of CORE-TRIO with PL is 10.86%.
# At time 96.73000028839137 ns, the overlap of CORE-TRIO with PL is 10.98%.
# At time 96.74000028842119 ns, the overlap of CORE-TRIO with PL is 11.09%.
# At time 96.750000288451 ns, the overlap of CORE-TRIO with PL is 11.11%.
# At time 96.76000028848082 ns, the overlap of CORE-TRIO with PL is 11.07%.
# At time 96.77000028851062 ns, the overlap of CORE-TRIO with PL is 11.37%.
# At time 96.78000028854044 ns, the overlap of CORE-TRIO with PL is 11.25%.
# At time 96.79000028857025 ns, the overlap of CORE-TRIO with PL is 11.11%.
# At time 96.80000028860007 ns, the overlap of CORE-TRIO with PL is 10.92%.
# At time 96.8100002886299 ns, the overlap of CORE-TRIO with PL is 10.98%.
# At time 96.82000028865971 ns, the overlap of CORE-TRIO with PL is 11.06%.
# At time 96.8300002886895 ns, the overlap of CORE-TRIO with PL is 10.91%.
# At time 96.84000028871932 ns, the overlap of CORE-TRIO with PL is 11.25%.
# At time 96.85000028874914 ns, the overlap of CORE-TRIO with PL is 11.10%.
# At time 96.86000028877896 ns, the overlap of CORE-TRIO with PL is 10.93%.
# At time 96.87000028880878 ns, the overlap of CORE-TRIO with PL is 11.10%.
# At time 96.88000028883857 ns, the overlap of CORE-TRIO with PL is 11.36%.
# At time 96.89000028886839 ns, the overlap of CORE-TRIO with PL is 11.36%.
# At time 96.90000028889821 ns, the overlap of CORE-TRIO with PL is 11.30%.
# At time 96.91000028892803 ns, the overlap of CORE-TRIO with PL is 11.38%.
# At time 96.92000028895785 ns, the overlap of CORE-TRIO with PL is 11.42%.
# At time 96.93000028898764 ns, the overlap of CORE-TRIO with PL is 11.23%.
# At time 96.94000028901746 ns, the overlap of CORE-TRIO with PL is 11.11%.
# At time 96.95000028904728 ns, the overlap of CORE-TRIO with PL is 11.57%.
# At time 96.9600002890771 ns, the overlap of CORE-TRIO with PL is 11.42%.
# At time 96.97000028910692 ns, the overlap of CORE-TRIO with PL is 11.41%.
# At time 96.98000028913671 ns, the overlap of CORE-TRIO with PL is 11.39%.
# At time 96.99000028916653 ns, the overlap of CORE-TRIO with PL is 11.84%.
# At time 97.00000028919635 ns, the overlap of CORE-TRIO with PL is 11.75%.
# At time 97.01000028922617 ns, the overlap of CORE-TRIO with PL is 12.04%.
# At time 97.02000028925599 ns, the overlap of CORE-TRIO with PL is 11.75%.
# At time 97.0300002892858 ns, the overlap of CORE-TRIO with PL is 12.20%.
# At time 97.0400002893156 ns, the overlap of CORE-TRIO with PL is 12.08%.
# At time 97.05000028934542 ns, the overlap of CORE-TRIO with PL is 11.95%.
# At time 97.06000028937524 ns, the overlap of CORE-TRIO with PL is 11.94%.
# At time 97.07000028940506 ns, the overlap of CORE-TRIO with PL is 12.07%.
# At time 97.08000028943486 ns, the overlap of CORE-TRIO with PL is 12.07%.
# At time 97.09000028946467 ns, the overlap of CORE-TRIO with PL is 12.16%.
# At time 97.10000028949449 ns, the overlap of CORE-TRIO with PL is 12.01%.
# At time 97.11000028952431 ns, the overlap of CORE-TRIO with PL is 12.25%.
# At time 97.12000028955413 ns, the overlap of CORE-TRIO with PL is 12.19%.
# At time 97.13000028958395 ns, the overlap of CORE-TRIO with PL is 11.64%.
# At time 97.14000028961374 ns, the overlap of CORE-TRIO with PL is 11.10%.
# At time 97.15000028964356 ns, the overlap of CORE-TRIO with PL is 11.36%.
# At time 97.16000028967338 ns, the overlap of CORE-TRIO with PL is 11.44%.
# At time 97.1700002897032 ns, the overlap of CORE-TRIO with PL is 11.04%.
# At time 97.18000028973302 ns, the overlap of CORE-TRIO with PL is 11.68%.
# At time 97.19000028976282 ns, the overlap of CORE-TRIO with PL is 11.53%.
# At time 97.20000028979263 ns, the overlap of CORE-TRIO with PL is 11.37%.
# At time 97.21000028982245 ns, the overlap of CORE-TRIO with PL is 11.76%.
# At time 97.22000028985227 ns, the overlap of CORE-TRIO with PL is 11.45%.
# At time 97.23000028988208 ns, the overlap of CORE-TRIO with PL is 11.19%.
# At time 97.24000028991189 ns, the overlap of CORE-TRIO with PL is 11.90%.
# At time 97.2500002899417 ns, the overlap of CORE-TRIO with PL is 12.01%.
# At time 97.26000028997152 ns, the overlap of CORE-TRIO with PL is 12.29%.
# At time 97.27000029000133 ns, the overlap of CORE-TRIO with PL is 12.08%.
# At time 97.28000029003115 ns, the overlap of CORE-TRIO with PL is 11.84%.
# At time 97.29000029006096 ns, the overlap of CORE-TRIO with PL is 11.94%.
# At time 97.30000029009076 ns, the overlap of CORE-TRIO with PL is 11.97%.
# At time 97.31000029012058 ns, the overlap of CORE-TRIO with PL is 11.60%.
# At time 97.3200002901504 ns, the overlap of CORE-TRIO with PL is 11.53%.
# At time 97.33000029018022 ns, the overlap of CORE-TRIO with PL is 11.75%.
# At time 97.34000029021003 ns, the overlap of CORE-TRIO with PL is 11.90%.
# At time 97.35000029023985 ns, the overlap of CORE-TRIO with PL is 11.87%.
# At time 97.36000029026965 ns, the overlap of CORE-TRIO with PL is 11.46%.
# At time 97.37000029029947 ns, the overlap of CORE-TRIO with PL is 11.64%.
# At time 97.38000029032929 ns, the overlap of CORE-TRIO with PL is 11.70%.
# At time 97.3900002903591 ns, the overlap of CORE-TRIO with PL is 11.58%.
# At time 97.40000029038892 ns, the overlap of CORE-TRIO with PL is 11.22%.
# At time 97.41000029041872 ns, the overlap of CORE-TRIO with PL is 11.74%.
# At time 97.42000029044854 ns, the overlap of CORE-TRIO with PL is 11.36%.
# At time 97.43000029047836 ns, the overlap of CORE-TRIO with PL is 11.47%.
# At time 97.44000029050818 ns, the overlap of CORE-TRIO with PL is 12.03%.
# At time 103.4300003083668 ns, the overlap of CORE-TRIO with PL is 13.27%.
# At time 103.4400003083966 ns, the overlap of CORE-TRIO with PL is 13.71%.
# At time 103.45000030842641 ns, the overlap of CORE-TRIO with PL is 13.59%.
# At time 103.46000030845623 ns, the overlap of CORE-TRIO with PL is 13.82%.
# At time 103.47000030848605 ns, the overlap of CORE-TRIO with PL is 14.05%.
# At time 103.48000030851587 ns, the overlap of CORE-TRIO with PL is 13.73%.
# At time 103.49000030854567 ns, the overlap of CORE-TRIO with PL is 13.59%.
# At time 103.5000003085755 ns, the overlap of CORE-TRIO with PL is 13.72%.
# At time 103.5100003086053 ns, the overlap of CORE-TRIO with PL is 13.86%.
# At time 103.52000030863512 ns, the overlap of CORE-TRIO with PL is 13.66%.
# At time 103.53000030866494 ns, the overlap of CORE-TRIO with PL is 14.08%.
# At time 103.54000030869474 ns, the overlap of CORE-TRIO with PL is 14.23%.
# At time 103.55000030872456 ns, the overlap of CORE-TRIO with PL is 14.69%.
# At time 103.56000030875437 ns, the overlap of CORE-TRIO with PL is 14.31%.
# At time 103.57000030878419 ns, the overlap of CORE-TRIO with PL is 14.57%.
# At time 103.58000030881401 ns, the overlap of CORE-TRIO with PL is 14.07%.
# At time 103.59000030884381 ns, the overlap of CORE-TRIO with PL is 14.17%.
# At time 103.60000030887363 ns, the overlap of CORE-TRIO with PL is 14.18%.
# At time 103.61000030890344 ns, the overlap of CORE-TRIO with PL is 13.95%.
# At time 103.62000030893326 ns, the overlap of CORE-TRIO with PL is 14.15%.
# At time 103.63000030896308 ns, the overlap of CORE-TRIO with PL is 13.99%.
# At time 103.64000030899288 ns, the overlap of CORE-TRIO with PL is 13.86%.
# At time 103.6500003090227 ns, the overlap of CORE-TRIO with PL is 14.18%.
# At time 103.6600003090525 ns, the overlap of CORE-TRIO with PL is 13.99%.
# At time 103.67000030908233 ns, the overlap of CORE-TRIO with PL is 14.20%.
# At time 103.68000030911215 ns, the overlap of CORE-TRIO with PL is 14.11%.
# At time 103.69000030914196 ns, the overlap of CORE-TRIO with PL is 13.96%.
# At time 103.70000030917177 ns, the overlap of CORE-TRIO with PL is 14.17%.
# At time 103.71000030920159 ns, the overlap of CORE-TRIO with PL is 14.42%.
# At time 103.7200003092314 ns, the overlap of CORE-TRIO with PL is 14.54%.
# At time 103.73000030926121 ns, the overlap of CORE-TRIO with PL is 14.75%.
# At time 103.74000030929103 ns, the overlap of CORE-TRIO with PL is 14.97%.
# At time 103.75000030932084 ns, the overlap of CORE-TRIO with PL is 14.42%.
# At time 103.76000030935066 ns, the overlap of CORE-TRIO with PL is 14.38%.
# At time 103.77000030938046 ns, the overlap of CORE-TRIO with PL is 14.71%.
# At time 103.78000030941028 ns, the overlap of CORE-TRIO with PL is 14.59%.
# At time 103.7900003094401 ns, the overlap of CORE-TRIO with PL is 14.92%.
# At time 103.80000030946991 ns, the overlap of CORE-TRIO with PL is 14.14%.
# At time 103.81000030949973 ns, the overlap of CORE-TRIO with PL is 14.44%.
# At time 103.82000030952953 ns, the overlap of CORE-TRIO with PL is 14.90%.
# At time 103.83000030955935 ns, the overlap of CORE-TRIO with PL is 14.86%.
# At time 103.84000030958917 ns, the overlap of CORE-TRIO with PL is 14.39%.
# At time 103.85000030961898 ns, the overlap of CORE-TRIO with PL is 14.29%.
# At time 103.8600003096488 ns, the overlap of CORE-TRIO with PL is 14.21%.
# At time 103.87000030967862 ns, the overlap of CORE-TRIO with PL is 14.12%.
# At time 103.88000030970842 ns, the overlap of CORE-TRIO with PL is 14.21%.
# At time 103.89000030973824 ns, the overlap of CORE-TRIO with PL is 14.47%.
# At time 103.90000030976805 ns, the overlap of CORE-TRIO with PL is 14.72%.
# At time 103.91000030979787 ns, the overlap of CORE-TRIO with PL is 14.61%.
# At time 103.92000030982769 ns, the overlap of CORE-TRIO with PL is 14.44%.
# At time 103.93000030985749 ns, the overlap of CORE-TRIO with PL is 14.20%.
# At time 103.94000030988731 ns, the overlap of CORE-TRIO with PL is 14.48%.
# At time 103.95000030991712 ns, the overlap of CORE-TRIO with PL is 14.37%.
# At time 103.96000030994693 ns, the overlap of CORE-TRIO with PL is 14.55%.
# At time 103.97000030997675 ns, the overlap of CORE-TRIO with PL is 14.43%.
# At time 103.98000031000656 ns, the overlap of CORE-TRIO with PL is 14.59%.
# At time 103.99000031003638 ns, the overlap of CORE-TRIO with PL is 14.38%.
# At time 104.0000003100662 ns, the overlap of CORE-TRIO with PL is 14.32%.
# At time 104.010000310096 ns, the overlap of CORE-TRIO with PL is 14.20%.
# At time 104.02000031012582 ns, the overlap of CORE-TRIO with PL is 14.44%.
# At time 104.03000031015564 ns, the overlap of CORE-TRIO with PL is 14.22%.
# At time 104.04000031018545 ns, the overlap of CORE-TRIO with PL is 14.29%.
# At time 104.05000031021527 ns, the overlap of CORE-TRIO with PL is 14.06%.
# At time 104.06000031024507 ns, the overlap of CORE-TRIO with PL is 14.56%.
# At time 104.07000031027489 ns, the overlap of CORE-TRIO with PL is 14.30%.
# At time 104.08000031030471 ns, the overlap of CORE-TRIO with PL is 14.30%.
# At time 104.09000031033452 ns, the overlap of CORE-TRIO with PL is 14.41%.
# At time 104.10000031036434 ns, the overlap of CORE-TRIO with PL is 13.94%.
# At time 104.11000031039414 ns, the overlap of CORE-TRIO with PL is 13.88%.
# At time 104.12000031042396 ns, the overlap of CORE-TRIO with PL is 13.77%.
# At time 104.13000031045378 ns, the overlap of CORE-TRIO with PL is 14.35%.
# At time 104.14000031048359 ns, the overlap of CORE-TRIO with PL is 14.17%.
# At time 104.1500003105134 ns, the overlap of CORE-TRIO with PL is 14.03%.
# At time 104.16000031054321 ns, the overlap of CORE-TRIO with PL is 14.24%.
# At time 104.17000031057303 ns, the overlap of CORE-TRIO with PL is 13.60%.
# At time 104.18000031060285 ns, the overlap of CORE-TRIO with PL is 13.93%.
# At time 104.19000031063266 ns, the overlap of CORE-TRIO with PL is 13.90%.
# At time 104.20000031066247 ns, the overlap of CORE-TRIO with PL is 13.99%.
# At time 104.21000031069228 ns, the overlap of CORE-TRIO with PL is 13.98%.
# At time 104.2200003107221 ns, the overlap of CORE-TRIO with PL is 13.86%.
# At time 104.23000031075192 ns, the overlap of CORE-TRIO with PL is 13.81%.
# At time 104.24000031078174 ns, the overlap of CORE-TRIO with PL is 13.37%.
# At time 104.25000031081154 ns, the overlap of CORE-TRIO with PL is 13.87%.
# At time 104.26000031084135 ns, the overlap of CORE-TRIO with PL is 13.76%.
# At time 104.27000031087117 ns, the overlap of CORE-TRIO with PL is 13.44%.
# At time 104.28000031090099 ns, the overlap of CORE-TRIO with PL is 13.64%.
# At time 104.29000031093081 ns, the overlap of CORE-TRIO with PL is 13.55%.
# At time 104.30000031096061 ns, the overlap of CORE-TRIO with PL is 13.93%.
# At time 104.31000031099043 ns, the overlap of CORE-TRIO with PL is 13.53%.
# At time 104.32000031102024 ns, the overlap of CORE-TRIO with PL is 14.07%.
# At time 104.33000031105006 ns, the overlap of CORE-TRIO with PL is 13.93%.
# At time 104.34000031107988 ns, the overlap of CORE-TRIO with PL is 13.75%.
# At time 104.35000031110968 ns, the overlap of CORE-TRIO with PL is 13.97%.
# At time 104.3600003111395 ns, the overlap of CORE-TRIO with PL is 13.91%.

# %%
def plot_overlap_evolution(times, overlap_evolution):
    plt.rc('font', size=12, weight='bold')
    plt.rc('axes', titlesize=14, labelsize=12, titleweight='bold')
    plt.rc('legend', fontsize=10)

    # Create the plot
    plt.figure(figsize=(5, 3))
    plt.plot(times, overlap_evolution, marker='o', markersize=3, linewidth=2.5, label='Overlap Evolution')
    plt.title('Overlap Percentage Over Time')
    plt.xlabel('Time (ns)')
    plt.ylabel('Overlap Percentage (%)')
    plt.ylim(0, 20)
    plt.grid(True)
    plt.show()

# %%
plot_overlap_evolution(times1, overlap_evolution1)
plot_overlap_evolution(times2, overlap_evolution2)
plot_overlap_evolution(times3, overlap_evolution3)
plot_overlap_evolution(times4, overlap_evolution4)
plot_overlap_evolution(times5, overlap_evolution5)
# plot_overlap_evolution(times6, overlap_evolution6)
# plot_overlap_evolution(times7, overlap_evolution7)

# %%
percent_overlap(results_drude, 'PL', 'SURF-TRIO')
# Out:
# The overlap of SURF-TRIO with PL represents 1.18% of the total PL area.
# 1.1805354907013377

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_ov(results, type_1_name, type_2_name):
    # Retrieve density data from the results
    type_1 = results['density'][type_1_name]
    type_2 = results['density'][type_2_name]
    z = type_1[:, 0]  # Adjust the 'end' and 'num' based on your data specifics

    # Set font properties globally
    plt.rc('font', size=12, weight='bold')  # Increase font size and weight
    plt.rc('axes', titlesize=14, labelsize=12, titleweight='bold')
    plt.rc('legend', fontsize=10)

    # Create the plot
    plt.figure(figsize=(5, 2))  # Larger figure for more space around legend
    plt.plot(z, type_1[:, 1], label=f'{type_1_name} Density', color='blue', linewidth=3.5)
    plt.plot(z, type_2[:, 1], label=f'{type_2_name} Density', color='red', linewidth=3.5)
    plt.fill_between(z, 0, np.minimum(type_1[:, 1], type_2[:, 1]), color='purple', alpha=0.8, label='Overlap Region')
    plt.title('Density Distribution with Overlap (C36)')
    plt.xlabel('Depth (z)')
    plt.ylabel('Density')

    # Position legend outside of the plot
#     plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
#     plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust the plot to fit the legend
    plt.grid(True)
    plt.show()

# %%
plot_ov(results_c36, 'PL', 'CORE-TRIO')
plot_ov(results_c36c, 'PL', 'CORE-TRIO')
plot_ov(results_drude, 'PL', 'CORE-TRIO')
plot_ov(results_eq, 'PL', 'CORE-TRIO')
plot_ov(results_3mn, 'PL', 'CORE-TRIO')
plot_ov(results_5mn, 'PL', 'CORE-TRIO')
plot_ov(results_20mn, 'PL', 'CORE-TRIO')

# %%
# z = np.linspace(0, 100, num=len(pl_density[:, 1]))
z = pl_density[:,0] 
area_under_curve = np.trapz(pl_density[:, 1], x=z)

# %%
# Minimum of PL and TG densities at each point along the z-axis
overlap_density = np.minimum(pl_density[:, 1], surf_density[:, 1])
overlap_area = np.trapz(overlap_density, x=z)
total_pl_area = np.trapz(pl_density[:, 1], x=z)
overlap_percentage = (overlap_area / total_pl_area) * 100
print(f"The overlap of TG with PL represents {overlap_percentage:.2f}% of the total PL area.")
# Out:
# The overlap of TG with PL represents 8.38% of the total PL area.
